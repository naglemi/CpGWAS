# %% [markdown]
# # Make plots of DNAm vs prediction power (python version for better speed)

# %% [markdown]
# ## Investigate for one in EA population

# %%
import os
import pandas as pd
import glob

# %%
# Get current working directory
cwd = os.getcwd()

# Set working directory to the parent directory
os.chdir("..") 

# Read all CSV files
file_list = glob.glob("**/*-DNAm_stats.csv", recursive=True)

# %%
file_list_EA = [file for file in file_list if 'EA' in file]

# %%
file_list_AA = [file for file in file_list if 'AA' in file]

# %%
len(file_list_EA)
# Out:
# 3807

# %%
temp_data = pd.read_csv(file_list_EA[1])

# %%
temp_data
# Out:
#        Chr       pos population region     mean_DNAm  var_DNAm       cor  \
# 0        7  10646506         EA  dlpfc -2.692077e-13  0.001964  0.556408
# 1        7  10646743         EA  dlpfc -2.692953e-13  0.001716  0.412880
# 2        7  10646946         EA  dlpfc -2.717399e-13  0.001528  0.507973
# 3        7  10646976         EA  dlpfc -2.706019e-13  0.001501  0.541968
# 4        7  10647749         EA  dlpfc -2.804850e-13  0.000970  0.550926
# ...    ...       ...        ...    ...           ...       ...       ...
# 19995    7  13899949         EA  dlpfc -2.988101e-13  0.000535  0.399458
# 19996    7  13899954         EA  dlpfc -2.988123e-13  0.000532  0.266209
# 19997    7  13899999         EA  dlpfc -3.011459e-13  0.000502  0.478905
# 19998    7  13900085         EA  dlpfc -3.003666e-13  0.000451       NaN
# 19999    7  13900107         EA  dlpfc -2.983895e-13  0.000440  0.202921
#
#             mse
# 0      0.001590
# 1      0.001682
# 2      0.001420
# 3      0.001271
# ...

# %%
temp_data = pd.read_csv(file_list_AA[1])

# %%
temp_data
# Out:
#        Chr        pos population region     mean_DNAm  var_DNAm       cor  \
# 0        7  125315260         AA  dlpfc  4.560916e-16  0.000220  0.328103
# 1        7  125315262         AA  dlpfc  8.311670e-16  0.000220  0.244956
# 2        7  125315301         AA  dlpfc  8.091625e-16  0.000220  0.328187
# 3        7  125315335         AA  dlpfc  8.141636e-16  0.000220  0.386078
# 4        7  125315396         AA  dlpfc  3.540711e-16  0.000221  0.434050
# ...    ...        ...        ...    ...           ...       ...       ...
# 19995    7  128308554         AA  dlpfc  4.010806e-16  0.000222  0.332804
# 19996    7  128308588         AA  dlpfc -3.300663e-17  0.000225  0.086366
# 19997    7  128308686         AA  dlpfc  7.761559e-16  0.000238  0.230438
# 19998    7  128308806         AA  dlpfc  2.900583e-16  0.000261  0.112883
# 19999    7  128308834         AA  dlpfc  2.990601e-16  0.000267  0.146492
#
#             mse
# 0      0.000219
# 1      0.000220
# 2      0.000223
# ...

# %% [markdown]
# ## Run over all

# %%
import os
import pandas as pd
import glob

# Get current working directory
cwd = os.getcwd()

# Set working directory to the parent directory
os.chdir("..")

# Read all CSV files
file_list = glob.glob("**/*-DNAm_stats.csv", recursive=True)

print(len(file_list))

# Open a file in write mode to write the header
with open("15a2-OUT_DNAm_vs_cor_intermediate.csv", "w") as f:
    header_written = False
    
    for i, file in enumerate(file_list, start=1):
        if i % 20 == 0:
            print(i)
        temp_data = pd.read_csv(file)
        
        # Write the header only once
        if not header_written:
            temp_data.to_csv(f, index=False)
            header_written = True
        else:
            temp_data.to_csv(f, index=False, header=False, mode='a')
# Out:
# 11420
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# ...

# %%
# # Plot mean_DNAm and var_DNAm vs. cor
# ggplot(combined_data, aes(x = cor)) +
#   geom_point(aes(y = mean_DNAm), color = "blue", alpha = 0.5) +
#   geom_point(aes(y = var_DNAm), color = "red", alpha = 0.5) +
#   labs(title = "Mean and Variance of DNAm vs. Correlation",
#        x = "Correlation",
#        y = "Value") +
#   scale_y_continuous(sec.axis = sec_axis(~ ., name = "Variance DNAm")) +
#   theme_minimal()
