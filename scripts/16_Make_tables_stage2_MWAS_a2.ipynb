# %% [markdown]
# # Produce tables of stage 2 MWAS results

# %%
library(data.table)
library(foreach)
library(doParallel)

# %%
getwd()
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts"

# %%
df <- fread("12-OUT_matched_SNP_meth_cov_outputs.csv")

# %%
print(nrow(df))
# Out:
# [1] 16098

# %%
library(data.table)
library(ggplot2)

# %%
# Initialize logging
log_file <- file("processing_log.txt", open = "wt")
sink(log_file, type = "message")
sink(log_file, type = "output", append = TRUE)

# %%
traits <- c("bp", "mdd", "scz")
df$stage2_paths <- gsub(".rds", "_gwas_stat_", df$path)
df$final_paths <- vector("list", length(df$stage2_paths))

# %%
for (trait in traits) {
  message("Processing trait: ", trait)
  df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
}
# Out:
# Processing trait: bp
#
# Processing trait: mdd
#
# Processing trait: scz

# %%
for (trait in traits) {
  message("Processing trait: ", trait)
  df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
  output_file <- paste0("16a6-OUT_stage2_MWAS_", trait, ".csv")
  header_written <- FALSE

  for (i in seq_along(df$final_paths)) {
    if (grepl("empty", df$final_paths[i])) next
    
    # Only print a message for every 20th file
    if (i %% 20 == 0) {
      message("Processing file ", i, " of ", length(df$final_paths))
    }

    stage2_in <- readRDS(df$final_paths[i])
    stage1_in <- readRDS(df$path[i])
    
    if (length(stage1_in@models) != length(stage2_in@MWASmodels)) {
      stop("Files don't match")
    }

    data_list <- vector("list", length(stage1_in@models))
    for (j in seq_along(stage1_in@models)) {
      model1 <- stage1_in@models[[j]]
      model2 <- stage2_in@MWASmodels[[j]]

      data_list[[j]] <- data.table(
        z = model2["z"],
        p = model2["p"],
        n = model2["n"],
        pos = model1@methylationPosition,
        stats = stage2_in@summary_stats_path,
        scaff = stage1_in@scaffoldIdentifier
      )
    }

    combined_data <- rbindlist(data_list, use.names = TRUE, fill = TRUE)

    # Write data incrementally
    if (!header_written) {
      fwrite(combined_data, output_file)
      header_written <- TRUE
    } else {
      fwrite(combined_data, output_file, append = TRUE)
    }
  }
}

# Close the log file
sink(type = "message")
sink(type = "output")
close(log_file)

# %% [markdown]
# ## Trust but verify

# %%
which(df$final_paths == "..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240505-001208_gwas_stat_bp_results.rds")
# Out:
# integer(0)

# %% [markdown]
# ## Investigate the files that didn't finish and repeat if needed

# %%
df$final_paths[4294]
# Out:
# [1] "..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240505-001208_gwas_stat_scz_results.rds"

# %%
file.exists(df$final_paths[4294])
# Out:
# [1] TRUE

# %%
file.exists(df$final_paths[4293])
# Out:
# [1] TRUE

# %%
file.exists(df$final_paths[4299])
# Out:
# [1] TRUE

# %%
df$exists <- file.exists(df$final_paths)

# %%
levels(factor(df$exists))
# Out:
# [1] "FALSE" "TRUE"

# %%
table(df$exists)
# Out:
# FALSE  TRUE
#    54 16044

# %%
df[!df$exists, ]
# Out:
#    Chr population region chunk_start chunk_end
# 1   1  AA         caud   1248982     1268981
# 2   1  AA         caud   1248982     1268981
# 3   1  AA         caud   1268982     1288981
# 4   1  AA         caud   1268982     1288981
# 5   1  AA         dlpfc  1248982     1268981
# 6   1  AA         dlpfc  1248982     1268981
# 7   1  AA         dlpfc  1268982     1288981
# 8   1  AA         dlpfc  1268982     1288981
# 9   1  AA         hippo  1248982     1268981
# 10  1  AA         hippo  1248982     1268981
# 11  1  AA         hippo  1268982     1288981
# 12  1  AA         hippo  1268982     1288981
# 13  1  EA         caud   1248982     1268981
# 14  1  EA         caud   1248982     1268981
# 15  1  EA         caud   1268982     1288981
# 16  1  EA         caud   1268982     1288981
# 17  1  EA         dlpfc  1248982     1268981
# 18  1  EA         dlpfc  1248982     1268981
# 19  1  EA         dlpfc  1268982     1288981
# 20  1  EA         dlpfc  1268982     1288981
# 21  1  EA         hippo  1248982     1268981
# 22  1  EA         hippo  1248982     1268981
# 23  1  EA         hippo  1268982     1288981
# 24  1  EA         hippo  1268982     1288981
# 25  1  all        caud   1248982     1268981
# 26  1  all        caud   1248982     1268981
# 27  1  all        caud   1268982     1288981
# 28  1  all        caud   1268982     1288981
# 29  1  all        dlpfc  1248982     1268981
# 30  1  all        dlpfc  1248982     1268981
# 31  1  all        dlpfc  1268982     1288981
# 32  1  all        dlpfc  1268982     1288981
# 33  1  all        hippo  1248982     1268981
# 34  1  all        hippo  1248982     1268981
# 35  1  all        hippo  1268982     1288981
# 36  1  all        hippo  1268982     1288981
# 37  9  AA         caud    302159      322158
# 38  9  AA         dlpfc   302159      322158
# 39  9  AA         hippo   302159      322158
# 40  9  EA         caud    302159      322158
# 41  9  EA         dlpfc   302159      322158
# 42  9  EA         hippo   302159      322158
# 43  9  all        caud    302159      322158
# 44  9  all        dlpfc   302159      322158
# 45  9  all        hippo   302159      322158
# 46 12  AA         caud    100001      120000
# 47 12  AA         dlpfc   100001      120000
# 48 12  AA         hippo   100001      120000
# 49 12  EA         caud    100001      120000
# 50 12  EA         dlpfc   100001      120000
# 51 12  EA         hippo   100001      120000
# 52 12  all        caud    100001      120000
# 53 12  all        dlpfc   100001      120000
# 54 12  all        hippo   100001      120000
#    SNP_data
# 1  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 2  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 3  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 4  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 5  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 6  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 7  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 8  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 9  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 10 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 11 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 12 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 13 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 14 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 15 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 16 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 17 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 18 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 19 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 20 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 21 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 22 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 23 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 24 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 25 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 26 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 27 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 28 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 29 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 30 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 31 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 32 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 33 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 34 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 35 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 36 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr1.pgen
# 37 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 38 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 39 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 40 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 41 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 42 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 43 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 44 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 45 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr9.pgen
# 46 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 47 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 48 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 49 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 50 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 51 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 52 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 53 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
# 54 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr12.pgen
#    methylation_data
# 1  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_AA.rda
# 2  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_AA.rda
# 3  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_AA.rda
# 4  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_AA.rda
# 5  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_AA.rda
# 6  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_AA.rda
# 7  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_AA.rda
# 8  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_AA.rda
# 9  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_AA.rda
# 10 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_AA.rda
# 11 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_AA.rda
# 12 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_AA.rda
# 13 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_EA.rda
# 14 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_EA.rda
# 15 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_EA.rda
# 16 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_EA.rda
# 17 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_EA.rda
# 18 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_EA.rda
# 19 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_EA.rda
# 20 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_EA.rda
# 21 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_EA.rda
# 22 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_EA.rda
# 23 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_EA.rda
# 24 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_EA.rda
# 25 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_all.rda
# 26 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_all.rda
# 27 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_all.rda
# 28 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr1_all.rda
# 29 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_all.rda
# 30 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_all.rda
# 31 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_all.rda
# 32 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr1_all.rda
# 33 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_all.rda
# 34 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_all.rda
# 35 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_all.rda
# 36 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr1_all.rda
# 37 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr9_AA.rda
# 38 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr9_AA.rda
# 39 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr9_AA.rda
# 40 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr9_EA.rda
# 41 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr9_EA.rda
# 42 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr9_EA.rda
# 43 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr9_all.rda
# 44 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr9_all.rda
# 45 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr9_all.rda
# 46 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr12_AA.rda
# 47 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr12_AA.rda
# 48 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr12_AA.rda
# 49 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr12_EA.rda
# 50 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr12_EA.rda
# 51 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr12_EA.rda
# 52 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr12_all.rda
# 53 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr12_all.rda
# 54 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr12_all.rda
#    last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1  248918358                         1069461
# 2  248918358                         1069461
# 3  248918358                         1069461
# 4  248918358                         1069461
# 5  248918358                         1069461
# 6  248918358                         1069461
# 7  248918358                         1069461
# 8  248918358                         1069461
# 9  248918358                         1069461
# 10 248918358                         1069461
# 11 248918358                         1069461
# 12 248918358                         1069461
# 13 248918358                         1069461
# 14 248918358                         1069461
# 15 248918358                         1069461
# 16 248918358                         1069461
# 17 248918358                         1069461
# 18 248918358                         1069461
# 19 248918358                         1069461
# 20 248918358                         1069461
# 21 248918358                         1069461
# 22 248918358                         1069461
# 23 248918358                         1069461
# 24 248918358                         1069461
# 25 248918358                         1069461
# 26 248918358                         1069461
# 27 248918358                         1069461
# 28 248918358                         1069461
# 29 248918358                         1069461
# 30 248918358                         1069461
# 31 248918358                         1069461
# 32 248918358                         1069461
# 33 248918358                         1069461
# 34 248918358                         1069461
# 35 248918358                         1069461
# 36 248918358                         1069461
# 37 136933101                          164314
# 38 136933101                          164314
# 39 136933101                          164314
# 40 136933101                          164314
# 41 136933101                          164314
# 42 136933101                          164314
# 43 136933101                          164314
# 44 136933101                          164314
# 45 136933101                          164314
# 46 133239922                           77807
# 47 133239922                           77807
# 48 133239922                           77807
# 49 133239922                           77807
# 50 133239922                           77807
# 51 133239922                           77807
# 52 133239922                           77807
# 53 133239922                           77807
# 54 133239922                           77807
#    last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1  2202702                           8982
# 2  2202702                           8982
# 3  2202702                           8982
# 4  2202702                           8982
# 5  2202702                           8982
# 6  2202702                           8982
# 7  2202702                           8982
# 8  2202702                           8982
# 9  2202702                           8982
# 10 2202702                           8982
# 11 2202702                           8982
# 12 2202702                           8982
# 13 2202702                           8982
# 14 2202702                           8982
# 15 2202702                           8982
# 16 2202702                           8982
# 17 2202702                           8982
# 18 2202702                           8982
# 19 2202702                           8982
# 20 2202702                           8982
# 21 2202702                           8982
# 22 2202702                           8982
# 23 2202702                           8982
# 24 2202702                           8982
# 25 2202702                           8982
# 26 2202702                           8982
# 27 2202702                           8982
# 28 2202702                           8982
# 29 2202702                           8982
# 30 2202702                           8982
# 31 2202702                           8982
# 32 2202702                           8982
# 33 2202702                           8982
# 34 2202702                           8982
# 35 2202702                           8982
# 36 2202702                           8982
# 37 1064218                           2159
# 38 1064218                           2159
# 39 1064218                           2159
# 40 1064218                           2159
# 41 1064218                           2159
# 42 1064218                           2159
# 43 1064218                           2159
# 44 1064218                           2159
# 45 1064218                           2159
# 46 1222018                              1
# 47 1222018                              1
# 48 1222018                              1
# 49 1222018                              1
# 50 1222018                              1
# 51 1222018                              1
# 52 1222018                              1
# 53 1222018                              1
# 54 1222018                              1
#    cov_file
# 1  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 2  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 3  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 4  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 5  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 6  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 7  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 8  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 9  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 10 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 11 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 12 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 13 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 14 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 15 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 16 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 17 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 18 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 19 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 20 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 21 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 22 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 23 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 24 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 25 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 26 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 27 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 28 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 29 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 30 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 31 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 32 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 33 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 34 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 35 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 36 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 37 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 38 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 39 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 40 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 41 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 42 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 43 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 44 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 45 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 46 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 47 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 48 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 49 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 50 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 51 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 52 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 53 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 54 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
#    modified_methylation_data
# 1  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_AA_1248982-1268981.rds
# 2  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_AA_1248982-1268981.rds
# 3  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_AA_1268982-1288981.rds
# 4  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_AA_1268982-1288981.rds
# 5  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_AA_1248982-1268981.rds
# 6  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_AA_1248982-1268981.rds
# 7  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_AA_1268982-1288981.rds
# 8  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_AA_1268982-1288981.rds
# 9  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_AA_1248982-1268981.rds
# 10 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_AA_1248982-1268981.rds
# 11 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_AA_1268982-1288981.rds
# 12 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_AA_1268982-1288981.rds
# 13 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_EA_1248982-1268981.rds
# 14 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_EA_1248982-1268981.rds
# 15 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_EA_1268982-1288981.rds
# 16 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_EA_1268982-1288981.rds
# 17 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_EA_1248982-1268981.rds
# 18 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_EA_1248982-1268981.rds
# 19 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_EA_1268982-1288981.rds
# 20 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_EA_1268982-1288981.rds
# 21 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_EA_1248982-1268981.rds
# 22 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_EA_1248982-1268981.rds
# 23 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_EA_1268982-1288981.rds
# 24 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_EA_1268982-1288981.rds
# 25 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_all_1248982-1268981.rds
# 26 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_all_1248982-1268981.rds
# 27 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_all_1268982-1288981.rds
# 28 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr1_all_1268982-1288981.rds
# 29 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_all_1248982-1268981.rds
# 30 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_all_1248982-1268981.rds
# 31 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_all_1268982-1288981.rds
# 32 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr1_all_1268982-1288981.rds
# 33 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_all_1248982-1268981.rds
# 34 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_all_1248982-1268981.rds
# 35 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_all_1268982-1288981.rds
# 36 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr1_all_1268982-1288981.rds
# 37 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr9_AA_302159-322158.rds
# 38 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr9_AA_302159-322158.rds
# 39 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr9_AA_302159-322158.rds
# 40 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr9_EA_302159-322158.rds
# 41 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr9_EA_302159-322158.rds
# 42 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr9_EA_302159-322158.rds
# 43 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr9_all_302159-322158.rds
# 44 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr9_all_302159-322158.rds
# 45 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr9_all_302159-322158.rds
# 46 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr12_AA_100001-120000.rds
# 47 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr12_AA_100001-120000.rds
# 48 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr12_AA_100001-120000.rds
# 49 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr12_EA_100001-120000.rds
# 50 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr12_EA_100001-120000.rds
# 51 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr12_EA_100001-120000.rds
# 52 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr12_all_100001-120000.rds
# 53 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr12_all_100001-120000.rds
# 54 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr12_all_100001-120000.rds
#    path
# 1  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-110927-empty.rds
# 2  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-132314-empty.rds
# 3  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-111229-empty.rds
# 4  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-132415-empty.rds
# 5  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-114006-empty.rds
# 6  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-190109-empty.rds
# 7  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-114308-empty.rds
# 8  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-190211-empty.rds
# 9  ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-123446-empty.rds
# 10 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-003819-empty.rds
# 11 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-123748-empty.rds
# 12 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-003920-empty.rds
# 13 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-113056-empty.rds
# 14 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-170831-empty.rds
# 15 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-113357-empty.rds
# 16 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-170932-empty.rds
# 17 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-121330-empty.rds
# 18 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-224549-empty.rds
# 19 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-121631-empty.rds
# 20 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-224650-empty.rds
# 21 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-130205-empty.rds
# 22 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-042252-empty.rds
# 23 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-130506-empty.rds
# 24 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-042353-empty.rds
# 25 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-111841-empty.rds
# 26 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-151543-empty.rds
# 27 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-112142-empty.rds
# 28 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-151647-empty.rds
# 29 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-114614-empty.rds
# 30 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-205334-empty.rds
# 31 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-114916-empty.rds
# 32 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-205435-empty.rds
# 33 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-124053-empty.rds
# 34 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-023027-empty.rds
# 35 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-124354-empty.rds
# 36 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-023128-empty.rds
# 37 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240508-074519-empty.rds
# 38 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205028-empty.rds
# 39 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205338-empty.rds
# 40 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240508-074827-empty.rds
# 41 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205235-empty.rds
# 42 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205646-empty.rds
# 43 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240508-074724-empty.rds
# 44 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240509-205132-empty.rds
# 45 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240509-205441-empty.rds
# 46 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240501-192342-empty.rds
# 47 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240502-014011-empty.rds
# 48 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240502-075630-empty.rds
# 49 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240501-233440-empty.rds
# 50 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240502-055107-empty.rds
# 51 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240502-120717-empty.rds
# 52 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240501-212912-empty.rds
# 53 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240502-034537-empty.rds
# 54 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240502-100152-empty.rds
#    stage2_paths
# 1  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-110927-empty_gwas_stat_
# 2  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-132314-empty_gwas_stat_
# 3  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-111229-empty_gwas_stat_
# 4  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-132415-empty_gwas_stat_
# 5  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-114006-empty_gwas_stat_
# 6  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-190109-empty_gwas_stat_
# 7  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-114308-empty_gwas_stat_
# 8  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-190211-empty_gwas_stat_
# 9  ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-123446-empty_gwas_stat_
# 10 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-003819-empty_gwas_stat_
# 11 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-123748-empty_gwas_stat_
# 12 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-003920-empty_gwas_stat_
# 13 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-113056-empty_gwas_stat_
# 14 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-170831-empty_gwas_stat_
# 15 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-113357-empty_gwas_stat_
# 16 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-170932-empty_gwas_stat_
# 17 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-121330-empty_gwas_stat_
# 18 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-224549-empty_gwas_stat_
# 19 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-121631-empty_gwas_stat_
# 20 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-224650-empty_gwas_stat_
# 21 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-130205-empty_gwas_stat_
# 22 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-042252-empty_gwas_stat_
# 23 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-130506-empty_gwas_stat_
# 24 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-042353-empty_gwas_stat_
# 25 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-111841-empty_gwas_stat_
# 26 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-151543-empty_gwas_stat_
# 27 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-112142-empty_gwas_stat_
# 28 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-151647-empty_gwas_stat_
# 29 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-114614-empty_gwas_stat_
# 30 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-205334-empty_gwas_stat_
# 31 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-114916-empty_gwas_stat_
# 32 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-205435-empty_gwas_stat_
# 33 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-124053-empty_gwas_stat_
# 34 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-023027-empty_gwas_stat_
# 35 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-124354-empty_gwas_stat_
# 36 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-023128-empty_gwas_stat_
# 37 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240508-074519-empty_gwas_stat_
# 38 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205028-empty_gwas_stat_
# 39 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205338-empty_gwas_stat_
# 40 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240508-074827-empty_gwas_stat_
# 41 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205235-empty_gwas_stat_
# 42 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205646-empty_gwas_stat_
# 43 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240508-074724-empty_gwas_stat_
# 44 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240509-205132-empty_gwas_stat_
# 45 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240509-205441-empty_gwas_stat_
# 46 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240501-192342-empty_gwas_stat_
# 47 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240502-014011-empty_gwas_stat_
# 48 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240502-075630-empty_gwas_stat_
# 49 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240501-233440-empty_gwas_stat_
# 50 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240502-055107-empty_gwas_stat_
# 51 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240502-120717-empty_gwas_stat_
# 52 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240501-212912-empty_gwas_stat_
# 53 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240502-034537-empty_gwas_stat_
# 54 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240502-100152-empty_gwas_stat_
#    final_paths
# 1  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-110927-empty_gwas_stat_scz_results.rds
# 2  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-132314-empty_gwas_stat_scz_results.rds
# 3  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-111229-empty_gwas_stat_scz_results.rds
# 4  ..//output_EXPANSE_a2_caud/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-132415-empty_gwas_stat_scz_results.rds
# 5  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-114006-empty_gwas_stat_scz_results.rds
# 6  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-190109-empty_gwas_stat_scz_results.rds
# 7  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-114308-empty_gwas_stat_scz_results.rds
# 8  ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-190211-empty_gwas_stat_scz_results.rds
# 9  ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-123446-empty_gwas_stat_scz_results.rds
# 10 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-003819-empty_gwas_stat_scz_results.rds
# 11 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-123748-empty_gwas_stat_scz_results.rds
# 12 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_AA-libd_chr1-chr1_AA-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-003920-empty_gwas_stat_scz_results.rds
# 13 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-113056-empty_gwas_stat_scz_results.rds
# 14 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-170831-empty_gwas_stat_scz_results.rds
# 15 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-113357-empty_gwas_stat_scz_results.rds
# 16 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-170932-empty_gwas_stat_scz_results.rds
# 17 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-121330-empty_gwas_stat_scz_results.rds
# 18 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-224549-empty_gwas_stat_scz_results.rds
# 19 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-121631-empty_gwas_stat_scz_results.rds
# 20 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-224650-empty_gwas_stat_scz_results.rds
# 21 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-130205-empty_gwas_stat_scz_results.rds
# 22 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-042252-empty_gwas_stat_scz_results.rds
# 23 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-130506-empty_gwas_stat_scz_results.rds
# 24 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_EA-libd_chr1-chr1_EA-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-042353-empty_gwas_stat_scz_results.rds
# 25 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-111841-empty_gwas_stat_scz_results.rds
# 26 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-caud-20240510-151543-empty_gwas_stat_scz_results.rds
# 27 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-112142-empty_gwas_stat_scz_results.rds
# 28 ..//output_EXPANSE_a2_caud/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-caud-20240510-151647-empty_gwas_stat_scz_results.rds
# 29 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-114614-empty_gwas_stat_scz_results.rds
# 30 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-dlpfc-20240510-205334-empty_gwas_stat_scz_results.rds
# 31 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-114916-empty_gwas_stat_scz_results.rds
# 32 ..//output_EXPANSE_a2_dlpfc/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-dlpfc-20240510-205435-empty_gwas_stat_scz_results.rds
# 33 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-20240501-124053-empty_gwas_stat_scz_results.rds
# 34 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1248982-1268981-dynamic-1corestotal-allcorepera-hippo-20240511-023027-empty_gwas_stat_scz_results.rds
# 35 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-20240501-124354-empty_gwas_stat_scz_results.rds
# 36 ..//output_EXPANSE_a2_hippo/libd_chr1-chr1_all-libd_chr1-chr1_all-1268982-1288981-dynamic-1corestotal-allcorepera-hippo-20240511-023128-empty_gwas_stat_scz_results.rds
# 37 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240508-074519-empty_gwas_stat_scz_results.rds
# 38 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205028-empty_gwas_stat_scz_results.rds
# 39 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_AA-libd_chr9-chr9_AA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205338-empty_gwas_stat_scz_results.rds
# 40 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240508-074827-empty_gwas_stat_scz_results.rds
# 41 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205235-empty_gwas_stat_scz_results.rds
# 42 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_EA-libd_chr9-chr9_EA-302159-322158-dynamic-1corestotal-allcorepera-20240509-205646-empty_gwas_stat_scz_results.rds
# 43 ..//output_EXPANSE_a2_caud/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240508-074724-empty_gwas_stat_scz_results.rds
# 44 ..//output_EXPANSE_a2_dlpfc/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240509-205132-empty_gwas_stat_scz_results.rds
# 45 ..//output_EXPANSE_a2_hippo/libd_chr9-chr9_all-libd_chr9-chr9_all-302159-322158-dynamic-1corestotal-allcorepera-20240509-205441-empty_gwas_stat_scz_results.rds
# 46 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240501-192342-empty_gwas_stat_scz_results.rds
# 47 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240502-014011-empty_gwas_stat_scz_results.rds
# 48 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_AA-libd_chr12-chr12_AA-100001-120000-dynamic-1corestotal-allcorepera-20240502-075630-empty_gwas_stat_scz_results.rds
# 49 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240501-233440-empty_gwas_stat_scz_results.rds
# 50 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240502-055107-empty_gwas_stat_scz_results.rds
# 51 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_EA-libd_chr12-chr12_EA-100001-120000-dynamic-1corestotal-allcorepera-20240502-120717-empty_gwas_stat_scz_results.rds
# 52 ..//output_EXPANSE_a2_caud/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240501-212912-empty_gwas_stat_scz_results.rds
# 53 ..//output_EXPANSE_a2_dlpfc/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240502-034537-empty_gwas_stat_scz_results.rds
# 54 ..//output_EXPANSE_a2_hippo/libd_chr12-chr12_all-libd_chr12-chr12_all-100001-120000-dynamic-1corestotal-allcorepera-20240502-100152-empty_gwas_stat_scz_results.rds
#    exists
# 1  FALSE
# 2  FALSE
# 3  FALSE
# 4  FALSE
# 5  FALSE
# 6  FALSE
# 7  FALSE
# 8  FALSE
# 9  FALSE
# 10 FALSE
# 11 FALSE
# 12 FALSE
# 13 FALSE
# 14 FALSE
# 15 FALSE
# 16 FALSE
# 17 FALSE
# 18 FALSE
# 19 FALSE
# 20 FALSE
# 21 FALSE
# 22 FALSE
# 23 FALSE
# 24 FALSE
# 25 FALSE
# 26 FALSE
# 27 FALSE
# 28 FALSE
# 29 FALSE
# 30 FALSE
# 31 FALSE
# 32 FALSE
# 33 FALSE
# 34 FALSE
# 35 FALSE
# 36 FALSE
# 37 FALSE
# 38 FALSE
# 39 FALSE
# 40 FALSE
# 41 FALSE
# 42 FALSE
# 43 FALSE
# 44 FALSE
# 45 FALSE
# 46 FALSE
# 47 FALSE
# 48 FALSE
# 49 FALSE
# 50 FALSE
# 51 FALSE
# 52 FALSE
# 53 FALSE
# 54 FALSE

# %% [markdown]
# Ok, some don't exist because we had empty rds due to no SNPs... okay, but what about the other 76?

# %%
df_not_empty_rds_due_to_no_snps_in_window <- df[!grepl("empty", df$path), ]

# %%
library(data.table)

# Sort df alphabetically by final_paths
df_not_empty_rds_due_to_no_snps_in_window <- df[!grepl("empty", df$path), ]
setorder(df_not_empty_rds_due_to_no_snps_in_window, final_paths)

# %%
# Remove duplicates, keeping the last occurrence
df_not_empty_rds_due_to_no_snps_in_window <- df_not_empty_rds_due_to_no_snps_in_window[
  , .SD[.N], by = modified_methylation_data
]

# %% [markdown]
# Even if we remove the ones interrupted...

# %%
table(df_not_empty_rds_due_to_no_snps_in_window$exists)
# Out:
#  TRUE
# 11421

# %%
df_not_empty_rds_due_to_no_snps_in_window[!which(df_not_empty_rds_due_to_no_snps_in_window$exists), ]
# Out:
#      modified_methylation_data Chr population region chunk_start chunk_end
#      SNP_data methylation_data last_meth_value_with_SNP_coverage
#      first_meth_value_with_SNP_coverage last_meth_index_with_SNP_coverage
#      first_meth_index_with_SNP_coverage cov_file path stage2_paths final_paths
#      exists

# %%
length(levels(factor(df_not_empty_rds_due_to_no_snps_in_window$modified_methylation_data)))
# Out:
# [1] 11421

# %%
length(levels(factor(df_not_empty_rds_due_to_no_snps_in_window$modified_methylation_data[which(
    df_not_empty_rds_due_to_no_snps_in_window$exists == TRUE
)])))
# Out:
# [1] 11421

# %% [markdown]
# What if we don't remove earlier observations

# %%
# Sort df alphabetically by final_paths
df_not_empty_rds_due_to_no_snps_in_window <- df[!grepl("empty", df$path), ]
setorder(df_not_empty_rds_due_to_no_snps_in_window, final_paths)

# %%
length(levels(factor(df_not_empty_rds_due_to_no_snps_in_window$modified_methylation_data[which(
    df_not_empty_rds_due_to_no_snps_in_window$exists == TRUE
)])))
# Out:
# [1] 11418

# %%
df[(grepl("1520001", df$modified_methylation_data)), ]
# Out:
#    Chr population region chunk_start chunk_end
# 1  2   AA         caud   1520001     1540000
# 2  2   AA         caud   1520001     1540000
# 3  2   AA         dlpfc  1520001     1540000
# 4  2   AA         dlpfc  1520001     1540000
# 5  2   AA         dlpfc  1520001     1540000
# 6  2   AA         hippo  1520001     1540000
# 7  2   AA         hippo  1520001     1540000
# 8  2   AA         hippo  1520001     1540000
# 9  2   EA         caud   1520001     1540000
# 10 2   EA         caud   1520001     1540000
# 11 2   EA         dlpfc  1520001     1540000
# 12 2   EA         dlpfc  1520001     1540000
# 13 2   EA         dlpfc  1520001     1540000
# 14 2   EA         hippo  1520001     1540000
# 15 2   EA         hippo  1520001     1540000
# 16 2   EA         hippo  1520001     1540000
# 17 2   all        caud   1520001     1540000
# 18 2   all        caud   1520001     1540000
# 19 2   all        dlpfc  1520001     1540000
# 20 2   all        dlpfc  1520001     1540000
# 21 2   all        dlpfc  1520001     1540000
# 22 2   all        hippo  1520001     1540000
# 23 2   all        hippo  1520001     1540000
# 24 2   all        hippo  1520001     1540000
# 25 3   AA         caud   1520001     1538467
# 26 3   AA         caud   1520001     1538467
# 27 3   AA         caud   1520001     1538467
# 28 3   AA         dlpfc  1520001     1538467
# 29 3   AA         dlpfc  1520001     1538467
# 30 3   AA         dlpfc  1520001     1538467
# 31 3   AA         hippo  1520001     1538467
# 32 3   AA         hippo  1520001     1538467
# 33 3   AA         hippo  1520001     1538467
# 34 3   EA         caud   1520001     1538467
# 35 3   EA         caud   1520001     1538467
# 36 3   EA         dlpfc  1520001     1538467
# 37 3   EA         dlpfc  1520001     1538467
# 38 3   EA         dlpfc  1520001     1538467
# 39 3   EA         hippo  1520001     1538467
# 40 3   EA         hippo  1520001     1538467
# 41 3   EA         hippo  1520001     1538467
# 42 3   all        caud   1520001     1538467
# 43 3   all        caud   1520001     1538467
# 44 3   all        caud   1520001     1538467
# 45 3   all        dlpfc  1520001     1538467
# 46 3   all        dlpfc  1520001     1538467
# 47 3   all        dlpfc  1520001     1538467
# 48 3   all        hippo  1520001     1538467
# 49 3   all        hippo  1520001     1538467
#    SNP_data
# 1  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 2  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 3  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 4  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 5  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 6  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 7  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 8  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 9  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 10 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 11 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 12 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 13 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 14 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 15 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 16 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 17 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 18 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 19 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 20 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 21 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 22 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 23 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 24 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 25 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 26 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 27 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 28 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 29 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 30 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 31 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 32 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 33 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 34 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 35 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 36 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 37 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 38 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 39 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 40 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 41 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 42 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 43 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 44 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 45 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 46 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 47 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 48 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
# 49 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr3.pgen
#    methylation_data
# 1  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr2_AA.rda
# 2  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr2_AA.rda
# 3  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_AA.rda
# 4  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_AA.rda
# 5  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_AA.rda
# 6  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_AA.rda
# 7  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_AA.rda
# 8  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_AA.rda
# 9  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr2_EA.rda
# 10 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr2_EA.rda
# 11 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_EA.rda
# 12 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_EA.rda
# 13 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_EA.rda
# 14 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_EA.rda
# 15 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_EA.rda
# 16 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_EA.rda
# 17 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr2_all.rda
# 18 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr2_all.rda
# 19 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_all.rda
# 20 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_all.rda
# 21 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr2_all.rda
# 22 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 23 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 24 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 25 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_AA.rda
# 26 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_AA.rda
# 27 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_AA.rda
# 28 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_AA.rda
# 29 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_AA.rda
# 30 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_AA.rda
# 31 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_AA.rda
# 32 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_AA.rda
# 33 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_AA.rda
# 34 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_EA.rda
# 35 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_EA.rda
# 36 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_EA.rda
# 37 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_EA.rda
# 38 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_EA.rda
# 39 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_EA.rda
# 40 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_EA.rda
# 41 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_EA.rda
# 42 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_all.rda
# 43 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_all.rda
# 44 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/caud/out/chr3_all.rda
# 45 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_all.rda
# 46 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_all.rda
# 47 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/dlpfc/out/chr3_all.rda
# 48 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_all.rda
# 49 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr3_all.rda
#    last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1  241863783                         10001
# 2  241863783                         10001
# 3  241863783                         10001
# 4  241863783                         10001
# 5  241863783                         10001
# 6  241863783                         10001
# 7  241863783                         10001
# 8  241863783                         10001
# 9  241863783                         10001
# 10 241863783                         10001
# 11 241863783                         10001
# 12 241863783                         10001
# 13 241863783                         10001
# 14 241863783                         10001
# 15 241863783                         10001
# 16 241863783                         10001
# 17 241863783                         10001
# 18 241863783                         10001
# 19 241863783                         10001
# 20 241863783                         10001
# 21 241863783                         10001
# 22 241863783                         10001
# 23 241863783                         10001
# 24 241863783                         10001
# 25 198099789                         11602
# 26 198099789                         11602
# 27 198099789                         11602
# 28 198099789                         11602
# 29 198099789                         11602
# 30 198099789                         11602
# 31 198099789                         11602
# 32 198099789                         11602
# 33 198099789                         11602
# 34 198099789                         11602
# 35 198099789                         11602
# 36 198099789                         11602
# 37 198099789                         11602
# 38 198099789                         11602
# 39 198099789                         11602
# 40 198099789                         11602
# 41 198099789                         11602
# 42 198099789                         11602
# 43 198099789                         11602
# 44 198099789                         11602
# 45 198099789                         11602
# 46 198099789                         11602
# 47 198099789                         11602
# 48 198099789                         11602
# 49 198099789                         11602
#    last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1  2019984                           1
# 2  2019984                           1
# 3  2019984                           1
# 4  2019984                           1
# 5  2019984                           1
# 6  2019984                           1
# 7  2019984                           1
# 8  2019984                           1
# 9  2019984                           1
# 10 2019984                           1
# 11 2019984                           1
# 12 2019984                           1
# 13 2019984                           1
# 14 2019984                           1
# 15 2019984                           1
# 16 2019984                           1
# 17 2019984                           1
# 18 2019984                           1
# 19 2019984                           1
# 20 2019984                           1
# 21 2019984                           1
# 22 2019984                           1
# 23 2019984                           1
# 24 2019984                           1
# 25 1538467                           1
# 26 1538467                           1
# 27 1538467                           1
# 28 1538467                           1
# 29 1538467                           1
# 30 1538467                           1
# 31 1538467                           1
# 32 1538467                           1
# 33 1538467                           1
# 34 1538467                           1
# 35 1538467                           1
# 36 1538467                           1
# 37 1538467                           1
# 38 1538467                           1
# 39 1538467                           1
# 40 1538467                           1
# 41 1538467                           1
# 42 1538467                           1
# 43 1538467                           1
# 44 1538467                           1
# 45 1538467                           1
# 46 1538467                           1
# 47 1538467                           1
# 48 1538467                           1
# 49 1538467                           1
#    cov_file
# 1  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 2  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 3  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 4  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 5  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 6  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 7  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 8  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 9  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 10 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 11 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 12 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 13 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 14 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 15 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 16 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 17 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 18 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 19 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 20 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 21 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 22 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 23 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 24 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 25 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 26 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 27 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv
# 28 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 29 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 30 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_dlpfc.csv
# 31 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 32 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 33 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_hippo.csv
# 34 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 35 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_caud.csv
# 36 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 37 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 38 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_dlpfc.csv
# 39 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 40 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 41 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/EA_hippo.csv
# 42 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 43 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 44 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_caud.csv
# 45 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 46 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 47 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_dlpfc.csv
# 48 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 49 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
#    modified_methylation_data
# 1  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr2_AA_1520001-1540000.rds
# 2  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr2_AA_1520001-1540000.rds
# 3  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_AA_1520001-1540000.rds
# 4  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_AA_1520001-1540000.rds
# 5  /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_AA_1520001-1540000.rds
# 6  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_AA_1520001-1540000.rds
# 7  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_AA_1520001-1540000.rds
# 8  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_AA_1520001-1540000.rds
# 9  /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr2_EA_1520001-1540000.rds
# 10 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr2_EA_1520001-1540000.rds
# 11 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_EA_1520001-1540000.rds
# 12 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_EA_1520001-1540000.rds
# 13 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_EA_1520001-1540000.rds
# 14 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_EA_1520001-1540000.rds
# 15 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_EA_1520001-1540000.rds
# 16 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_EA_1520001-1540000.rds
# 17 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr2_all_1520001-1540000.rds
# 18 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr2_all_1520001-1540000.rds
# 19 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_all_1520001-1540000.rds
# 20 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_all_1520001-1540000.rds
# 21 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr2_all_1520001-1540000.rds
# 22 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1520001-1540000.rds
# 23 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1520001-1540000.rds
# 24 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1520001-1540000.rds
# 25 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_AA_1520001-1538467.rds
# 26 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_AA_1520001-1538467.rds
# 27 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_AA_1520001-1538467.rds
# 28 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_AA_1520001-1538467.rds
# 29 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_AA_1520001-1538467.rds
# 30 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_AA_1520001-1538467.rds
# 31 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_AA_1520001-1538467.rds
# 32 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_AA_1520001-1538467.rds
# 33 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_AA_1520001-1538467.rds
# 34 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_EA_1520001-1538467.rds
# 35 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_EA_1520001-1538467.rds
# 36 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_EA_1520001-1538467.rds
# 37 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_EA_1520001-1538467.rds
# 38 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_EA_1520001-1538467.rds
# 39 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_EA_1520001-1538467.rds
# 40 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_EA_1520001-1538467.rds
# 41 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_EA_1520001-1538467.rds
# 42 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_all_1520001-1538467.rds
# 43 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_all_1520001-1538467.rds
# 44 /dcs04/lieber/statsgen/mnagle/mwas/pheno/caud/out/chr3_all_1520001-1538467.rds
# 45 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_all_1520001-1538467.rds
# 46 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_all_1520001-1538467.rds
# 47 /dcs04/lieber/statsgen/mnagle/mwas/pheno/dlpfc/out/chr3_all_1520001-1538467.rds
# 48 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_all_1520001-1538467.rds
# 49 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr3_all_1520001-1538467.rds
#    path
# 1  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240423-151115.rds
# 2  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-062949.rds
# 3  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240501-144218.rds
# 4  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240513-213318.rds
# 5  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-113916.rds
# 6  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240504-223556.rds
# 7  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-024346.rds
# 8  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-164818.rds
# 9  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240424-044347.rds
# 10 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-095613.rds
# 11 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240507-105631.rds
# 12 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-010025.rds
# 13 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-150515.rds
# 14 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240508-093048.rds
# 15 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-061305.rds
# 16 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-201409.rds
# 17 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240423-215724.rds
# 18 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-081258.rds
# 19 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240502-120941.rds
# 20 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240513-231708.rds
# 21 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-132214.rds
# 22 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240505-001208.rds
# 23 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-042942.rds
# 24 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-183113.rds
# 25 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240502-211556.rds
# 26 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-133040.rds
# 27 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-caud-20240512-032813.rds
# 28 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240505-032935.rds
# 29 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-173940.rds
# 30 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-172628.rds
# 31 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240508-113815.rds
# 32 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-213549.rds
# 33 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-212206.rds
# 34 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240503-022733.rds
# 35 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-162009.rds
# 36 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240507-120520.rds
# 37 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-201708.rds
# 38 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-200325.rds
# 39 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240508-135311.rds
# 40 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240514-001307.rds
# 41 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-235932.rds
# 42 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240502-235142.rds
# 43 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-145555.rds
# 44 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-caud-20240512-044649.rds
# 45 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240505-044420.rds
# 46 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-185830.rds
# 47 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-184457.rds
# 48 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-225428.rds
# 49 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-224057.rds
#    stage2_paths
# 1  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240423-151115_gwas_stat_
# 2  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-062949_gwas_stat_
# 3  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240501-144218_gwas_stat_
# 4  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240513-213318_gwas_stat_
# 5  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-113916_gwas_stat_
# 6  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240504-223556_gwas_stat_
# 7  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-024346_gwas_stat_
# 8  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-164818_gwas_stat_
# 9  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240424-044347_gwas_stat_
# 10 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-095613_gwas_stat_
# 11 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240507-105631_gwas_stat_
# 12 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-010025_gwas_stat_
# 13 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-150515_gwas_stat_
# 14 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240508-093048_gwas_stat_
# 15 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-061305_gwas_stat_
# 16 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-201409_gwas_stat_
# 17 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240423-215724_gwas_stat_
# 18 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-081258_gwas_stat_
# 19 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240502-120941_gwas_stat_
# 20 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240513-231708_gwas_stat_
# 21 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-132214_gwas_stat_
# 22 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240505-001208_gwas_stat_
# 23 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-042942_gwas_stat_
# 24 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-183113_gwas_stat_
# 25 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240502-211556_gwas_stat_
# 26 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-133040_gwas_stat_
# 27 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-caud-20240512-032813_gwas_stat_
# 28 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240505-032935_gwas_stat_
# 29 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-173940_gwas_stat_
# 30 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-172628_gwas_stat_
# 31 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240508-113815_gwas_stat_
# 32 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-213549_gwas_stat_
# 33 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-212206_gwas_stat_
# 34 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240503-022733_gwas_stat_
# 35 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-162009_gwas_stat_
# 36 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240507-120520_gwas_stat_
# 37 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-201708_gwas_stat_
# 38 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-200325_gwas_stat_
# 39 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240508-135311_gwas_stat_
# 40 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240514-001307_gwas_stat_
# 41 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-235932_gwas_stat_
# 42 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240502-235142_gwas_stat_
# 43 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-145555_gwas_stat_
# 44 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-caud-20240512-044649_gwas_stat_
# 45 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240505-044420_gwas_stat_
# 46 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-185830_gwas_stat_
# 47 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-184457_gwas_stat_
# 48 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-225428_gwas_stat_
# 49 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-224057_gwas_stat_
#    final_paths
# 1  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240423-151115_gwas_stat_scz_results.rds
# 2  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-062949_gwas_stat_scz_results.rds
# 3  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240501-144218_gwas_stat_scz_results.rds
# 4  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240513-213318_gwas_stat_scz_results.rds
# 5  ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-113916_gwas_stat_scz_results.rds
# 6  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240504-223556_gwas_stat_scz_results.rds
# 7  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-024346_gwas_stat_scz_results.rds
# 8  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_AA-libd_chr2-chr2_AA-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-164818_gwas_stat_scz_results.rds
# 9  ..//output_EXPANSE_a2_caud/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240424-044347_gwas_stat_scz_results.rds
# 10 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-095613_gwas_stat_scz_results.rds
# 11 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240507-105631_gwas_stat_scz_results.rds
# 12 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-010025_gwas_stat_scz_results.rds
# 13 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-150515_gwas_stat_scz_results.rds
# 14 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240508-093048_gwas_stat_scz_results.rds
# 15 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-061305_gwas_stat_scz_results.rds
# 16 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_EA-libd_chr2-chr2_EA-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-201409_gwas_stat_scz_results.rds
# 17 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240423-215724_gwas_stat_scz_results.rds
# 18 ..//output_EXPANSE_a2_caud/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-caud-20240511-081258_gwas_stat_scz_results.rds
# 19 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240502-120941_gwas_stat_scz_results.rds
# 20 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240513-231708_gwas_stat_scz_results.rds
# 21 ..//output_EXPANSE_a2_dlpfc/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-dlpfc-20240511-132214_gwas_stat_scz_results.rds
# 22 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240505-001208_gwas_stat_scz_results.rds
# 23 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-20240514-042942_gwas_stat_scz_results.rds
# 24 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1520001-1540000-dynamic-1corestotal-allcorepera-hippo-20240511-183113_gwas_stat_scz_results.rds
# 25 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240502-211556_gwas_stat_scz_results.rds
# 26 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-133040_gwas_stat_scz_results.rds
# 27 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-caud-20240512-032813_gwas_stat_scz_results.rds
# 28 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240505-032935_gwas_stat_scz_results.rds
# 29 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-173940_gwas_stat_scz_results.rds
# 30 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-172628_gwas_stat_scz_results.rds
# 31 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240508-113815_gwas_stat_scz_results.rds
# 32 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-213549_gwas_stat_scz_results.rds
# 33 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_AA-libd_chr3-chr3_AA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-212206_gwas_stat_scz_results.rds
# 34 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240503-022733_gwas_stat_scz_results.rds
# 35 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-162009_gwas_stat_scz_results.rds
# 36 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240507-120520_gwas_stat_scz_results.rds
# 37 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-201708_gwas_stat_scz_results.rds
# 38 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-200325_gwas_stat_scz_results.rds
# 39 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240508-135311_gwas_stat_scz_results.rds
# 40 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240514-001307_gwas_stat_scz_results.rds
# 41 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_EA-libd_chr3-chr3_EA-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-235932_gwas_stat_scz_results.rds
# 42 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240502-235142_gwas_stat_scz_results.rds
# 43 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-145555_gwas_stat_scz_results.rds
# 44 ..//output_EXPANSE_a2_caud/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-caud-20240512-044649_gwas_stat_scz_results.rds
# 45 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240505-044420_gwas_stat_scz_results.rds
# 46 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-185830_gwas_stat_scz_results.rds
# 47 ..//output_EXPANSE_a2_dlpfc/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-184457_gwas_stat_scz_results.rds
# 48 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240513-225428_gwas_stat_scz_results.rds
# 49 ..//output_EXPANSE_a2_hippo/libd_chr3-chr3_all-libd_chr3-chr3_all-1520001-1538467-dynamic-1corestotal-allcorepera-20240516-224057_gwas_stat_scz_results.rds
#    exists
# 1  TRUE
# 2  TRUE
# 3  TRUE
# 4  TRUE
# 5  TRUE
# 6  TRUE
# 7  TRUE
# 8  TRUE
# 9  TRUE
# 10 TRUE
# 11 TRUE
# 12 TRUE
# 13 TRUE
# 14 TRUE
# 15 TRUE
# 16 TRUE
# 17 TRUE
# 18 TRUE
# 19 TRUE
# 20 TRUE
# 21 TRUE
# 22 TRUE
# 23 TRUE
# 24 TRUE
# 25 TRUE
# 26 TRUE
# 27 TRUE
# 28 TRUE
# 29 TRUE
# 30 TRUE
# 31 TRUE
# 32 TRUE
# 33 TRUE
# 34 TRUE
# 35 TRUE
# 36 TRUE
# 37 TRUE
# 38 TRUE
# 39 TRUE
# 40 TRUE
# 41 TRUE
# 42 TRUE
# 43 TRUE
# 44 TRUE
# 45 TRUE
# 46 TRUE
# 47 TRUE
# 48 TRUE
# 49 TRUE

# %%
df_not_empty_rds_due_to_no_snps_in_window[!df_not_empty_rds_due_to_no_snps_in_window$exists, ]
# Out:
#    Chr population region chunk_start chunk_end
# 1  2   all        hippo  1940001     1960000
# 2  2   all        hippo  1940001     1960000
# 3  2   all        hippo  1960001     1980000
# 4  2   all        hippo  1960001     1980000
# 5  2   all        hippo  1960001     1980000
# 6  2   all        hippo  1980001     2000000
# 7  2   all        hippo  1980001     2000000
# 8  2   all        hippo  1980001     2000000
# 9  2   all        hippo  2000001     2019984
# 10 2   all        hippo  2000001     2019984
# 11 2   all        hippo  2000001     2019984
#    SNP_data
# 1  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 2  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 3  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 4  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 5  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 6  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 7  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 8  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 9  /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 10 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
# 11 /dcs04/lieber/statsgen/shizhong/michael/mwas/gwas//libd_chr2.pgen
#    methylation_data
# 1  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 2  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 3  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 4  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 5  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 6  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 7  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 8  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 9  /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 10 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
# 11 /dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/hippo/out/chr2_all.rda
#    last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1  241863783                         10001
# 2  241863783                         10001
# 3  241863783                         10001
# 4  241863783                         10001
# 5  241863783                         10001
# 6  241863783                         10001
# 7  241863783                         10001
# 8  241863783                         10001
# 9  241863783                         10001
# 10 241863783                         10001
# 11 241863783                         10001
#    last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1  2019984                           1
# 2  2019984                           1
# 3  2019984                           1
# 4  2019984                           1
# 5  2019984                           1
# 6  2019984                           1
# 7  2019984                           1
# 8  2019984                           1
# 9  2019984                           1
# 10 2019984                           1
# 11 2019984                           1
#    cov_file
# 1  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 2  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 3  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 4  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 5  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 6  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 7  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 8  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 9  /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 10 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
# 11 /dcs04/lieber/statsgen/mnagle/mwas/full_covariates/all_hippo.csv
#    modified_methylation_data
# 1  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1940001-1960000.rds
# 2  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1940001-1960000.rds
# 3  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1960001-1980000.rds
# 4  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1960001-1980000.rds
# 5  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1960001-1980000.rds
# 6  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1980001-2e+06.rds
# 7  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1980001-2e+06.rds
# 8  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_1980001-2e+06.rds
# 9  /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_2000001-2019984.rds
# 10 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_2000001-2019984.rds
# 11 /dcs04/lieber/statsgen/mnagle/mwas/pheno/hippo/out/chr2_all_2000001-2019984.rds
#    path
# 1  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1940001-1960000-dynamic-1corestotal-allcorepera-20240514-045111.rds
# 2  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1940001-1960000-dynamic-1corestotal-allcorepera-hippo-20240511-185237.rds
# 3  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-20240505-003448.rds
# 4  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-20240514-045212.rds
# 5  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-hippo-20240511-185338.rds
# 6  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-20240505-003549.rds
# 7  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-20240514-045315.rds
# 8  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-hippo-20240511-185439.rds
# 9  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-20240505-003652.rds
# 10 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-20240514-045416.rds
# 11 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-hippo-20240511-185540.rds
#    stage2_paths
# 1  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1940001-1960000-dynamic-1corestotal-allcorepera-20240514-045111_gwas_stat_
# 2  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1940001-1960000-dynamic-1corestotal-allcorepera-hippo-20240511-185237_gwas_stat_
# 3  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-20240505-003448_gwas_stat_
# 4  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-20240514-045212_gwas_stat_
# 5  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-hippo-20240511-185338_gwas_stat_
# 6  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-20240505-003549_gwas_stat_
# 7  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-20240514-045315_gwas_stat_
# 8  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-hippo-20240511-185439_gwas_stat_
# 9  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-20240505-003652_gwas_stat_
# 10 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-20240514-045416_gwas_stat_
# 11 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-hippo-20240511-185540_gwas_stat_
#    final_paths
# 1  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1940001-1960000-dynamic-1corestotal-allcorepera-20240514-045111_gwas_stat_scz_results.rds
# 2  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1940001-1960000-dynamic-1corestotal-allcorepera-hippo-20240511-185237_gwas_stat_scz_results.rds
# 3  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-20240505-003448_gwas_stat_scz_results.rds
# 4  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-20240514-045212_gwas_stat_scz_results.rds
# 5  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1960001-1980000-dynamic-1corestotal-allcorepera-hippo-20240511-185338_gwas_stat_scz_results.rds
# 6  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-20240505-003549_gwas_stat_scz_results.rds
# 7  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-20240514-045315_gwas_stat_scz_results.rds
# 8  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-1980001-2000000-dynamic-1corestotal-allcorepera-hippo-20240511-185439_gwas_stat_scz_results.rds
# 9  ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-20240505-003652_gwas_stat_scz_results.rds
# 10 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-20240514-045416_gwas_stat_scz_results.rds
# 11 ..//output_EXPANSE_a2_hippo/libd_chr2-chr2_all-libd_chr2-chr2_all-2000001-2019984-dynamic-1corestotal-allcorepera-hippo-20240511-185540_gwas_stat_scz_results.rds
#    exists
# 1  FALSE
# 2  FALSE
# 3  FALSE
# 4  FALSE
# 5  FALSE
# 6  FALSE
# 7  FALSE
# 8  FALSE
# 9  FALSE
# 10 FALSE
# 11 FALSE

# %%
getwd()
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts"

# %% [markdown]
# ## Checking logs etc

# %%
# Function to check for errors in the log file
check_log_for_errors <- function(log_path) {
  log_contents <- readLines(log_path)
  errors <- grep("error|stop|interrupted", tolower(log_contents), value = TRUE)
  if (length(errors) > 0) {
    return(list(success = FALSE, messages = errors))
  }
  return(list(success = TRUE))
}

# Usage
log_result <- check_log_for_errors("processing_log.txt")
if (log_result$success) {
  cat("No errors found in log.\n")
} else {
  cat("Errors found in log:\n", paste(log_result$messages, collapse = "\n"))
}
# Out:
# No errors found in log.

# %%
library(data.table)

# %%
# SLOW Function to validate output files
validate_output_files <- function(trait_names, output_path_template) {
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      cat(sprintf("Output file for %s does not exist.\n", trait))
      next
    }
    dt <- fread(file_path)
    if (nrow(dt) == 0) {
      cat(sprintf("Output file for %s is empty.\n", trait))
    } else {
      cat(sprintf("Output file for %s has %d rows.\n", trait, nrow(dt)))
    }
  }
}

# Usage
#validate_output_files(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")

# %%
# Function to check if output files exist and are not empty
check_output_files_existence_and_size <- function(trait_names, output_path_template) {
  results <- list()
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      results[[trait]] <- sprintf("Output file for %s does not exist.", trait)
    } else {
      file_size <- file.info(file_path)$size
      if (file_size > 0) {
        results[[trait]] <- sprintf("Output file for %s is valid with size %d bytes.", trait, file_size)
      } else {
        results[[trait]] <- sprintf("Output file for %s exists but is empty.", trait)
      }
    }
  }
  return(results)
}

# Usage
file_check_results <- check_output_files_existence_and_size(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")
for (result in file_check_results) {
  cat(result, "\n")
}
# Out:
# Error in sprintf("Output file for %s is valid with size %d bytes.", trait, : invalid format '%d'; use format %f, %e, %g or %a for numeric objects
# Traceback:
#
# 1. check_output_files_existence_and_size(c("bp", "mdd", "scz"),
#  .     "16a5-OUT_stage2_MWAS_%s.csv")
# 2. sprintf("Output file for %s is valid with size %d bytes.", trait,
#  .     file_size)   # at line 11 of file <text>

# %%
# Function to check if output files exist and are not empty
check_output_files_existence_and_size <- function(trait_names, output_path_template) {
  results <- list()
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      results[[trait]] <- sprintf("Output file for %s does not exist.", trait)
    } else {
      file_size <- as.integer(file.info(file_path)$size)  # Ensure integer format
      if (file_size > 0) {
        results[[trait]] <- sprintf("Output file for %s is valid with size %d bytes.", trait, file_size)
      } else {
        results[[trait]] <- sprintf("Output file for %s exists but is empty.", trait)
      }
    }
  }
  return(results)
}

# Usage
file_check_results <- check_output_files_existence_and_size(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")
for (result in file_check_results) {
  cat(result, "\n")
}
# Out:
# Warning message in check_output_files_existence_and_size(c("bp", "mdd", "scz"), :
# “NAs introduced by coercion to integer range”
# Error in if (file_size > 0) {: missing value where TRUE/FALSE needed
# Traceback:
#
# 1. check_output_files_existence_and_size(c("bp", "mdd", "scz"),
#  .     "16a5-OUT_stage2_MWAS_%s.csv")

# %%
# Function to check if output files exist and are not empty
check_output_files_existence_and_size <- function(trait_names, output_path_template) {
  results <- list()
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      results[[trait]] <- sprintf("Output file for %s does not exist.", trait)
    } else {
      file_size <- file.info(file_path)$size  # Get the file size without casting
      if (!is.na(file_size) && file_size > 0) {
        results[[trait]] <- sprintf("Output file for %s is valid with size %f bytes.", trait, file_size)
      } else if (is.na(file_size)) {
        results[[trait]] <- sprintf("Error retrieving file size for %s.", trait)
      } else {
        results[[trait]] <- sprintf("Output file for %s exists but is empty.", trait)
      }
    }
  }
  return(results)
}

# Usage
file_check_results <- check_output_files_existence_and_size(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")
for (result in file_check_results) {
  cat(result, "\n")
}
# Out:
# Output file for bp is valid with size 16912150884.000000 bytes.
# Output file for mdd does not exist.
# Output file for scz does not exist.

# %% [markdown]
# ## Second attempt

# %%
library(data.table)
library(ggplot2)

# Initialize logging
log_file <- file("processing_log.txt", open = "wt")
sink(log_file, type = "message")
sink(log_file, type = "output", append = TRUE)

tryCatch({
    traits <- c("bp", "mdd", "scz")
    df$stage2_paths <- gsub(".rds", "_gwas_stat_", df$path)
    df$final_paths <- vector("list", length(df$stage2_paths))

    for (trait in traits) {
        message("Processing trait: ", trait)
        df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
        output_file <- paste0("16a6-OUT_stage2_MWAS_", trait, ".csv")
        header_written <- FALSE

        for (i in seq_along(df$final_paths)) {
            if (grepl("empty", df$final_paths[i])) next
            
            message("Processing file ", i, " of ", length(df$final_paths))
            stage2_in <- readRDS(df$final_paths[i])
            stage1_in <- readRDS(df$path[i])
            
            if (length(stage1_in@models) != length(stage2_in@MWASmodels)) {
                stop("Files don't match")
            }

            data_list <- vector("list", length(stage1_in@models))
            for (j in seq_along(stage1_in@models)) {
                model1 <- stage1_in@models[[j]]
                model2 <- stage2_in@MWASmodels[[j]]

                data_list[[j]] <- data.table(
                    z = model2["z"],
                    p = model2["p"],
                    n = model2["n"],
                    pos = model1@methylationPosition,
                    stats = stage2_in@summary_stats_path,
                    scaff = stage1_in@scaffoldIdentifier
                )
            }

            combined_data <- rbindlist(data_list, use.names = TRUE, fill = TRUE)

            # Write data incrementally
            if (!header_written) {
                fwrite(combined_data, output_file)
                header_written <- TRUE
            } else {
                fwrite(combined_data, output_file, append = TRUE)
            }
        }
    }
}, error = function(e) {
    message("An error occurred: ", e$message)
}, finally = {
    sink(NULL)  # Turn off logging
    close(log_file)
    message("Logging ended.")
})
# Out:
# An error occurred: object of type 'closure' is not subsettable
# Error in close.connection(log_file): cannot close 'message' sink connection
# Traceback:
#
# 1. tryCatch({
#  .     traits <- c("bp", "mdd", "scz")
#  .     df$stage2_paths <- gsub(".rds", "_gwas_stat_", df$path)
#  .     df$final_paths <- vector("list", length(df$stage2_paths))
#  .     for (trait in traits) {
#  .         message("Processing trait: ", trait)
#  .         df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
#  .         output_file <- paste0("16a6-OUT_stage2_MWAS_", trait,
#  .             ".csv")
#  .         header_written <- FALSE
#  .         for (i in seq_along(df$final_paths)) {
#  .             if (grepl("empty", df$final_paths[i]))
#  .                 next
#  .             message("Processing file ", i, " of ", length(df$final_paths))
#  .             stage2_in <- readRDS(df$final_paths[i])
#  .             stage1_in <- readRDS(df$path[i])
#  .             if (length(stage1_in@models) != length(stage2_in@MWASmodels)) {
#  .                 stop("Files don't match")
#  .             }
#  .             data_list <- vector("list", length(stage1_in@models))
#  .             for (j in seq_along(stage1_in@models)) {
#  .                 model1 <- stage1_in@models[[j]]
#  .                 model2 <- stage2_in@MWASmodels[[j]]
#  .                 data_list[[j]] <- data.table(z = model2["z"],
#  .                   p = model2["p"], n = model2["n"], pos = model1@methylationPosition,
#  .                   stats = stage2_in@summary_stats_path, scaff = stage1_in@scaffoldIdentifier)
#  .             }
#  .             combined_data <- rbindlist(data_list, use.names = TRUE,
#  .                 fill = TRUE)
#  .             if (!header_written) {
#  .                 fwrite(combined_data, output_file)
#  .                 header_written <- TRUE
#  .             }
#  .             else {
#  .                 fwrite(combined_data, output_file, append = TRUE)
#  .             }
#  .         }
#  .     }
#  . }, error = function(e) {
#  .     message("An error occurred: ", e$message)
#  . }, finally = {
#  .     sink(NULL)
#  .     close(log_file)
#  .     message("Logging ended.")
#  . })
# 2. close(log_file)   # at line 61 of file <text>
# 3. close.connection(log_file)
