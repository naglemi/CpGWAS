# %% [markdown]
# # Check which window_size, alpha parameters tend to give best R^2

# %%
library(CpGWAS)

# %%
# Assume scaff_paths is already defined and contains full paths to the files
scaff_paths <- list.files("../output/", pattern = "rds", full.names = TRUE)

# Define a simplified function to extract date and time directly into the data frame creation step
extract_info <- function(path) {
  # Extract date and time based on the filename pattern
  matches <- regmatches(path, regexpr("\\d{8}-\\d{6}", path))
  if (length(matches) > 0) {
    datetime <- strsplit(matches, "-")[[1]]
    date <- paste(substr(datetime[1], 1, 4), substr(datetime[1], 5, 6), substr(datetime[1], 7, 8), sep="-")
    time <- paste(substr(datetime[2], 1, 2), substr(datetime[2], 3, 4), substr(datetime[2], 5, 6), sep=":")
    return(c(date, time))
  } else {
    return(c(NA, NA)) # Provide a fallback in case of no match
  }
}

# Create the data frame by applying the function and combining the results
data_frame <- do.call(rbind, lapply(scaff_paths, function(path) {
  info <- extract_info(path)
  data.frame(path = path, date = info[1], time = info[2], stringsAsFactors = FALSE)
}))

# Sort the data frame by date and then by time
sorted_data_frame <- data_frame[order(data_frame$date, data_frame$time), ]

# Print the first few rows of the sorted data frame to check
head(sorted_data_frame)
# Out:
#   path
# 5 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-1corestotal-1corepera-20240131-122515.rds
# 7 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-1corestotal-allcorepera-20240131-122517.rds
# 8 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-8corestotal-allcorepera-20240131-122518.rds
# 1 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-1corestotal-1corepera-20240131-122519.rds
# 3 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-1corestotal-allcorepera-20240131-122521.rds
# 4 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-8corestotal-allcorepera-20240131-122522.rds
#   date       time
# 5 2024-01-31 12:25:15
# 7 2024-01-31 12:25:17
# 8 2024-01-31 12:25:18
# 1 2024-01-31 12:25:19
# 3 2024-01-31 12:25:21
# 4 2024-01-31 12:25:22

# %%
sorted_data_frame
# Out:
#    path
# 5  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-1corestotal-1corepera-20240131-122515.rds
# 7  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-1corestotal-allcorepera-20240131-122517.rds
# 8  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-8corestotal-allcorepera-20240131-122518.rds
# 1  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-1corestotal-1corepera-20240131-122519.rds
# 3  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-1corestotal-allcorepera-20240131-122521.rds
# 4  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-8corestotal-allcorepera-20240131-122522.rds
# 6  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-static-1corestotal-1corepera-20240201-121736.rds
# 2  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1000000-1001000-dynamic-1corestotal-1corepera-20240201-121737.rds
# 9  ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1001000-1001999-static-1corestotal-1corepera-20240201-164244.rds
# 10 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1004000-1004999-static-1corestotal-1corepera-20240201-164247.rds
# 11 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1005000-1005999-static-1corestotal-1corepera-20240201-164248.rds
# 12 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-dynamic-1corestotal-1corepera-20240205-120121.rds
# 19 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-dynamic-1corestotal-1corepera-20240205-120122.rds
# 26 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-dynamic-1corestotal-1corepera-20240205-120123.rds
# 13 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-dynamic-1corestotal-1corepera-20240205-120214.rds
# 16 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-static-1corestotal-1corepera-20240205-120215.rds
# 20 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-dynamic-1corestotal-1corepera-20240205-120218.rds
# 23 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-static-1corestotal-1corepera-20240205-120219.rds
# 27 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-dynamic-1corestotal-1corepera-20240205-120220.rds
# 30 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-static-1corestotal-1corepera-20240205-120221.rds
# 14 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-dynamic-1corestotal-1corepera-20240205-120236.rds
# 17 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-static-1corestotal-1corepera-20240205-120237.rds
# 21 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-dynamic-1corestotal-1corepera-20240205-120238.rds
# 24 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-static-1corestotal-1corepera-20240205-120240.rds
# 28 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-dynamic-1corestotal-1corepera-20240205-120241.rds
# 31 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-static-1corestotal-1corepera-20240205-120242.rds
# 18 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-static-1corestotal-1corepera-20240205-120316.rds
# 25 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-static-1corestotal-1corepera-20240205-120317.rds
# 32 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-static-1corestotal-1corepera-20240205-120318.rds
# 15 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1006000-1006999-dynamic-1corestotal-1corepera-20240205-165208.rds
# 22 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1007000-1007999-dynamic-1corestotal-1corepera-20240205-165209.rds
# 29 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1008000-1008999-dynamic-1corestotal-1corepera-20240205-165210.rds
# 33 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1009000-1009999-dynamic-1corestotal-1corepera-20240205-165815.rds
# 34 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1010000-1010999-dynamic-1corestotal-1corepera-20240205-165816.rds
# 36 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1011000-1011999-dynamic-1corestotal-1corepera-20240205-165817.rds
# 35 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1010000-1010999-dynamic-1corestotal-1corepera-20240208-104421.rds
# 37 ../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1011000-1011999-dynamic-1corestotal-1corepera-20240208-104422.rds
#    date       time
# 5  2024-01-31 12:25:15
# 7  2024-01-31 12:25:17
# 8  2024-01-31 12:25:18
# 1  2024-01-31 12:25:19
# 3  2024-01-31 12:25:21
# 4  2024-01-31 12:25:22
# 6  2024-02-01 12:17:36
# 2  2024-02-01 12:17:37
# 9  2024-02-01 16:42:44
# 10 2024-02-01 16:42:47
# 11 2024-02-01 16:42:48
# 12 2024-02-05 12:01:21
# 19 2024-02-05 12:01:22
# 26 2024-02-05 12:01:23
# 13 2024-02-05 12:02:14
# 16 2024-02-05 12:02:15
# 20 2024-02-05 12:02:18
# 23 2024-02-05 12:02:19
# 27 2024-02-05 12:02:20
# 30 2024-02-05 12:02:21
# 14 2024-02-05 12:02:36
# 17 2024-02-05 12:02:37
# 21 2024-02-05 12:02:38
# 24 2024-02-05 12:02:40
# 28 2024-02-05 12:02:41
# 31 2024-02-05 12:02:42
# 18 2024-02-05 12:03:16
# 25 2024-02-05 12:03:17
# 32 2024-02-05 12:03:18
# 15 2024-02-05 16:52:08
# 22 2024-02-05 16:52:09
# 29 2024-02-05 16:52:10
# 33 2024-02-05 16:58:15
# 34 2024-02-05 16:58:16
# 36 2024-02-05 16:58:17
# 35 2024-02-08 10:44:21
# 37 2024-02-08 10:44:22

# %%
scaff_paths <- sorted_data_frame$path[36:37]

# %%
scaff_paths
# Out:
# [1] "../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1010000-1010999-dynamic-1corestotal-1corepera-20240208-104421.rds"
# [2] "../output//libd_chr1-chr1_AA-libd_chr1-chr1_AA-1011000-1011999-dynamic-1corestotal-1corepera-20240208-104422.rds"

# %%
convertToDataFrame <- function(object) {
  if (!inherits(object, "MethylationScaff")) {
    stop("The object must be of class 'MethylationScaff'.")
  }

  modelsList <- lapply(object@models, function(model) {
    data.frame(
      scaffoldIdentifier = object@scaffoldIdentifier,  # Scaffold identifier is the same for all models
      methylationPosition = model@methylationPosition,
      windowSize = model@windowSize,
      nSNPs = model@n_SNPs,
      cor = model@evaluation_results['cor'],
      mse = model@evaluation_results['mse'],
      alpha = model@alpha,
      lambda = model@lambda
    )
  })

  do.call("rbind", modelsList)
}

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df <- data.frame()

# %%
for(scaff_path in scaff_paths){
    my_scaff <- readRDS(scaff_path)
    small_df <- convertToDataFrame(my_scaff)
    df <- bind_rows(df, small_df)
}

# %%
dim(df)
# Out:
# [1] 16975     8

# %%
length(levels(factor(df$methylationPosition)))
# Out:
# [1] 2000

# %%
dim(df)[1]/(8*5)
# Out:
# [1] 424.375

# %% [markdown]
# What percentage of models have all coefficients dropped during regularization?

# %%
sum(is.na(df$cor))/dim(df)[1]
# Out:
# [1] 0.004889543

# %% [markdown]
# What if we limit to the best model for each positions?

# %% [markdown]
# ## Which alpha, window_size tend to give most `NA`?

# %% [markdown]
# We get `NA` values for cor when all SNPs are dropped during regularization.

# %%
library(dplyr)
library(ggplot2)

# For alpha
na_percentage_alpha <- df %>%
  group_by(alpha) %>%
  summarise(PercentageNA = mean(is.na(cor)) * 100)

# For windowSize
na_percentage_windowSize <- df %>%
  group_by(windowSize) %>%
  summarise(PercentageNA = mean(is.na(cor)) * 100)

# %%
ggplot(na_percentage_alpha, aes(x = as.factor(alpha), y = PercentageNA)) +
  geom_bar(stat = "identity", fill = "skyblue") +
  geom_text(aes(label = sprintf("%.2f%%", PercentageNA)), vjust = -0.5) +
  theme_minimal() +
  labs(title = "Percentage of sites with NA R by alpha\nChr1:1010000-1011999", x = "alpha", y = "Percentage of NA") +
  theme(
    text = element_text(size = 20),  # Global text size
    plot.title = element_text(size = 22),  # Title size
    axis.title = element_text(size = 20),  # Axis titles size
    axis.text = element_text(size = 18)  # Axis text size
  )
# Out:
# plot without title

# %%
ggplot(na_percentage_windowSize, aes(x = as.factor(windowSize), y = PercentageNA)) +
  geom_bar(stat = "identity", fill = "lightgreen") +
  geom_text(aes(label = sprintf("%.2f%%", PercentageNA)), vjust = -0.5) +
  theme_minimal() +
  labs(title = "Percentage of sites with NA R by window size\nChr1:1010000-1011999", x = "Window Size", y = "Percentage of NA") +
  theme(
    text = element_text(size = 20),  # Global text size
    plot.title = element_text(size = 22),  # Title size
    axis.title = element_text(size = 20),  # Axis titles size
    axis.text.x = element_text(angle = 45, hjust = 1, size = 18)  # Rotate x-axis text and adjust size
  )
# Out:
# plot without title

# %% [markdown]
# ## See which have best `alpha`, `window_size` tend to give best R^2 (`cor1`)

# %%
library(dplyr)

# Assuming your data frame is named df
# filtered_df <- df %>%
#   filter(!is.na(cor)) %>%
#   group_by(methylationPosition) %>%
#   slice(which.max(cor))

# %%
filtered_df <- df

# %% [markdown]
# Which have NA for all?

# %%
na_positions <- df %>%
  group_by(methylationPosition) %>%
  filter(all(is.na(cor))) %>%
  summarise() %>%
  pull(methylationPosition)

# %%
length(na_positions)
# Out:
# [1] 0

# %%
na_positions_df <- df %>%
  filter(methylationPosition %in% na_positions)

# %%
na_positions
# Out:
# integer(0)

# %%
library(ggplot2)

ggplot(filtered_df, aes(x = as.factor(alpha), y = cor)) +
  geom_boxplot() +
  geom_jitter(width = 0.2, alpha = 0.05) +
  theme_minimal() +
  labs(title = "Correlation (R) by Alpha\nChr1:1010000-1011999", x = "Alpha", y = "Correlation (R)") +
  scale_y_continuous(breaks = seq(floor(min(filtered_df$cor, na.rm = TRUE)), ceiling(max(filtered_df$cor, na.rm = TRUE)), by = 0.1)) +  # Add y-axis breaks every 0.1
  theme(
    text = element_text(size = 20),  # Global text size
    plot.title = element_text(size = 22),  # Title size
    axis.title = element_text(size = 20),  # Axis titles size
    axis.text.x = element_text(angle = 45, hjust = 1, size = 18)  # Rotate x-axis text and adjust size
  )
# Out:
# Warning message:
# “Removed 83 rows containing non-finite values (`stat_boxplot()`).”
# Warning message:
# “Removed 83 rows containing missing values (`geom_point()`).”
# plot without title

# %%
library(ggplot2)

# Base plot with boxplot and jitter
p <- ggplot(filtered_df, aes(x = as.factor(alpha), y = cor)) +
  geom_boxplot() +
  geom_jitter(width = 0.2, alpha = 0.05) +
  geom_violin(fill = "skyblue", alpha = 0.3) +  # Add a violin plot for density
  theme_minimal() +
  labs(title = "Correlation (R) by Alpha\nChr1:1010000-1011999", x = "Alpha", y = "Correlation (R)") +
  scale_y_continuous(breaks = seq(floor(min(filtered_df$cor, na.rm = TRUE)), ceiling(max(filtered_df$cor, na.rm = TRUE)), by = 0.1)) +
  theme(
    text = element_text(size = 20),
    plot.title = element_text(size = 22),
    axis.title = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 18)
  )

# Print the plot
print(p)
# Out:
# Warning message:
# “Removed 83 rows containing non-finite values (`stat_boxplot()`).”
# Warning message:
# “Removed 83 rows containing non-finite values (`stat_ydensity()`).”
# Warning message:
# “Removed 83 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(filtered_df, aes(x = as.factor(windowSize), y = cor)) +
  geom_boxplot() +
  geom_jitter(width = 0.2, alpha = 0.05) +
  theme_minimal() +
  geom_violin(fill = "skyblue", alpha = 0.3) +  # Add a violin plot for density
  labs(title = "Correlation (R) by Window Size\nChr1:1010000-1011999", x = "Window Size", y = "Correlation (R)") +
  scale_y_continuous(breaks = seq(floor(min(filtered_df$cor, na.rm = TRUE)), ceiling(max(filtered_df$cor, na.rm = TRUE)), by = 0.1)) +  # Add y-axis breaks every 0.1
  theme(
    text = element_text(size = 20),  # Global text size
    plot.title = element_text(size = 22),  # Title size
    axis.title = element_text(size = 20),  # Axis titles size
    axis.text.x = element_text(angle = 45, hjust = 1, size = 18)  # Rotate x-axis text and adjust size
  )
# Out:
# Warning message:
# “Removed 83 rows containing non-finite values (`stat_boxplot()`).”
# Warning message:
# “Removed 83 rows containing non-finite values (`stat_ydensity()`).”
# Warning message:
# “Removed 83 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# What's highest cor value?

# %%
max(na.omit(filtered_df$cor))
# Out:
# [1] 0.788785

# %% [markdown]
# How many have this value?

# %%
dim(filtered_df[which(filtered_df$cor == max(na.omit(filtered_df$cor))), ])
# Out:
# [1] 1 8

# %% [markdown]
# What percentage of non-NA R sites have unique values for R?

# %%
length(unique(filtered_df$cor)) / length(na.omit(filtered_df$cor))
# Out:
# [1] 1.000059

# %%
library(ggplot2)

# Assuming filtered_df has 'alpha', 'windowSize', and 'cor' columns
# Create a new interaction factor representing combinations of alpha and windowSize
filtered_df$alpha_windowSize <- interaction(filtered_df$alpha, filtered_df$windowSize, sep = "-")

# Plot
ggplot(filtered_df, aes(x = cor)) +  # Use cor as x since we're doing a density plot
  geom_density(aes(fill = factor(alpha_windowSize)), alpha = 0.5) +  # Density plot for each combination
  facet_wrap(~alpha_windowSize, scales = "free_x") +  # Facet by the new interaction factor
  theme_minimal() +
  labs(title = "Density of Correlation (R) by Alpha and Window Size",
       x = "Correlation (R)", y = "Density") +
  theme(
    text = element_text(size = 14),
    plot.title = element_text(size = 16),
    axis.title = element_text(size = 14),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 12),
    strip.text.x = element_text(size = 12)  # Adjust facet label size
  )
# Out:
# Warning message:
# “Removed 83 rows containing non-finite values (`stat_density()`).”
# plot without title
