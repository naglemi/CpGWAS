# %% [markdown]
# # Split `BSseq` objects into chunks to save memory

# %%
library(data.table)

# %%
df <- fread("09-OUT_matched_SNP_meth_cov.csv")

# %%
#' Generate Chunk Ranges with Fixed Number of Chunks
#'
#' This function divides a range into a specified number of chunks, with each chunk
#' having approximately the same size.
#'
#' @param start The starting point of the range to be divided.
#' @param end The ending point of the range to be divided.
#' @param num_chunks The fixed number of chunks to divide the range into.
#'
#' @return A matrix where each row represents a chunk, with the first column being
#'         the start of the chunk and the second column being the end of the chunk.
#' @examples
#' chunk_fixed_n(1, 100, 5)
#' @export
chunk_fixed_n <- function(start, end, num_chunks) {
  chunk_size <- ceiling((end - start + 1) / num_chunks)
  chunk_ranges <- sapply(1:num_chunks, function(i) {
    chunk_start <- start + (i - 1) * chunk_size
    chunk_end <- min(chunk_start + chunk_size - 1, end)
    c(chunk_start, chunk_end)
  })
  return(chunk_ranges)
}

#' Generate Chunk Ranges with Fixed Chunk Size
#'
#' This function divides a range into chunks up to a given maximum size, dynamically
#' determining the number of chunks based on the range and maximum chunk size.
#'
#' @param start The starting point of the range to be divided.
#' @param end The ending point of the range to be divided.
#' @param max_chunk_size The maximum size that each chunk can have.
#'bz
#' @return A matrix where each row represents a chunk, with the first column being
#'         the start of the chunk and the second column being the end of the chunk.
#'         The last chunk may be smaller than `max_chunk_size` to fit the range.
#' @examples
#' chunk_fixed_size(1, 100, 20)
#' @export
chunk_fixed_size <- function(start, end, max_chunk_size) {
  if (length(start) > 1 || length(end) > 1) {
    stop("start and end must be single values")
  }
  if (start > end || max_chunk_size <= 0) {
    stop("Invalid arguments: ensure start <= end and max_chunk_size > 0")
  }
  
  num_chunks <- ceiling((end - start + 1) / max_chunk_size)
  chunk_ranges <- matrix(nrow = num_chunks, ncol = 2)
  
  for (i in 1:num_chunks) {
    chunk_start <- start + (i - 1) * max_chunk_size
    chunk_end <- min(chunk_start + max_chunk_size - 1, end)
    chunk_ranges[i, ] <- c(chunk_start, chunk_end)
  }
  
  return(t(chunk_ranges))
}

# %%
head(df)
# Out:
#   Chr SNP_data
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
#   last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1 248918358                         1069461
# 2 241863783                           10001
# 3 198099789                           11602
# 4 189877411                           69399
# 5 181172584                           44104
# 6 170619093                          192453
#   last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1 2202702                           8982
# 2 2019984                              1
# 3 1538467                              1
# 4 1387731                              1
# 5 1409038                              1
# 6 1412543                           1138
#   population region
# 1 AA         caud
# 2 AA         caud
# 3 AA         caud
# 4 AA         caud
# 5 AA         caud
# 6 AA         caud
#   cov_file
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv

# %%
i <- 1

chunk_ranges <- chunk_fixed_size(df$first_meth_index_with_SNP_coverage[i],
                                 df$last_meth_index_with_SNP_coverage[i],
                                 20000)

# %%
chunk_ranges <- t(chunk_ranges)
colnames(chunk_ranges) <- c("chunk_start", "chunk_end")

# %%
library(data.table)

# Assume df is your existing data.table

# Function to apply chunk_fixed_size for each row and expand the data.table
expand_df_with_chunks <- function(df) {
  expanded_list <- lapply(1:nrow(df), function(i) {
    # Use the chunk_fixed_size function to get chunk start and end for the row
    chunk_ranges <- t(chunk_fixed_size(df$first_meth_index_with_SNP_coverage[i],
                                       df$last_meth_index_with_SNP_coverage[i],
                                       20000))
    
    # Create a data.table for the chunks of the current row
    chunks_dt <- data.table(chunk_ranges)
    setnames(chunks_dt, c("V1", "V2"), c("chunk_start", "chunk_end"))
    
    # Repeat the i-th row of df for each chunk
    repeated_rows <- df[rep(i, nrow(chunks_dt)), ]
    
    # Combine the chunks with the repeated rows
    cbind(repeated_rows, chunks_dt)
  })
  
  # Combine all expanded rows into a single data.table
  return(rbindlist(expanded_list))
}

# Use the function to expand the original df with chunk information
df_expanded <- expand_df_with_chunks(df)

df_expanded
# Out:
#       Chr SNP_data
# 1     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 3     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 4     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 5     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 6     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 7     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 8     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 9     1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 10    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 11    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 12    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 13    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 14    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 15    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 16    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 17    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 18    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 19    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 20    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 21    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 22    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 23    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 24    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 25    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 26    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 27    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 28    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 29    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 30    1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# ⋮     ⋮   ⋮
# 11428 21  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr21.pgen
# 11429 21  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr21.pgen
# 11430 21  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr21.pgen
# 11431 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11432 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11433 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11434 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11435 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11436 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11437 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11438 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11439 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11440 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11441 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11442 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11443 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11444 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11445 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11446 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11447 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11448 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11449 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11450 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11451 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11452 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11453 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11454 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11455 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11456 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
# 11457 22  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr22.pgen
#       methylation_data
# 1     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 3     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 4     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 5     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 6     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 7     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 8     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 9     /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 10    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 11    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 12    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 13    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 14    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 15    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 16    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 17    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 18    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 19    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 20    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 21    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 22    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 23    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 24    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 25    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 26    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 27    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 28    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 29    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 30    /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# ⋮     ⋮
# 11428 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr21_EA.rda
# 11429 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr21_EA.rda
# 11430 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr21_EA.rda
# 11431 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11432 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11433 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11434 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11435 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11436 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11437 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11438 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11439 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11440 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11441 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11442 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11443 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11444 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11445 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11446 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11447 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11448 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11449 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11450 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11451 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11452 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11453 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11454 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11455 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11456 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
# 11457 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr22_EA.rda
#       last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1     248918358                         1069461
# 2     248918358                         1069461
# 3     248918358                         1069461
# 4     248918358                         1069461
# 5     248918358                         1069461
# 6     248918358                         1069461
# 7     248918358                         1069461
# 8     248918358                         1069461
# 9     248918358                         1069461
# 10    248918358                         1069461
# 11    248918358                         1069461
# 12    248918358                         1069461
# 13    248918358                         1069461
# 14    248918358                         1069461
# 15    248918358                         1069461
# 16    248918358                         1069461
# 17    248918358                         1069461
# 18    248918358                         1069461
# 19    248918358                         1069461
# 20    248918358                         1069461
# 21    248918358                         1069461
# 22    248918358                         1069461
# 23    248918358                         1069461
# 24    248918358                         1069461
# 25    248918358                         1069461
# 26    248918358                         1069461
# 27    248918358                         1069461
# 28    248918358                         1069461
# 29    248918358                         1069461
# 30    248918358                         1069461
# ⋮     ⋮                                 ⋮
# 11428 46682679                          13391623
# 11429 46682679                          13391623
# 11430 46682679                          13391623
# 11431 50767586                          16603949
# 11432 50767586                          16603949
# 11433 50767586                          16603949
# 11434 50767586                          16603949
# 11435 50767586                          16603949
# 11436 50767586                          16603949
# 11437 50767586                          16603949
# 11438 50767586                          16603949
# 11439 50767586                          16603949
# 11440 50767586                          16603949
# 11441 50767586                          16603949
# 11442 50767586                          16603949
# 11443 50767586                          16603949
# 11444 50767586                          16603949
# 11445 50767586                          16603949
# 11446 50767586                          16603949
# 11447 50767586                          16603949
# 11448 50767586                          16603949
# 11449 50767586                          16603949
# 11450 50767586                          16603949
# 11451 50767586                          16603949
# 11452 50767586                          16603949
# 11453 50767586                          16603949
# 11454 50767586                          16603949
# 11455 50767586                          16603949
# 11456 50767586                          16603949
# 11457 50767586                          16603949
#       last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1     2202702                           8982
# 2     2202702                           8982
# 3     2202702                           8982
# 4     2202702                           8982
# 5     2202702                           8982
# 6     2202702                           8982
# 7     2202702                           8982
# 8     2202702                           8982
# 9     2202702                           8982
# 10    2202702                           8982
# 11    2202702                           8982
# 12    2202702                           8982
# 13    2202702                           8982
# 14    2202702                           8982
# 15    2202702                           8982
# 16    2202702                           8982
# 17    2202702                           8982
# 18    2202702                           8982
# 19    2202702                           8982
# 20    2202702                           8982
# 21    2202702                           8982
# 22    2202702                           8982
# 23    2202702                           8982
# 24    2202702                           8982
# 25    2202702                           8982
# 26    2202702                           8982
# 27    2202702                           8982
# 28    2202702                           8982
# 29    2202702                           8982
# 30    2202702                           8982
# ⋮     ⋮                                 ⋮
# 11428 358983                            11194
# 11429 358983                            11194
# 11430 358983                            11194
# 11431 543839                            14844
# 11432 543839                            14844
# 11433 543839                            14844
# 11434 543839                            14844
# 11435 543839                            14844
# 11436 543839                            14844
# 11437 543839                            14844
# 11438 543839                            14844
# 11439 543839                            14844
# 11440 543839                            14844
# 11441 543839                            14844
# 11442 543839                            14844
# 11443 543839                            14844
# 11444 543839                            14844
# 11445 543839                            14844
# 11446 543839                            14844
# 11447 543839                            14844
# 11448 543839                            14844
# 11449 543839                            14844
# 11450 543839                            14844
# 11451 543839                            14844
# 11452 543839                            14844
# 11453 543839                            14844
# 11454 543839                            14844
# 11455 543839                            14844
# 11456 543839                            14844
# 11457 543839                            14844
#       population region
# 1     AA         caud
# 2     AA         caud
# 3     AA         caud
# 4     AA         caud
# 5     AA         caud
# 6     AA         caud
# 7     AA         caud
# 8     AA         caud
# 9     AA         caud
# 10    AA         caud
# 11    AA         caud
# 12    AA         caud
# 13    AA         caud
# 14    AA         caud
# 15    AA         caud
# 16    AA         caud
# 17    AA         caud
# 18    AA         caud
# 19    AA         caud
# 20    AA         caud
# 21    AA         caud
# 22    AA         caud
# 23    AA         caud
# 24    AA         caud
# 25    AA         caud
# 26    AA         caud
# 27    AA         caud
# 28    AA         caud
# 29    AA         caud
# 30    AA         caud
# ⋮     ⋮          ⋮
# 11428 EA         hippo
# 11429 EA         hippo
# 11430 EA         hippo
# 11431 EA         hippo
# 11432 EA         hippo
# 11433 EA         hippo
# 11434 EA         hippo
# 11435 EA         hippo
# 11436 EA         hippo
# 11437 EA         hippo
# 11438 EA         hippo
# 11439 EA         hippo
# 11440 EA         hippo
# 11441 EA         hippo
# 11442 EA         hippo
# 11443 EA         hippo
# 11444 EA         hippo
# 11445 EA         hippo
# 11446 EA         hippo
# 11447 EA         hippo
# 11448 EA         hippo
# 11449 EA         hippo
# 11450 EA         hippo
# 11451 EA         hippo
# 11452 EA         hippo
# 11453 EA         hippo
# 11454 EA         hippo
# 11455 EA         hippo
# 11456 EA         hippo
# 11457 EA         hippo
#       cov_file
# 1     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 2     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 3     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 4     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 5     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 6     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 7     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 8     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 9     /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 10    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 11    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 12    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 13    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 14    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 15    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 16    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 17    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 18    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 19    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 20    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 21    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 22    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 23    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 24    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 25    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 26    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 27    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 28    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 29    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# 30    /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv
# ⋮     ⋮
# 11428 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11429 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11430 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11431 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11432 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11433 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11434 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11435 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11436 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11437 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11438 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11439 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11440 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11441 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11442 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11443 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11444 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11445 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11446 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11447 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11448 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11449 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11450 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11451 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11452 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11453 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11454 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11455 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11456 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
# 11457 /expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv
#       chunk_start chunk_end
# 1       8982       28981
# 2      28982       48981
# 3      48982       68981
# 4      68982       88981
# 5      88982      108981
# 6     108982      128981
# 7     128982      148981
# 8     148982      168981
# 9     168982      188981
# 10    188982      208981
# 11    208982      228981
# 12    228982      248981
# 13    248982      268981
# 14    268982      288981
# 15    288982      308981
# 16    308982      328981
# 17    328982      348981
# 18    348982      368981
# 19    368982      388981
# 20    388982      408981
# 21    408982      428981
# 22    428982      448981
# 23    448982      468981
# 24    468982      488981
# 25    488982      508981
# 26    508982      528981
# 27    528982      548981
# 28    548982      568981
# 29    568982      588981
# 30    588982      608981
# ⋮     ⋮           ⋮
# 11428 311194      331193
# 11429 331194      351193
# 11430 351194      358983
# 11431  14844       34843
# 11432  34844       54843
# 11433  54844       74843
# 11434  74844       94843
# 11435  94844      114843
# 11436 114844      134843
# 11437 134844      154843
# 11438 154844      174843
# 11439 174844      194843
# 11440 194844      214843
# 11441 214844      234843
# 11442 234844      254843
# 11443 254844      274843
# 11444 274844      294843
# 11445 294844      314843
# 11446 314844      334843
# 11447 334844      354843
# 11448 354844      374843
# 11449 374844      394843
# 11450 394844      414843
# 11451 414844      434843
# 11452 434844      454843
# 11453 454844      474843
# 11454 474844      494843
# 11455 494844      514843
# 11456 514844      534843
# 11457 534844      543839

# %% [markdown]
# Sanity checks

# %%
#df_expanded[which(df_expanded$chunk_end == 2202702), ]

# %%
#df_expanded[which(df_expanded$Chr == 2), ]

# %%
df_expanded[, modified_methylation_data := sub("out", "chunked", methylation_data)]
df_expanded[, modified_methylation_data := sub("\\.rda$", paste0("_", chunk_start, "-", chunk_end, ".rds"), modified_methylation_data), by = .I]

#df_expanded

# %% [markdown]
# ## Test for first chunk

# %%
library(CpGWAS)

# %%
num_cores <- future::availableCores()

i <- 1

load(df_expanded$methylation_data[i])

methInput <- new("MethylationInput",
               BSseq_obj = BSobj2,
               snp_data_path = df_expanded$SNP_data[i],
               cov_path = df_expanded$cov_file[i],
               start_site = df_expanded$chunk_start[i],
               end_site = df_expanded$chunk_end[i],
               no_cores = num_cores)

BSobj2 <- means <- sds <- NULL

if(!dir.exists(dirname(df_expanded$modified_methylation_data[i]))) dir.create(dirname(df_expanded$modified_methylation_data[i]))

object.size(methInput)/10^6

saveRDS(methInput, df_expanded$modified_methylation_data[i])
# Out:
# Warning message in processMethylationData(BSseq_obj, start_site, end_site):
# “Row names not found in methylation matrix of BSseq object. Retrieving from $colData$brnum.”
# 71 bytes

# %%
file.exists(df_expanded$modified_methylation_data[i])
# Out:
# [1] TRUE

# %%
df_expanded$modified_methylation_data[i]
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/chunked/chr1_AA_8982-28981.rds"

# %% [markdown]
# ## Run over all

# %%
num_cores <- future::availableCores()

# %%
library(plyr)
library(methods)

# %%
# Filter out rows where the modified methylation data file already exists
df_expanded <- df_expanded[!sapply(modified_methylation_data, file.exists)]

# %%
# Initialize last loaded methylation_data to manage repeated loading
last_loaded <- "filler"

# Initialize the progress bar
#pb <- txtProgressBar(min = 0, max = nrow(df_expanded), style = 3)

for (i in 1:nrow(df_expanded)) {
    # Progress bar setup
    #setTxtProgressBar(pb, i)

    # Check if the file already exists to skip the processing for this row
    if (file.exists(df_expanded$modified_methylation_data[i])) {
        next
    }

    # Only reload the methylation data if it's different from the last loaded data
    if (df_expanded$methylation_data[i] != last_loaded) {
        BSobj2 <- means <- sds <- NULL    
        load(df_expanded$methylation_data[i])
        last_loaded <- df_expanded$methylation_data[i]
    }
    
    # Create MethylationInput object
    methInput <- suppressWarnings(new("MethylationInput",
                     BSseq_obj = BSobj2,
                     snp_data_path = df_expanded$SNP_data[i],
                     cov_path = df_expanded$cov_file[i],
                     start_site = df_expanded$chunk_start[i],
                     end_site = df_expanded$chunk_end[i],
                     no_cores = num_cores))
    
    # Ensure the directory exists before saving
    if (!dir.exists(dirname(df_expanded$modified_methylation_data[i]))) {
        dir.create(dirname(df_expanded$modified_methylation_data[i]), recursive = TRUE)
    }
    
    # Print object size for debugging
    #print(paste("Size of methInput object:", object.size(methInput)/10^6, "MB"))

    methInput@pvar_dt <- NULL # To save space on disk since we'll reload it from SNP data
    
    # Save the RDS file
    saveRDS(methInput, df_expanded$modified_methylation_data[i])
}
