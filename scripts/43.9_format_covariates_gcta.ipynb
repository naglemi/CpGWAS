# %% [markdown]
# # 43.9: Reformat covariate files for GCTA.

# %%
import pandas as pd
import os

# %%
os.chdir("/dcs04/lieber/statsgen/mnagle/mwas/full_covariates/")

# %%
import pandas as pd
import os

def prepare_gwas_covariates(input_csv, discrete_output, quantitative_output):
    """
    Prepares covariate files for GWAS analysis.
    
    Parameters:
    - input_csv (str): Path to the input CSV file.
    - discrete_output (str): Path to the output file for discrete covariates.
    - quantitative_output (str): Path to the output file for quantitative covariates.
    """
    # Read the input CSV
    df = pd.read_csv(input_csv, sep=',')
    
    # Print the head of the DataFrame and the column names
    print(f"Reading {input_csv}:")
    print("DataFrame Head:")
    print(df.head())
    print("\nColumn Names:")
    print(df.columns.tolist())
    
    # Ensure 'ID' is interpreted as FID and IID
    if 'ID' in df.columns:
        df['FID'] = 0
        df['IID'] = df['ID']
    else:
        raise KeyError("Column 'ID' not found in the file.")
    
    # Define columns
    discrete_cols = ['FID', 'IID', 'Dx', 'Sex']
    quantitative_cols = ['FID', 'IID', 'genoPC1', 'genoPC2', 'genoPC3'] + \
                        [f'methPC{i}' for i in range(1, 11)] + ['Age']

    # Convert categorical to numeric for discrete columns
    if 'Dx' in df.columns and 'Sex' in df.columns:
        df['Dx'] = pd.Categorical(df['Dx']).codes
        df['Sex'] = pd.Categorical(df['Sex']).codes
    else:
        raise KeyError("Necessary columns 'Dx' or 'Sex' not found in the file.")
    
    # Prepare discrete DataFrame
    discrete_df = df[discrete_cols]
    
    # Prepare quantitative DataFrame
    quantitative_df = df[quantitative_cols]
    
    # Save to CSV without header and index
    discrete_df.to_csv(discrete_output, sep='\t', index=False, header=False)
    quantitative_df.to_csv(quantitative_output, sep='\t', index=False, header=False)
    print(f"Processed {input_csv}:")
    print(f"- Discrete covariates saved to {discrete_output}")
    print(f"- Quantitative covariates saved to {quantitative_output}")

# Loop over files in the current directory
for filename in os.listdir('.'):
    if filename.endswith('.csv'):
        prefix = filename.split('.')[0]
        discrete_output = f'{prefix}.covar'
        quantitative_output = f'{prefix}.qcovar'
        prepare_gwas_covariates(filename, discrete_output, quantitative_output)
# Out:
# Reading EA_hippo.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1016 -0.102730 -0.007874  0.002259 -582.250410 -195.066376   14.540472
# 1  Br1023 -0.090669 -0.331012  0.001278  182.960586  -84.161823  111.237437
# 2  Br1034 -0.101899  0.013660  0.005231 -548.376263 -191.801205 -114.255203
# 3  Br1092 -0.100973 -0.000949 -0.000945  -41.944428  568.769599  198.333064
# 4  Br1093 -0.101100  0.034861  0.029725  101.058254  355.618952   64.023480
#
#       methPC4     methPC5     methPC6     methPC7     methPC8    methPC9  \
# 0 -155.757748   88.609704 -259.841967   -5.449045   66.233979  -9.111428
# 1 -121.846469 -108.675703    9.201356  114.092966  149.898635 -74.053124
# 2  197.384645  -32.900962  -49.010551    9.324397  -35.902978 -76.886305
# 3  -22.722300 -234.328217   -3.249619   35.845048   34.789159  77.225962
# 4  161.421514 -132.173168   78.876031   -1.594505  -20.586247 -11.694494
#
#      methPC10       Dx    Age Sex
# 0  113.843382      SCZ  20.22   M
# 1  -19.005887  Control  63.00   M
# 2  -46.958898  Control  57.60   M
# 3 -106.518608  Control  48.95   M
# 4   62.468243      SCZ  71.81   F
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed EA_hippo.csv:
# - Discrete covariates saved to EA_hippo.covar
# - Quantitative covariates saved to EA_hippo.qcovar
# Reading AA_dlpfc.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3      methPC1     methPC2     methPC3  \
# 0  Br1003  0.064963  0.074912 -0.129771 -1080.757470 -183.508276   43.997443
# 1  Br1004  0.052137  0.007243 -0.140084   117.248502  149.108508  210.480053
# 2  Br1007  0.077869  0.042406  0.012769  -263.014597  347.669673 -151.630658
# 3  Br1017  0.079119  0.082674  0.041231    37.937152  242.189299 -255.331803
# 4  Br1021  0.064803  0.088405  0.056332  -200.324311  261.421534  159.267846
#
#       methPC4     methPC5     methPC6     methPC7     methPC8    methPC9  \
# 0  -23.788727   73.354715  -65.130577   68.979638  -76.186697  84.147458
# 1  116.411971  -18.692115   -7.441670   58.691919   92.345865  57.052108
# 2 -155.460984 -161.957081   71.835809  -16.465749   -4.039417  20.078478
# 3 -169.157859  -30.608900 -160.603646 -119.687238 -203.422434  98.541195
# 4  138.194436  149.503265  159.262414   27.372758  -15.746279  33.307769
#
#      methPC10       Dx    Age Sex
# 0   35.764712  Control  52.57   F
# 1   13.876368  Control  21.01   M
# 2  -83.178154  Control  57.10   M
# 3 -202.960719  Control  48.42   F
# 4   32.492158      SCZ  63.18   M
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed AA_dlpfc.csv:
# - Discrete covariates saved to AA_dlpfc.covar
# - Quantitative covariates saved to AA_dlpfc.qcovar
# Reading all_hippo.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1003  0.067144 -0.037235  0.072773 -741.523472   -7.633219  106.266089
# 1  Br1004  0.054991 -0.013580  0.052920   61.363711 -151.938629  -24.981684
# 2  Br1007  0.078474 -0.005480  0.100941  -94.958564 -398.668461   85.832111
# 3  Br1016 -0.102730 -0.007874  0.002259 -463.228014  354.857300 -139.944060
# 4  Br1017  0.079086 -0.027208  0.065699  552.235588  258.134883 -278.548762
#
#       methPC4     methPC5     methPC6     methPC7    methPC8     methPC9  \
# 0  -94.384989   62.031338  -37.796088    9.625000 -61.623860    5.881620
# 1  185.309290  142.907783 -181.925481   65.087436  -5.219542  -26.188442
# 2   93.157348  121.971782  132.153691  140.772041 -38.120997  -41.247657
# 3  165.258471 -168.284605    8.663533  190.686873  69.134257   25.225274
# 4 -434.752918  105.410458 -316.855047  -72.221474   7.598522  135.869066
#
#      methPC10       Dx    Age Sex
# 0  -12.245952  Control  52.57   F
# 1   40.762554  Control  21.01   M
# 2 -100.179681  Control  57.10   M
# 3  -44.476145      SCZ  20.22   M
# 4 -182.252860  Control  48.42   F
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed all_hippo.csv:
# - Discrete covariates saved to all_hippo.covar
# - Quantitative covariates saved to all_hippo.qcovar
# Reading all_caud.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1003  0.059123 -0.039808  0.020531  143.209364  128.591799  -88.154445
# 1  Br1004  0.050751  0.016700 -0.023502  194.371327   81.154099  -40.362598
# 2  Br1007  0.068320  0.005024 -0.059590 -123.938202  154.705592  157.181450
# 3  Br1016 -0.063984 -0.043628  0.033461  364.038425 -227.750105   70.339940
# 4  Br1017  0.068506 -0.008444 -0.010932 -155.012135  131.998283   56.226110
#
#       methPC4    methPC5     methPC6     methPC7    methPC8    methPC9  \
# 0 -113.868719 -19.873129 -117.743828  -41.251334  52.943663 -50.511411
# 1  -94.568722  83.616459   33.955421  160.874471 -32.969432  57.579260
# 2 -119.736784 -17.233759  111.030514  -67.781352 -56.681392 -48.163955
# 3   -0.330318  72.028156   27.093025  188.583557 -44.239040  36.884147
# 4 -153.686500  -8.949595  -24.211563  -70.991050 -86.086464 -55.229823
#
#      methPC10       Dx    Age Sex
# 0   63.607456  Control  52.57   F
# 1 -105.135625  Control  21.01   M
# 2   40.716193  Control  57.10   M
# 3  -50.579984      SCZ  20.22   M
# 4  -69.932589  Control  48.42   F
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed all_caud.csv:
# - Discrete covariates saved to all_caud.covar
# - Quantitative covariates saved to all_caud.qcovar
# Reading AA_hippo.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1003  0.067144 -0.037235  0.072773 -750.337418   32.219235  -38.616053
# 1  Br1004  0.054991 -0.013580  0.052920   59.122239 -155.717344   92.497935
# 2  Br1007  0.078474 -0.005480  0.100941 -120.648148 -406.334440  -56.429329
# 3  Br1017  0.079086 -0.027208  0.065699  609.350776  252.238116  318.144211
# 4  Br1021  0.066385 -0.004914  0.089785  173.601707 -200.204861   -2.157365
#
#       methPC4     methPC5     methPC6    methPC7     methPC8     methPC9  \
# 0   90.630439  -57.256359   12.009852 -49.428593   37.267736  -32.400913
# 1 -226.003088 -141.920945  -31.082812 -28.557155   18.934647  -40.142648
# 2 -122.363118  140.126551  -88.627684 -84.108796  113.299330   95.508269
# 3  432.985649 -302.300736  182.674427  45.528937  -83.530536  166.924371
# 4  135.527292   66.616546 -104.188157 -60.479979  -55.132642 -227.851492
#
#      methPC10       Dx    Age Sex
# 0  107.757255  Control  52.57   F
# 1  -81.371943  Control  21.01   M
# 2   21.781729  Control  57.10   M
# 3   78.149548  Control  48.42   F
# 4  121.940050      SCZ  63.18   M
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed AA_hippo.csv:
# - Discrete covariates saved to AA_hippo.covar
# - Quantitative covariates saved to AA_hippo.qcovar
# Reading EA_dlpfc.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1016 -0.113154  0.021414  0.013420 -240.617034  716.996486  -43.275506
# 1  Br1023 -0.100480  0.223684 -0.069715 -214.639879  -95.602467 -277.067015
# 2  Br1034 -0.112748 -0.000420 -0.032425  -12.759773  608.189028    6.664371
# 3  Br1093 -0.112134 -0.001253  0.032796   68.342272 -247.580861  -89.600457
# 4  Br1214 -0.112075 -0.027417  0.027889 -413.549018  -55.239519  -60.934469
#
#       methPC4    methPC5     methPC6    methPC7     methPC8    methPC9  \
# 0  -65.613340  47.654509  -40.739665   4.554927  -67.864622  24.234744
# 1   28.361260 -91.094486 -101.337623 -13.220663  117.226718 -51.194671
# 2   70.906831 -24.208597  -19.053973 -63.675807  -61.484333   7.424395
# 3  145.968871 -18.340009   -0.035812  24.965400   12.778925 -93.194492
# 4  131.393273  44.329258   11.791898  86.834125   86.891743 -92.341174
#
#     methPC10       Dx    Age Sex
# 0 -57.503466      SCZ  20.22   M
# 1  -3.371285  Control  63.00   M
# 2 -43.309677  Control  57.60   M
# 3  65.578568      SCZ  71.81   F
# 4   1.975586  Control  61.13   M
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed EA_dlpfc.csv:
# - Discrete covariates saved to EA_dlpfc.covar
# - Quantitative covariates saved to EA_dlpfc.qcovar
# Reading EA_caud.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1016 -0.063984 -0.043628  0.033461 -362.980615  -45.120005  113.748708
# 1  Br1023 -0.054572 -0.327459 -0.030464  375.801592  268.636079    1.834617
# 2  Br1033 -0.063235 -0.001205  0.004668  -29.330842 -256.668085   66.793944
# 3  Br1034 -0.063174 -0.004474  0.017187   56.856574  102.796917  -72.870736
# 4  Br1092 -0.062556  0.002444  0.016724  668.328821   88.054021   31.415066
#
#      methPC4     methPC5     methPC6     methPC7    methPC8     methPC9  \
# 0 -99.148958  -28.249523  209.583776 -108.191343  18.319889   32.702830
# 1  56.976343  -66.999011  -31.533647  -12.253772 -54.312592  -59.798244
# 2 -68.220938 -149.172400   89.201088  157.028234  21.815190   47.296770
# 3  90.078280   51.513956  240.371754   92.467284 -46.893300  167.123364
# 4  84.156076   19.306240   81.391933 -195.069839 -24.477233  -71.818228
#
#      methPC10       Dx    Age Sex
# 0   17.190263      SCZ  20.22   M
# 1   62.903547  Control  63.00   M
# 2   89.274746  Control  26.51   F
# 3  -25.768102  Control  57.60   M
# 4  133.079743  Control  48.95   M
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed EA_caud.csv:
# - Discrete covariates saved to EA_caud.covar
# - Quantitative covariates saved to EA_caud.qcovar
# Reading AA_caud.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3     methPC1     methPC2     methPC3  \
# 0  Br1003  0.059123 -0.039808  0.020531 -157.046466   22.431504   -3.613153
# 1  Br1004  0.050751  0.016700 -0.023502 -207.977926   14.563873  -48.109417
# 2  Br1007  0.068320  0.005024 -0.059590  119.293384 -184.287037 -127.987516
# 3  Br1017  0.068506 -0.008444 -0.010932  148.351403  -89.715577  -97.742602
# 4  Br1021  0.059670  0.003678  0.047955  453.471004 -132.387141   35.349695
#
#      methPC4     methPC5     methPC6     methPC7     methPC8     methPC9  \
# 0  28.587802 -165.830789   15.491404   27.347098   68.146346  -83.144721
# 1 -48.368597   65.479538 -174.436205  -40.363495 -103.813378   11.087242
# 2   8.047659  100.518214  112.404812  -44.079714  -13.331837  109.550591
# 3   7.072870  -78.404717   77.029617  -33.334885  -34.948204   73.886328
# 4  80.759933  123.878599  -39.433812 -122.191818   64.627124  -62.891067
#
#     methPC10       Dx    Age Sex
# 0  74.405523  Control  52.57   F
# 1 -84.670514  Control  21.01   M
# 2  55.891996  Control  57.10   M
# 3  65.622516  Control  48.42   F
# 4 -25.939892      SCZ  63.18   M
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed AA_caud.csv:
# - Discrete covariates saved to AA_caud.covar
# - Quantitative covariates saved to AA_caud.qcovar
# Reading all_dlpfc.csv:
# DataFrame Head:
#        ID   genoPC1   genoPC2   genoPC3      methPC1     methPC2     methPC3  \
# 0  Br1003  0.064963  0.074912 -0.129771 -1063.856371 -178.166581 -122.616337
# 1  Br1004  0.052137  0.007243 -0.140084   124.245986  145.082035  -45.819605
# 2  Br1007  0.077869  0.042406  0.012769  -242.209238  337.358345 -102.688518
# 3  Br1016 -0.113154  0.021414  0.013420   210.627335 -677.011184  234.981716
# 4  Br1017  0.079119  0.082674  0.041231    56.754711  237.679573 -196.489674
#
#       methPC4     methPC5    methPC6    methPC7     methPC8     methPC9  \
# 0   41.019397  -15.628191  25.712962 -93.254520   34.981711   -1.678003
# 1  236.922395  -23.319253 -78.783541 -27.489030  -18.863886   60.377535
# 2 -180.217203 -180.319796 -27.880320  74.632757  -31.780362    5.828085
# 3    2.795834   -4.344111 -38.000925 -56.424583  -42.914173  -90.919412
# 4 -245.901087 -103.081975  51.141895  -7.924028  136.443338 -115.072485
#
#      methPC10       Dx    Age Sex
# 0  133.010687  Control  52.57   F
# 1   -6.303476  Control  21.01   M
# 2  -34.318495  Control  57.10   M
# 3   22.720535      SCZ  20.22   M
# 4  124.219645  Control  48.42   F
#
# Column Names:
# ['ID', 'genoPC1', 'genoPC2', 'genoPC3', 'methPC1', 'methPC2', 'methPC3', 'methPC4', 'methPC5', 'methPC6', 'methPC7', 'methPC8', 'methPC9', 'methPC10', 'Dx', 'Age', 'Sex']
# Processed all_dlpfc.csv:
# - Discrete covariates saved to all_dlpfc.covar
# - Quantitative covariates saved to all_dlpfc.qcovar

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
