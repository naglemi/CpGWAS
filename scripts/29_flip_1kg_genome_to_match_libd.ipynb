# %% [markdown]
# # Flip allele order in 1k genome reference to match alleles in LIBD SNP dataset.

# %%
cd /expanse/lustre/projects/jhu152/naglemi/mwas/gwas_flipped/

# %%
conda activate mwas

# %% [markdown]
# ## Run for one chromosome

# %%
head ref_EUR_chr1.pvar
# Out:
# #CHROM	POS	ID	REF	ALT
# 1	1079456	rs12401605	G	A
# 1	1079484	rs12411041	A	T
# 1	1079746	rs36027499	G	A
# 1	1079877	rs9442369	G	A
# 1	1080171	rs9442370	T	C
# 1	1080437	rs12746483	A	G
# 1	1081790	rs3766193	G	C
# 1	1081817	rs3766192	T	C
# 1	1081961	rs1133647	T	G

# %%
# Define paths to the pvar files
ref_pvar="ref_EUR_chr1.pvar"
libd_pvar="libd_chr1.pvar"
output_file="snps_to_flip.txt"

# Call the R script to generate the flip list
Rscript /expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts/generate_flip_list.R $ref_pvar $libd_pvar $output_file
# Out:
# Total SNPs in ref file: 448584
# Total SNPs in libd file: 448584
# Percentage of SNPs to potentially flip in ref file: 22.55%
# Percentage of SNPs to potentially flip in libd file: 22.55%

# %%
head snps_to_flip.txt
# Out:
# rs12401605	A
# rs12411041	T
# rs36027499	A
# rs9442369	A
# rs9442370	C
# rs12746483	G
# rs3766193	C
# rs3766192	C
# rs1133647	G
# rs9442395	T

# %% [raw]
# From PLINK docs:
#
# Set REF/ALT alleles
# --ref-allele ['force'] <filename> [REF col. number] [variant ID col.] [skip]
# --alt-allele ['force'] <filename> [ALT col. number] [variant ID col.] [skip]
# --alt1-allele ['force'] <filename> [ALT1 col. number] [variant ID col.] [skip]
#
# --ref-from-fa ['force']
#
# --ref-allele, --alt-allele, and --alt1-allele reorder REF/ALT alleles. For each input row, --ref-allele sets the given allele to REF, --alt1-allele sets the given allele to ALT1, and --alt-allele can set multiple comma-separated ALT alleles. Column and skip parameters work the same way as with --update-chr and friends.

# %%
# Path to the PLINK binary
plink_path="./plink2"

# Check if the SNP flip list was created and is not empty
if [ -s "$output_file" ]; then

  # Run PLINK to flip the alleles
  ./plink2 --pfile ref_EUR_chr1 --ref-allele snps_to_flip.txt 2 1 --make-pgen --out ref_EUR_flipped_chr1

  echo "PLINK has been executed to flip the alleles."
else
  echo "No SNPs need flipping, or an error occurred."
fi
# Out:
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr1.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr1
#   --pfile ref_EUR_chr1
#   --ref-allele snps_to_flip.txt 2 1
#
# Start time: Mon Aug 12 12:09:43 2024
# 257485 MiB RAM detected, ~214434 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr1.psam.
# 448584 variants loaded from ref_EUR_chr1.pvar.
# Note: No phenotype data present.
# --ref-allele: 101161 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr1.psam ... done.
# Writing ref_EUR_flipped_chr1.pvar ... .
# Writing ref_EUR_flipped_chr1.pgen ... 4387done.
# End time: Mon Aug 12 12:09:43 2024
# PLINK has been executed to flip the alleles.

# %% [markdown]
# ## Run for all

# %%
# Path to the PLINK binary
plink_path="./plink2"

# Path to the R script
r_script_path="/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts/generate_flip_list.R"

# Loop through chromosomes 1 to 22
for chr in {1..22}
do
  echo "Processing chromosome $chr..."

  # Define file paths for this chromosome
  ref_pvar="ref_EUR_chr${chr}.pvar"
  libd_pvar="libd_chr${chr}.pvar"
  output_file="snps_to_flip_chr${chr}.txt"

  # Call the R script to generate the flip list
  Rscript $r_script_path $ref_pvar $libd_pvar $output_file

  # Check if the SNP flip list for this chromosome was created and is not empty
  if [ -s "$output_file" ]; then
    # Run PLINK to set the reference alleles
    $plink_path --pfile ref_EUR_chr$chr --ref-allele $output_file 2 1 --make-pgen --out ref_EUR_flipped_chr$chr

    echo "PLINK has been executed to flip the alleles for chromosome $chr."
  else
    echo "No SNPs need flipping for chromosome $chr, or an error occurred."
  fi

  # Add a blank line for readability between iterations
  echo ""
  echo ""
  echo ""
  echo ""
  echo ""
done
# Out:
# Processing chromosome 1...
# Total SNPs in ref file: 448584
# Total SNPs in libd file: 448584
# Percentage of SNPs to potentially flip in ref file: 22.55%
# Percentage of SNPs to potentially flip in libd file: 22.55%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr1.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr1
#   --pfile ref_EUR_chr1
#   --ref-allele snps_to_flip_chr1.txt 2 1
#
# Start time: Mon Aug 12 12:15:43 2024
# 257485 MiB RAM detected, ~214555 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr1.psam.
# 448584 variants loaded from ref_EUR_chr1.pvar.
# Note: No phenotype data present.
# --ref-allele: 101161 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr1.psam ... done.
# Writing ref_EUR_flipped_chr1.pvar ... .
# Writing ref_EUR_flipped_chr1.pgen ... 4387done.
# End time: Mon Aug 12 12:15:43 2024
# PLINK has been executed to flip the alleles for chromosome 1.
#
#
#
#
#
# Processing chromosome 2...
# Total SNPs in ref file: 502800
# Total SNPs in libd file: 502800
# Percentage of SNPs to potentially flip in ref file: 22.00%
# Percentage of SNPs to potentially flip in libd file: 22.00%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr2.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr2
#   --pfile ref_EUR_chr2
#   --ref-allele snps_to_flip_chr2.txt 2 1
#
# Start time: Mon Aug 12 12:15:44 2024
# 257485 MiB RAM detected, ~214571 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr2.psam.
# 502800 variants loaded from ref_EUR_chr2.pvar.
# Note: No phenotype data present.
# Warning: --ref-allele mismatch for biallelic variant 'rs9308891'.
# --ref-allele: 110599 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr2.psam ... done.
# Writing ref_EUR_flipped_chr2.pvar ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# Writing ref_EUR_flipped_chr2.pgen ... 3978done.
# End time: Mon Aug 12 12:15:45 2024
# PLINK has been executed to flip the alleles for chromosome 2.
#
#
#
#
#
# Processing chromosome 3...
# Total SNPs in ref file: 429002
# Total SNPs in libd file: 429002
# Percentage of SNPs to potentially flip in ref file: 22.14%
# Percentage of SNPs to potentially flip in libd file: 22.14%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr3.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr3
#   --pfile ref_EUR_chr3
#   --ref-allele snps_to_flip_chr3.txt 2 1
#
# Start time: Mon Aug 12 12:15:47 2024
# 257485 MiB RAM detected, ~214440 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr3.psam.
# 429002 variants loaded from ref_EUR_chr3.pvar.
# Note: No phenotype data present.
# --ref-allele: 94973 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr3.psam ... done.
# Writing ref_EUR_flipped_chr3.pvar ... .
# Writing ref_EUR_flipped_chr3.pgen ... 4591done.
# End time: Mon Aug 12 12:15:47 2024
# PLINK has been executed to flip the alleles for chromosome 3.
#
#
#
#
#
# Processing chromosome 4...
# Total SNPs in ref file: 435606
# Total SNPs in libd file: 435606
# Percentage of SNPs to potentially flip in ref file: 22.61%
# Percentage of SNPs to potentially flip in libd file: 22.61%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr4.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr4
#   --pfile ref_EUR_chr4
#   --ref-allele snps_to_flip_chr4.txt 2 1
#
# Start time: Mon Aug 12 12:15:49 2024
# 257485 MiB RAM detected, ~214355 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr4.psam.
# 435606 variants loaded from ref_EUR_chr4.pvar.
# Note: No phenotype data present.
# --ref-allele: 98489 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr4.psam ... done.
# Writing ref_EUR_flipped_chr4.pvar ... .
# Writing ref_EUR_flipped_chr4.pgen ... 4590done.
# End time: Mon Aug 12 12:15:49 2024
# PLINK has been executed to flip the alleles for chromosome 4.
#
#
#
#
#
# Processing chromosome 5...
# Total SNPs in ref file: 380613
# Total SNPs in libd file: 380613
# Percentage of SNPs to potentially flip in ref file: 21.31%
# Percentage of SNPs to potentially flip in libd file: 21.31%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr5.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr5
#   --pfile ref_EUR_chr5
#   --ref-allele snps_to_flip_chr5.txt 2 1
#
# Start time: Mon Aug 12 12:15:51 2024
# 257485 MiB RAM detected, ~214486 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr5.psam.
# 380613 variants loaded from ref_EUR_chr5.pvar.
# Note: No phenotype data present.
# --ref-allele: 81117 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr5.psam ... done.
# Writing ref_EUR_flipped_chr5.pvar ... .
# Writing ref_EUR_flipped_chr5.pgen ... 51done.
# End time: Mon Aug 12 12:15:51 2024
# PLINK has been executed to flip the alleles for chromosome 5.
#
#
#
#
#
# Processing chromosome 6...
# Total SNPs in ref file: 373979
# Total SNPs in libd file: 373979
# Percentage of SNPs to potentially flip in ref file: 21.23%
# Percentage of SNPs to potentially flip in libd file: 21.23%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr6.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr6
#   --pfile ref_EUR_chr6
#   --ref-allele snps_to_flip_chr6.txt 2 1
#
# Start time: Mon Aug 12 12:15:53 2024
# 257485 MiB RAM detected, ~214357 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr6.psam.
# 373979 variants loaded from ref_EUR_chr6.pvar.
# Note: No phenotype data present.
# Warning: --ref-allele mismatch for biallelic variant 'rs1932643'.
# Warning: --ref-allele mismatch for biallelic variant 'rs62424078'.
# Warning: --ref-allele mismatch for biallelic variant 'rs9378089'.
# 7 more allele-mismatch warnings: see log file.
# --ref-allele: 79377 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr6.psam ... done.
# Writing ref_EUR_flipped_chr6.pvar ... .
# Writing ref_EUR_flipped_chr6.pgen ... 52done.
# End time: Mon Aug 12 12:15:53 2024
# PLINK has been executed to flip the alleles for chromosome 6.
#
#
#
#
#
# Processing chromosome 7...
# Total SNPs in ref file: 345874
# Total SNPs in libd file: 345874
# Percentage of SNPs to potentially flip in ref file: 20.98%
# Percentage of SNPs to potentially flip in libd file: 20.98%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr7.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr7
#   --pfile ref_EUR_chr7
#   --ref-allele snps_to_flip_chr7.txt 2 1
#
# Start time: Mon Aug 12 12:15:54 2024
# 257485 MiB RAM detected, ~214274 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr7.psam.
# 345874 variants loaded from ref_EUR_chr7.pvar.
# Note: No phenotype data present.
# --ref-allele: 72576 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr7.psam ... done.
# Writing ref_EUR_flipped_chr7.pvar ... .
# Writing ref_EUR_flipped_chr7.pgen ... 56done.
# End time: Mon Aug 12 12:15:55 2024
# PLINK has been executed to flip the alleles for chromosome 7.
#
#
#
#
#
# Processing chromosome 8...
# Total SNPs in ref file: 336686
# Total SNPs in libd file: 336686
# Percentage of SNPs to potentially flip in ref file: 21.51%
# Percentage of SNPs to potentially flip in libd file: 21.51%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr8.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr8
#   --pfile ref_EUR_chr8
#   --ref-allele snps_to_flip_chr8.txt 2 1
#
# Start time: Mon Aug 12 12:15:56 2024
# 257485 MiB RAM detected, ~214466 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr8.psam.
# 336686 variants loaded from ref_EUR_chr8.pvar.
# Note: No phenotype data present.
# --ref-allele: 72422 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr8.psam ... done.
# Writing ref_EUR_flipped_chr8.pvar ... .
# Writing ref_EUR_flipped_chr8.pgen ... 58done.
# End time: Mon Aug 12 12:15:56 2024
# PLINK has been executed to flip the alleles for chromosome 8.
#
#
#
#
#
# Processing chromosome 9...
# Total SNPs in ref file: 253860
# Total SNPs in libd file: 253860
# Percentage of SNPs to potentially flip in ref file: 21.44%
# Percentage of SNPs to potentially flip in libd file: 21.44%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr9.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr9
#   --pfile ref_EUR_chr9
#   --ref-allele snps_to_flip_chr9.txt 2 1
#
# Start time: Mon Aug 12 12:15:57 2024
# 257485 MiB RAM detected, ~214326 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr9.psam.
# 253860 variants loaded from ref_EUR_chr9.pvar.
# Note: No phenotype data present.
# --ref-allele: 54432 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr9.psam ... done.
# Writing ref_EUR_flipped_chr9.pvar ... .
# Writing ref_EUR_flipped_chr9.pgen ... 77done.
# End time: Mon Aug 12 12:15:58 2024
# PLINK has been executed to flip the alleles for chromosome 9.
#
#
#
#
#
# Processing chromosome 10...
# Total SNPs in ref file: 305528
# Total SNPs in libd file: 305528
# Percentage of SNPs to potentially flip in ref file: 22.07%
# Percentage of SNPs to potentially flip in libd file: 22.07%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr10.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr10
#   --pfile ref_EUR_chr10
#   --ref-allele snps_to_flip_chr10.txt 2 1
#
# Start time: Mon Aug 12 12:15:59 2024
# 257485 MiB RAM detected, ~214213 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr10.psam.
# 305528 variants loaded from ref_EUR_chr10.pvar.
# Note: No phenotype data present.
# --ref-allele: 67420 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr10.psam ... done.
# Writing ref_EUR_flipped_chr10.pvar ... .
# Writing ref_EUR_flipped_chr10.pgen ... 64done.
# End time: Mon Aug 12 12:15:59 2024
# PLINK has been executed to flip the alleles for chromosome 10.
#
#
#
#
#
# Processing chromosome 11...
# Total SNPs in ref file: 293499
# Total SNPs in libd file: 293499
# Percentage of SNPs to potentially flip in ref file: 23.23%
# Percentage of SNPs to potentially flip in libd file: 23.23%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr11.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr11
#   --pfile ref_EUR_chr11
#   --ref-allele snps_to_flip_chr11.txt 2 1
#
# Start time: Mon Aug 12 12:16:05 2024
# 257485 MiB RAM detected, ~214293 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr11.psam.
# 293499 variants loaded from ref_EUR_chr11.pvar.
# Note: No phenotype data present.
# --ref-allele: 68168 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr11.psam ... done.
# Writing ref_EUR_flipped_chr11.pvar ... .
# Writing ref_EUR_flipped_chr11.pgen ... 66done.
# End time: Mon Aug 12 12:16:05 2024
# PLINK has been executed to flip the alleles for chromosome 11.
#
#
#
#
#
# Processing chromosome 12...
# Total SNPs in ref file: 278631
# Total SNPs in libd file: 278631
# Percentage of SNPs to potentially flip in ref file: 21.85%
# Percentage of SNPs to potentially flip in libd file: 21.85%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr12.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr12
#   --pfile ref_EUR_chr12
#   --ref-allele snps_to_flip_chr12.txt 2 1
#
# Start time: Mon Aug 12 12:16:09 2024
# 257485 MiB RAM detected, ~214223 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr12.psam.
# 278631 variants loaded from ref_EUR_chr12.pvar.
# Note: No phenotype data present.
# --ref-allele: 60885 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr12.psam ... done.
# Writing ref_EUR_flipped_chr12.pvar ... .
# Writing ref_EUR_flipped_chr12.pgen ... 70done.
# End time: Mon Aug 12 12:16:09 2024
# PLINK has been executed to flip the alleles for chromosome 12.
#
#
#
#
#
# Processing chromosome 13...
# Total SNPs in ref file: 225273
# Total SNPs in libd file: 225273
# Percentage of SNPs to potentially flip in ref file: 23.31%
# Percentage of SNPs to potentially flip in libd file: 23.31%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr13.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr13
#   --pfile ref_EUR_chr13
#   --ref-allele snps_to_flip_chr13.txt 2 1
#
# Start time: Mon Aug 12 12:16:11 2024
# 257485 MiB RAM detected, ~214335 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr13.psam.
# 225273 variants loaded from ref_EUR_chr13.pvar.
# Note: No phenotype data present.
# --ref-allele: 52510 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr13.psam ... done.
# Writing ref_EUR_flipped_chr13.pvar ... .
# Writing ref_EUR_flipped_chr13.pgen ... 87done.
# End time: Mon Aug 12 12:16:11 2024
# PLINK has been executed to flip the alleles for chromosome 13.
#
#
#
#
#
# Processing chromosome 14...
# Total SNPs in ref file: 192569
# Total SNPs in libd file: 192569
# Percentage of SNPs to potentially flip in ref file: 21.25%
# Percentage of SNPs to potentially flip in libd file: 21.25%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr14.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr14
#   --pfile ref_EUR_chr14
#   --ref-allele snps_to_flip_chr14.txt 2 1
#
# Start time: Mon Aug 12 12:16:12 2024
# 257485 MiB RAM detected, ~214193 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr14.psam.
# 192569 variants loaded from ref_EUR_chr14.pvar.
# Note: No phenotype data present.
# --ref-allele: 40919 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr14.psam ... done.
# Writing ref_EUR_flipped_chr14.pvar ... .
# Writing ref_EUR_flipped_chr14.pgen ... done.
# End time: Mon Aug 12 12:16:12 2024
# PLINK has been executed to flip the alleles for chromosome 14.
#
#
#
#
#
# Processing chromosome 15...
# Total SNPs in ref file: 165316
# Total SNPs in libd file: 165316
# Percentage of SNPs to potentially flip in ref file: 22.16%
# Percentage of SNPs to potentially flip in libd file: 22.16%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr15.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr15
#   --pfile ref_EUR_chr15
#   --ref-allele snps_to_flip_chr15.txt 2 1
#
# Start time: Mon Aug 12 12:16:13 2024
# 257485 MiB RAM detected, ~214285 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr15.psam.
# 165316 variants loaded from ref_EUR_chr15.pvar.
# Note: No phenotype data present.
# --ref-allele: 36627 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr15.psam ... done.
# Writing ref_EUR_flipped_chr15.pvar ... .
# Writing ref_EUR_flipped_chr15.pgen ... done.
# End time: Mon Aug 12 12:16:13 2024
# PLINK has been executed to flip the alleles for chromosome 15.
#
#
#
#
#
# Processing chromosome 16...
# Total SNPs in ref file: 179545
# Total SNPs in libd file: 179545
# Percentage of SNPs to potentially flip in ref file: 21.69%
# Percentage of SNPs to potentially flip in libd file: 21.69%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr16.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr16
#   --pfile ref_EUR_chr16
#   --ref-allele snps_to_flip_chr16.txt 2 1
#
# Start time: Mon Aug 12 12:16:14 2024
# 257485 MiB RAM detected, ~214430 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr16.psam.
# 179545 variants loaded from ref_EUR_chr16.pvar.
# Note: No phenotype data present.
# --ref-allele: 38947 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr16.psam ... done.
# Writing ref_EUR_flipped_chr16.pvar ... .
# Writing ref_EUR_flipped_chr16.pgen ... done.
# End time: Mon Aug 12 12:16:21 2024
# PLINK has been executed to flip the alleles for chromosome 16.
#
#
#
#
#
# Processing chromosome 17...
# Total SNPs in ref file: 149786
# Total SNPs in libd file: 149786
# Percentage of SNPs to potentially flip in ref file: 21.91%
# Percentage of SNPs to potentially flip in libd file: 21.91%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr17.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr17
#   --pfile ref_EUR_chr17
#   --ref-allele snps_to_flip_chr17.txt 2 1
#
# Start time: Mon Aug 12 12:16:22 2024
# 257485 MiB RAM detected, ~214332 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr17.psam.
# 149786 variants loaded from ref_EUR_chr17.pvar.
# Note: No phenotype data present.
# --ref-allele: 32821 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr17.psam ... done.
# Writing ref_EUR_flipped_chr17.pvar ... .
# Writing ref_EUR_flipped_chr17.pgen ... done.
# End time: Mon Aug 12 12:16:23 2024
# PLINK has been executed to flip the alleles for chromosome 17.
#
#
#
#
#
# Processing chromosome 18...
# Total SNPs in ref file: 171246
# Total SNPs in libd file: 171246
# Percentage of SNPs to potentially flip in ref file: 21.41%
# Percentage of SNPs to potentially flip in libd file: 21.41%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr18.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr18
#   --pfile ref_EUR_chr18
#   --ref-allele snps_to_flip_chr18.txt 2 1
#
# Start time: Mon Aug 12 12:16:24 2024
# 257485 MiB RAM detected, ~214224 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr18.psam.
# 171246 variants loaded from ref_EUR_chr18.pvar.
# Note: No phenotype data present.
# --ref-allele: 36657 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr18.psam ... done.
# Writing ref_EUR_flipped_chr18.pvar ... .
# Writing ref_EUR_flipped_chr18.pgen ... done.
# End time: Mon Aug 12 12:16:24 2024
# PLINK has been executed to flip the alleles for chromosome 18.
#
#
#
#
#
# Processing chromosome 19...
# Total SNPs in ref file: 118848
# Total SNPs in libd file: 118848
# Percentage of SNPs to potentially flip in ref file: 20.07%
# Percentage of SNPs to potentially flip in libd file: 20.07%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr19.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr19
#   --pfile ref_EUR_chr19
#   --ref-allele snps_to_flip_chr19.txt 2 1
#
# Start time: Mon Aug 12 12:16:24 2024
# 257485 MiB RAM detected, ~214053 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr19.psam.
# 118848 variants loaded from ref_EUR_chr19.pvar.
# Note: No phenotype data present.
# --ref-allele: 23855 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr19.psam ... done.
# Writing ref_EUR_flipped_chr19.pvar ... .
# Writing ref_EUR_flipped_chr19.pgen ... done.
# End time: Mon Aug 12 12:16:25 2024
# PLINK has been executed to flip the alleles for chromosome 19.
#
#
#
#
#
# Processing chromosome 20...
# Total SNPs in ref file: 133791
# Total SNPs in libd file: 133791
# Percentage of SNPs to potentially flip in ref file: 20.76%
# Percentage of SNPs to potentially flip in libd file: 20.76%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr20.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr20
#   --pfile ref_EUR_chr20
#   --ref-allele snps_to_flip_chr20.txt 2 1
#
# Start time: Mon Aug 12 12:16:25 2024
# 257485 MiB RAM detected, ~214489 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr20.psam.
# 133791 variants loaded from ref_EUR_chr20.pvar.
# Note: No phenotype data present.
# --ref-allele: 27770 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr20.psam ... done.
# Writing ref_EUR_flipped_chr20.pvar ... .
# Writing ref_EUR_flipped_chr20.pgen ... done.
# End time: Mon Aug 12 12:16:26 2024
# PLINK has been executed to flip the alleles for chromosome 20.
#
#
#
#
#
# Processing chromosome 21...
# Total SNPs in ref file: 82864
# Total SNPs in libd file: 82864
# Percentage of SNPs to potentially flip in ref file: 23.17%
# Percentage of SNPs to potentially flip in libd file: 23.17%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr21.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr21
#   --pfile ref_EUR_chr21
#   --ref-allele snps_to_flip_chr21.txt 2 1
#
# Start time: Mon Aug 12 12:16:27 2024
# 257485 MiB RAM detected, ~214284 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr21.psam.
# 82864 variants loaded from ref_EUR_chr21.pvar.
# Note: No phenotype data present.
# --ref-allele: 19203 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr21.psam ... done.
# Writing ref_EUR_flipped_chr21.pvar ... .
# Writing ref_EUR_flipped_chr21.pgen ... done.
# End time: Mon Aug 12 12:16:27 2024
# PLINK has been executed to flip the alleles for chromosome 21.
#
#
#
#
#
# Processing chromosome 22...
# Total SNPs in ref file: 75840
# Total SNPs in libd file: 75840
# Percentage of SNPs to potentially flip in ref file: 20.54%
# Percentage of SNPs to potentially flip in libd file: 20.54%
# PLINK v2.00a5.12LM AVX2 AMD (25 Jun 2024)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ref_EUR_flipped_chr22.log.
# Options in effect:
#   --make-pgen
#   --out ref_EUR_flipped_chr22
#   --pfile ref_EUR_chr22
#   --ref-allele snps_to_flip_chr22.txt 2 1
#
# Start time: Mon Aug 12 12:16:28 2024
# 257485 MiB RAM detected, ~214473 available; reserving 128742 MiB for main
# workspace.
# Using up to 12 threads (change this with --threads).
# 489 samples (0 females, 0 males, 489 ambiguous; 489 founders) loaded from
# ref_EUR_chr22.psam.
# 75840 variants loaded from ref_EUR_chr22.pvar.
# Note: No phenotype data present.
# --ref-allele: 15578 sets of allele codes rotated.
# Writing ref_EUR_flipped_chr22.psam ... done.
# Writing ref_EUR_flipped_chr22.pvar ... .
# Writing ref_EUR_flipped_chr22.pgen ... done.
# End time: Mon Aug 12 12:16:28 2024
# PLINK has been executed to flip the alleles for chromosome 22.

# %% [markdown]
# ### Verify

# %% [markdown]
# #### We should get 0% need to be flipped if we re-run script over flipped files

# %%
# Path to the PLINK binary
plink_path="./plink2"

# Path to the R script
r_script_path="/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts/generate_flip_list.R"

# Loop through chromosomes 1 to 22
for chr in {1..22}
do
  echo "Processing chromosome $chr..."

  # Define file paths for this chromosome
  ref_pvar="ref_EUR_flipped_chr${chr}.pvar"
  libd_pvar="libd_chr${chr}.pvar"
  output_file="snps_to_flip_chr${chr}.txt"

  # Call the R script to generate the flip list
  Rscript $r_script_path $ref_pvar $libd_pvar $output_file

  # Add a blank line for readability between iterations
  echo ""
  echo ""
  echo ""
  echo ""
  echo ""
done
# Out:
# Processing chromosome 1...
# Total SNPs in ref file: 448584
# Total SNPs in libd file: 448584
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 2...
# Total SNPs in ref file: 502800
# Total SNPs in libd file: 502800
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 3...
# Total SNPs in ref file: 429002
# Total SNPs in libd file: 429002
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 4...
# Total SNPs in ref file: 435606
# Total SNPs in libd file: 435606
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 5...
# Total SNPs in ref file: 380613
# Total SNPs in libd file: 380613
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 6...
# Total SNPs in ref file: 373979
# Total SNPs in libd file: 373979
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 7...
# Total SNPs in ref file: 345874
# Total SNPs in libd file: 345874
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 8...
# Total SNPs in ref file: 336686
# Total SNPs in libd file: 336686
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 9...
# Total SNPs in ref file: 253860
# Total SNPs in libd file: 253860
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 10...
# Total SNPs in ref file: 305528
# Total SNPs in libd file: 305528
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 11...
# Total SNPs in ref file: 293499
# Total SNPs in libd file: 293499
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 12...
# Total SNPs in ref file: 278631
# Total SNPs in libd file: 278631
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 13...
# Total SNPs in ref file: 225273
# Total SNPs in libd file: 225273
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 14...
# Total SNPs in ref file: 192569
# Total SNPs in libd file: 192569
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 15...
# Total SNPs in ref file: 165316
# Total SNPs in libd file: 165316
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 16...
# Total SNPs in ref file: 179545
# Total SNPs in libd file: 179545
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 17...
# Total SNPs in ref file: 149786
# Total SNPs in libd file: 149786
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 18...
# Total SNPs in ref file: 171246
# Total SNPs in libd file: 171246
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 19...
# Total SNPs in ref file: 118848
# Total SNPs in libd file: 118848
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 20...
# Total SNPs in ref file: 133791
# Total SNPs in libd file: 133791
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 21...
# Total SNPs in ref file: 82864
# Total SNPs in libd file: 82864
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%
#
#
#
#
#
# Processing chromosome 22...
# Total SNPs in ref file: 75840
# Total SNPs in libd file: 75840
# Percentage of SNPs to potentially flip in ref file: 0.00%
# Percentage of SNPs to potentially flip in libd file: 0.00%

# %% [markdown]
# #### pvar files should match now. Let's check this in notebook 30 in R kernel.
