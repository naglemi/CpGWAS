# %% [markdown]
# # Match up SNP, methylation and covariate files to be analyzed together

# %% [markdown]
# As part of this, we will determine which methylation sites have coverage in the SNP data and should be analyzed.

# %% [markdown]
# ## Match SNP and methylation files

# %%
library(stringr)

# %%
library(data.table)

# %%
SNP_files <- list.files("/expanse/lustre/projects/jhu152/naglemi/mwas/gwas/",
                        #"/dcs04/lieber/statsgen/shizhong/michael/mwas/gwas",
                        pattern = "pgen", full.names = TRUE)
SNP_files <- SNP_files[ordered(SNP_files)]

SNP_files_libd <- data.frame(SNPs_libd = SNP_files[grepl("libd", SNP_files)])
SNP_files_ref_EUR <- data.frame(SNPs_ref_EUR = SNP_files[grepl("ref_EUR", SNP_files)])

SNP_files_libd$Chr <- as.numeric(stringr::str_extract(SNP_files_libd$SNPs_libd, "(?<=chr)\\d+"))
SNP_files_ref_EUR$Chr <- as.numeric(stringr::str_extract(SNP_files_ref_EUR$SNPs_ref_EUR, "(?<=chr)\\d+"))

SNP_files <- merge(SNP_files_libd, SNP_files_ref_EUR)

# %%
meth_files <- list.files("/expanse/lustre/projects/jhu152/naglemi/mwas/pheno", recursive = TRUE, pattern = "rda", full.names = TRUE)

# %% [markdown]
# We will bring in original dlpfc and hippo methylation files, and the caudate files that were reprocessed to store everything in given files (where previously those ones had h5 pointers)

# %%
#meth_caud <- data.frame(meth_caud = meth_files[grepl("caud", meth_files)])
meth_dlpfc <- data.frame(meth_dlpfc = meth_files[grepl("dlpfc", meth_files)])
meth_hippo <- data.frame(meth_hippo = meth_files[grepl("hippo", meth_files)])

# %%
meth_caud_files <- list.files("/expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud",
                              recursive = TRUE, pattern = "rda", full.names = TRUE)
meth_caud_files <- meth_caud_files[!grepl("pointers", meth_caud_files)]
meth_caud <- data.frame(meth_caud = meth_caud_files[grepl("caud", meth_caud_files)])

# %%
dim(meth_caud)
# Out:
# [1] 66  1

# %%
head(meth_dlpfc)
# Out:
#   meth_dlpfc
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr10_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr10_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr10_EA.rda

# %%
head(meth_caud)
# Out:
#   meth_caud
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr10_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr10_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr10_EA.rda

# %%
meth_caud$Chr <- as.numeric(str_extract(meth_caud$meth_caud, "(?<=chr)\\d+(?=_)"))
meth_dlpfc$Chr <- as.numeric(str_extract(meth_dlpfc$meth_dlpfc, "(?<=chr)\\d+(?=_)"))
meth_hippo$Chr <- as.numeric(str_extract(meth_hippo$meth_hippo, "(?<=chr)\\d+(?=_)"))

# %%
reshape_and_rename_corrected <- function(data, region) {
  # Extracting the type (AA, EA, all) based on the filename pattern
  data$Type <- gsub(paste0(".*", region, "/out/chr\\d+_(AA|EA|all)\\.rda"), "\\1", data[[1]])
  
  # Creating a wide dataframe with separate columns for AA, EA, and all
  wide_data <- reshape(data, idvar = "Chr", timevar = "Type", direction = "wide")
  
  # Correcting column names to include only the region and type without redundant parts
  colnames(wide_data)[-1] <- sapply(colnames(wide_data)[-1], function(x) {
    paste(region, gsub(".*\\.(AA|EA|all)$", "\\1", x), sep = "_")
  })
  
  return(wide_data)
}

# Applying the corrected function to each dataset
meth_caud_wide <- reshape_and_rename_corrected(meth_caud, "caud")
meth_dlpfc_wide <- reshape_and_rename_corrected(meth_dlpfc, "dlpfc")
meth_hippo_wide <- reshape_and_rename_corrected(meth_hippo, "hippo")

merged_data <- Reduce(function(x, y) merge(x, y, by = "Chr", all = TRUE), list(meth_caud_wide, meth_dlpfc_wide, meth_hippo_wide))

# %%
head(merged_data)
# Out:
#   Chr caud_AA
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
#   caud_all
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_all.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_all.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_all.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_all.rda
#   caud_EA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_EA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_EA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_EA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_EA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_EA.rda
#   dlpfc_AA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr6_AA.rda
#   dlpfc_all
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_all.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr2_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr3_all.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr4_all.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr5_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr6_all.rda
#   dlpfc_EA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_EA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr2_EA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr3_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr4_EA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr5_EA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr6_EA.rda
#   hippo_AA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr6_AA.rda
#   hippo_all
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr1_all.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr2_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr3_all.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr4_all.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr5_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr6_all.rda
#   hippo_EA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr1_EA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr2_EA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr3_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr4_EA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr5_EA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr6_EA.rda

# %%
head(SNP_files)
# Out:
#   Chr SNPs_libd
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   SNPs_ref_EUR
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//ref_EUR_chr1.pgen
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//ref_EUR_chr2.pgen
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//ref_EUR_chr3.pgen
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//ref_EUR_chr4.pgen
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//ref_EUR_chr5.pgen
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//ref_EUR_chr6.pgen

# %%
merged <- merge(SNP_files, merged_data)

# %%
data.table::fwrite(merged, "09-OUT_matched_SNP_meth_files.csv")

# %% [markdown]
# ## Determine first, last position for each SNP, methylation file pair

# %%
merged$SNPs_ref_EUR <- NULL

# %%
head(merged)
# Out:
#   Chr SNPs_libd
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   caud_AA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
#   caud_all
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_all.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_all.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_all.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_all.rda
#   caud_EA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_EA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_EA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_EA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_EA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_EA.rda
#   dlpfc_AA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr6_AA.rda
#   dlpfc_all
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_all.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr2_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr3_all.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr4_all.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr5_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr6_all.rda
#   dlpfc_EA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr1_EA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr2_EA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr3_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr4_EA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr5_EA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/dlpfc/out/chr6_EA.rda
#   hippo_AA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr6_AA.rda
#   hippo_all
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr1_all.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr2_all.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr3_all.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr4_all.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr5_all.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr6_all.rda
#   hippo_EA
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr1_EA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr2_EA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr3_EA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr4_EA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr5_EA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/hippo/out/chr6_EA.rda

# %%
# Load data.table
library(data.table)

# Assuming 'merged' is your data.table with the wide format
# Set it as a data.table if it's not already
setDT(merged)

# Melt the data.table from wide to long format
# id.vars = "Chr" to keep the chromosome column as identifier
# measure.vars patterns to match SNP data and methylation data columns
long_format <- melt(
  merged,
  id.vars = "Chr",
  measure.vars = patterns("^SNPs_libd", "caud_.*|dlpfc_.*|hippo_.*"),
  value.name = c("SNP_data", "methylation_data"),
  variable.name = "type"
)

# Adjust 'type' to distinguish between SNP and methylation data if needed
long_format[, type := ifelse(grepl("SNPs_libd", type), "pgen", "rda")]

# View the head of the long format table
head(long_format)
# Out:
#   Chr type SNP_data
# 1 1   rda  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   rda  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   rda  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   rda  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   rda  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   rda  /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda

# %%
# Load the data.table library
library(data.table)

# Assuming 'merged' is already a data.table
# If it's not, convert it using setDT(merged)

# Select SNP column and reshape methylation columns into long format
# Extract column names for methylation data
methylation_columns <- grep("caud_|dlpfc_|hippo_", names(merged), value = TRUE)

# Create a long format table
long_format <- melt(merged, id.vars = "Chr", measure.vars = methylation_columns, variable.name = "Methylation_Type", value.name = "methylation_data")

# Add SNP data to the long format data.table
long_format[, SNP_data := merged[.SD, on = "Chr", SNPs_libd]]

# Remove Methylation_Type column and arrange columns as specified
long_format[, `Methylation_Type` := NULL]
setcolorder(long_format, c("Chr", "SNP_data", "methylation_data"))

# Result
head(long_format)
# Out:
#   Chr SNP_data
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda

# %%
library(bsseq)
# Out:
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians

# %% [markdown]
# ### Test on first row

# %%
dim(long_format)
head(long_format)
Sys.time()
# Out:
# [1] 198   3
#   Chr SNP_data
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
# [1] "2024-04-08 13:19:23 PDT"

# %%
i <- 1

# %%
pvar <- fread(gsub("pgen", "pvar", long_format$SNP_data[i]))[, 1:3]
load(long_format$methylation_data[i])
first_SNP_position <- min(pvar$POS)
last_SNP_position <- max(pvar$POS)
first_meth_position <- min(start(BSobj2))
last_meth_position <- max(start(BSobj2))
window_size <- 10000
# Find first methylation index with SNP coverage
meth_indices_w_SNP_coverage <- which(start(BSobj2) >= (first_SNP_position - window_size) &
                                   start(BSobj2) <= (last_SNP_position + window_size))
first_meth_index_with_SNP_coverage <- min(meth_indices_w_SNP_coverage)
# Correcting the approach to find the last methylation index with SNP coverage
last_meth_index_with_SNP_coverage <- max(meth_indices_w_SNP_coverage)

first_meth_value_with_SNP_coverage <- start(BSobj2)[first_meth_index_with_SNP_coverage]
last_meth_value_with_SNP_coverage <- start(BSobj2)[last_meth_index_with_SNP_coverage]

# %%
first_meth_index_with_SNP_coverage
# Out:
# [1] 8982

# %%
first_SNP_position
# Out:
# [1] 1079456

# %%
max(pvar$POS)
# Out:
# [1] 248908368

# %%
if(!identical(start(BSobj2), sort(start(BSobj2)))) {
  stop("start positions in BSobj2 are not ordered")
}

BSobj2 <- NULL

# %%
Sys.time()
# Out:
# [1] "2024-04-08 13:22:10 PDT"

# %% [markdown]
# ### Sanity checks

# %%
first_meth_value_with_SNP_coverage
# Out:
# [1] 1069461

# %%
last_meth_value_with_SNP_coverage
# Out:
# [1] 248918358

# %%
first_meth_index_with_SNP_coverage
# Out:
# [1] 8982

# %%
last_meth_index_with_SNP_coverage
# Out:
# [1] 2202702

# %% [markdown]
# ### Deploy

# %%
i

# %%
BSobj2

# %%
long_format$first_snp_position <-
long_format$last_snp_position <-
long_format$last_meth_index <-
long_format$first_meth_position <- 
long_format$last_meth_position <-
long_format$first_meth_index_with_SNP_coverage <-
long_format$last_meth_index_with_SNP_coverage <- 
long_format$first_meth_value_with_SNP_coverage <-
long_format$last_meth_value_with_SNP_coverage <- 
NA

start_time <- Sys.time()

for(i in 1:nrow(long_format)){
    print(i)
    iter_start_time <- Sys.time()
    
    pvar <- fread(gsub("pgen", "pvar", long_format$SNP_data[i]))[, 1:3]
    load(long_format$methylation_data[i])

    if(!identical(start(BSobj2), sort(start(BSobj2)))) {
      stop("start positions in BSobj2 are not ordered")
    }
    
    first_SNP_position <- min(pvar$POS)
    last_SNP_position <- max(pvar$POS)
    first_meth_position <- min(start(BSobj2))
    last_meth_position <- max(start(BSobj2))
    window_size <- 10000
    # Find first methylation index with SNP coverage
    meth_indices_w_SNP_coverage <- which(start(BSobj2) >= (first_SNP_position - window_size) &
                                         start(BSobj2) <= (last_SNP_position + window_size))
    first_meth_index_with_SNP_coverage <- min(meth_indices_w_SNP_coverage)
    # Correcting the approach to find the last methylation index with SNP coverage
    last_meth_index_with_SNP_coverage <- max(meth_indices_w_SNP_coverage)

    first_meth_value_with_SNP_coverage <- start(BSobj2)[first_meth_index_with_SNP_coverage]
    last_meth_value_with_SNP_coverage <- start(BSobj2)[last_meth_index_with_SNP_coverage]

    long_format$first_snp_position[i] <- first_SNP_position
    long_format$last_snp_position[i] <- last_SNP_position
    long_format$last_meth_index[i] <- length(start(BSobj2))
    BSobj2 <- NULL
    long_format$first_meth_position[i] <- first_meth_position
    long_format$last_meth_position[i] <- last_meth_position
    
    long_format$first_meth_index_with_SNP_coverage[i] <- first_meth_index_with_SNP_coverage
    long_format$last_meth_index_with_SNP_coverage[i] <- last_meth_index_with_SNP_coverage
    long_format$first_meth_value_with_SNP_coverage[i] <- first_meth_value_with_SNP_coverage
    long_format$last_meth_value_with_SNP_coverage[i] <- last_meth_value_with_SNP_coverage
    
    iter_end_time <- Sys.time()
    elapsed_time_per_iter <- iter_end_time - iter_start_time
    total_elapsed_time <- Sys.time() - start_time
    average_time_per_iter <- total_elapsed_time / i
    estimated_total_time <- average_time_per_iter * nrow(long_format)
    estimated_time_remaining <- estimated_total_time - total_elapsed_time

    print(sprintf("Ran %d of %d so far. Estimated time remaining: %s minutes\n", 
                i, nrow(long_format), round(as.numeric(estimated_time_remaining) / 60, 2)))

}

# %%
fwrite(long_format, "09-OUT_matched_files_and_indices_to_test_a3.csv")

# %%
long_format_a2 <- fread("09-OUT_matched_files_and_indices_to_test_a2.csv")

# %%
long_format <- fread("09-OUT_matched_files_and_indices_to_test_a3.csv")

# %%
head(long_format_a2)
# Out:
#   Chr SNP_data
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
#   last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1 248918358                         1069461
# 2 241863783                           10001
# 3 198099789                           11602
# 4 189877411                           69399
# 5 181172584                           44104
# 6 170619093                          192453
#   last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1 2202702                           8982
# 2 2019984                              1
# 3 1538467                              1
# 4 1387731                              1
# 5 1409038                              1
# 6 1412543                           1138

# %%
head(long_format)
# Out:
#   Chr SNP_data
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
#   last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1 248918358                         1069461
# 2 241863783                           10001
# 3 198099789                           11602
# 4 189877411                           69399
# 5 181172584                           44104
# 6 170619093                          192453
#   last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1 2202702                           8982
# 2 2019984                              1
# 3 1538467                              1
# 4 1387731                              1
# 5 1409038                              1
# 6 1412543                           1138
#   last_meth_position first_meth_position last_meth_index last_snp_position
# 1 248932459          792731              2202819         248908368
# 2 242110081           10001              2025108         241853790
# 3 198099789           11602              1538467         198114462
# 4 190048422           69399              1388072         189974231
# 5 181172584           44104              1409038         181286423
# 6 170745956           60470              1413875         170609176
#   first_snp_position
# 1 1079456
# 2   10797
# 3   18519
# 4   68894
# 5   25361
# 6  202452

# %% [markdown]
# Started around 2pm

# %% [markdown]
# ## Prepare covariate files

# %% [markdown]
# ### Get paths

# %%
# genotype_pc <- list.files("/dcs04/lieber/statsgen/shizhong/database/libd/genotype/postmortem/topmed/merge_H650_1M_2.5M_5M/EA_AA/all/pca_wgbs",
#                           recursive = TRUE,
#                           full.names = TRUE,
#                           pattern = "pca.eigenvec")

# genotype_pc <- data.frame(genotype_pc_path = genotype_pc, brain_region = c("caud", "dlpfc", "hippo"))

# genotype_pc <- rbind(genotype_pc, genotype_pc, genotype_pc)

# genotype_pc$subpopulation <- c("EA", "EA", "EA", "AA", "AA", "AA", "all", "all", "all")

# genotype_pc

# meth_pc <- list.files("/dcs04/lieber/statsgen/shizhong/michael/mwas/pheno/",
#                       recursive = TRUE,
#                       full.names = TRUE,
#                       pattern = "pc_")

# meth_pc <- data.table(meth_pc_path = meth_pc)

# meth_pc[, subpopulation := sub(".*pc_(.*)\\.csv", "\\1", meth_pc_path)]
# meth_pc[, brain_region := sub(".*/pheno//(.*)/out/.*", "\\1", meth_pc_path)]

# meth_pc

# cov3 <- "/dcs04/lieber/statsgen/shizhong/database/libd/genotype/postmortem/phenotype/pheno_PC"

# %% [markdown]
# ### Format, merge with data frame

# %%
# long_format[, subpopulation := sub(".*_(.*)\\.rda", "\\1", methylation_data)]
# long_format[, brain_region := sub(".*/pheno/(.*)/out/.*", "\\1", methylation_data)]

# merged <- merge(long_format, genotype_pc)

# merged <- merge(merged, meth_pc)

# merged$pheno_pc <- cov3

# head(merged)

# %% [markdown]
# ### Unite covariate files for each row into a single file

# %%
# outdir <- "/dcs04/lieber/statsgen/mnagle/mwas/full_covariates/"
# #dir.create(outdir)

# %% [markdown]
# #### test for first row

# %%
# colnames(merged)

# dim(merged)



# merged_pc_only <- unique(merged[, c(1, 2, 10:12)])

# merged_pc_only

# i <- 1

# geno_pc <- fread(merged$genotype_pc_path[i])
# meth_pc <- fread(merged$meth_pc_path[i])
# pheno_pc <- fread(merged$pheno_pc[i])

# meth_pc <- meth_pc[, 1:11]

# geno_pc <- geno_pc[, 1:4]

# pheno_pc <- pheno_pc[, c(2, 6, 7, 8)]

# colnames(meth_pc)[1] <- colnames(pheno_pc)[1] <- colnames(geno_pc)[1] <- "ID"

# colnames(meth_pc)[2:11] <- paste0("methPC", 1:10)

# colnames(geno_pc)[2:4] <- paste0("genoPC", 1:3)

# geno_pc$ID <- gsub("Br0", "Br", geno_pc$ID)
# pheno_pc$ID <- gsub("Br0", "Br", pheno_pc$ID)
# meth_pc$ID <- gsub("Br0", "Br", meth_pc$ID)

# #dim(meth_pc)
# #dim(geno_pc)
# #dim(pheno_pc)

# unified_pc <- merge(geno_pc, pheno_pc)
# #dim(unified_pc)
# unified_pc <- merge(unified_pc, meth_pc)
# #dim(unified_pc)

# if(nrow(unified_pc) != nrow(meth_pc)){
#     stop(paste0("We have a mismatch for row ", i))
#     }

# outname <- paste0(outdir, merged$subpopulation[i], "_", merged$brain_region[i], ".csv")
# fwrite(merged_pc_only, outname)

# %% [markdown]
# #### Run for all

# %%
# for(i in 1:nrow(merged_pc_only)){
#     geno_pc <- fread(merged_pc_only$genotype_pc_path[i])
#     meth_pc <- fread(merged_pc_only$meth_pc_path[i])
#     pheno_pc <- fread(merged_pc_only$pheno_pc[i])

#     meth_pc <- meth_pc[, 1:11]

#     geno_pc <- geno_pc[, 1:4]

#     pheno_pc <- pheno_pc[, c(2, 6, 7, 8)]

#     colnames(meth_pc)[1] <- colnames(pheno_pc)[1] <- colnames(geno_pc)[1] <- "ID"

#     colnames(meth_pc)[2:11] <- paste0("methPC", 1:10)

#     colnames(geno_pc)[2:4] <- paste0("genoPC", 1:3)

#     geno_pc$ID <- gsub("Br0", "Br", geno_pc$ID)
#     pheno_pc$ID <- gsub("Br0", "Br", pheno_pc$ID)
#     pheno_pc$Dx <- gsub("chizo", "CZ", pheno_pc$Dx)
#     meth_pc$ID <- gsub("Br0", "Br", meth_pc$ID)

#     #dim(meth_pc)
#     #dim(geno_pc)
#     #dim(pheno_pc)

#     unified_pc <- merge(geno_pc, meth_pc)
#     #dim(unified_pc)
#     unified_pc <- merge(unified_pc, pheno_pc)
#     #dim(unified_pc)

#     if(nrow(unified_pc) != nrow(meth_pc)){
#         print(setdiff(meth_pc$ID, unified_pc$ID))
#         warning(paste0("We have a mismatch for row ", i))
#         print(merged_pc_only[i, ])
#         }
#     outname <- paste0(outdir, merged_pc_only$subpopulation[i], "_", merged_pc_only$brain_region[i], ".csv")
#     fwrite(unified_pc, outname)
    
#     }


# outname

# merged$full_covariate_path <-
# paste0(outdir, merged$subpopulation, "_", merged$brain_region, ".csv")

# fread("/dcs04/lieber/statsgen/mnagle/mwas/full_covariates/AA_caud.csv")

# %% [markdown]
# ## Match covariate files to corresponding datasets

# %%
list.files("../../full_covariates/")
# Out:
# [1] "AA_caud.csv"   "AA_dlpfc.csv"  "AA_hippo.csv"  "all_caud.csv"
# [5] "all_dlpfc.csv" "all_hippo.csv" "EA_caud.csv"   "EA_dlpfc.csv"
# [9] "EA_hippo.csv"

# %%
head(long_format)
# Out:
#   Chr SNP_data
# 1 1   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr1.pgen
# 2 2   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr2.pgen
# 3 3   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr3.pgen
# 4 4   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr4.pgen
# 5 5   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr5.pgen
# 6 6   /expanse/lustre/projects/jhu152/naglemi/mwas/gwas//libd_chr6.pgen
#   methylation_data
# 1 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr1_AA.rda
# 2 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr2_AA.rda
# 3 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr3_AA.rda
# 4 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr4_AA.rda
# 5 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr5_AA.rda
# 6 /expanse/lustre/projects/jhu152/naglemi/mwas/pheno/caud/out/chr6_AA.rda
#   last_meth_value_with_SNP_coverage first_meth_value_with_SNP_coverage
# 1 248918358                         1069461
# 2 241863783                           10001
# 3 198099789                           11602
# 4 189877411                           69399
# 5 181172584                           44104
# 6 170619093                          192453
#   last_meth_index_with_SNP_coverage first_meth_index_with_SNP_coverage
# 1 2202702                           8982
# 2 2019984                              1
# 3 1538467                              1
# 4 1387731                              1
# 5 1409038                              1
# 6 1412543                           1138

# %%
long_format$population <- str_split_fixed(long_format$methylation_data,
                                          pattern = "_",
                                          2)[, 2]

# %%
long_format$population <- gsub("\\.rda", "", long_format$population)

# %%
long_format$population
# Out:
#   [1] "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"
#  [13] "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "all" "all"
#  [25] "all" "all" "all" "all" "all" "all" "all" "all" "all" "all" "all" "all"
#  [37] "all" "all" "all" "all" "all" "all" "all" "all" "EA"  "EA"  "EA"  "EA"
#  [49] "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"
#  [61] "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"
#  [73] "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"
#  [85] "AA"  "AA"  "AA"  "AA"  "all" "all" "all" "all" "all" "all" "all" "all"
#  [97] "all" "all" "all" "all" "all" "all" "all" "all" "all" "all" "all" "all"
# [109] "all" "all" "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"
# [121] "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"
# [133] "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"
# [145] "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "AA"  "all" "all"
# [157] "all" "all" "all" "all" "all" "all" "all" "all" "all" "all" "all" "all"
# [169] "all" "all" "all" "all" "all" "all" "all" "all" "EA"  "EA"  "EA"  "EA"
# [181] "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"  "EA"
# [193] "EA"  "EA"  "EA"  "EA"  "EA"  "EA"

# %%
long_format$region <- str_split_fixed(long_format$methylation_data,
                                      pattern = "pheno/",
                                      2)[, 2]
long_format$region <- str_split_fixed(long_format$region,
                                      pattern = "/out",
                                      2)[, 1]

# %%
head(long_format$region)
# Out:
# [1] "caud" "caud" "caud" "caud" "caud" "caud"

# %%
list.files("/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates")
# Out:
# [1] "AA_caud.csv"   "AA_dlpfc.csv"  "AA_hippo.csv"  "all_caud.csv"
# [5] "all_dlpfc.csv" "all_hippo.csv" "EA_caud.csv"   "EA_dlpfc.csv"
# [9] "EA_hippo.csv"

# %%
long_format$cov_file <- paste0("/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/",
                               long_format$population,
                               "_",
                               long_format$region,
                               ".csv")

# %%
file.exists(long_format$cov_file[1])
# Out:
# [1] TRUE

# %%
fwrite(long_format, "09-OUT_matched_SNP_meth_cov.csv")

# %% [markdown]
# ## Inspect files

# %%
files <- unique(long_format$cov_file)

# %%
files
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv"
# [2] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/all_caud.csv"
# [3] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_caud.csv"
# [4] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_dlpfc.csv"
# [5] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/all_dlpfc.csv"
# [6] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_dlpfc.csv"
# [7] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_hippo.csv"
# [8] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/all_hippo.csv"
# [9] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/EA_hippo.csv"

# %%
for(file in files){
    print(file)
    file_in <- fread(file)
    print(file_in)
    cat("\n\n")
}
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates/AA_caud.csv"
#          ID   genoPC1     genoPC2    genoPC3    methPC1    methPC2     methPC3
#      <char>     <num>       <num>      <num>      <num>      <num>       <num>
#   1: Br1003 0.0591231 -0.03980770  0.0205308 -157.04647   22.43150   -3.613153
#   2: Br1004 0.0507512  0.01670030 -0.0235019 -207.97793   14.56387  -48.109417
#   3: Br1007 0.0683202  0.00502359 -0.0595899  119.29338 -184.28704 -127.987516
#   4: Br1017 0.0685061 -0.00844357 -0.0109324  148.35140  -89.71558  -97.742602
#   5: Br1021 0.0596699  0.00367841  0.0479552  453.47100 -132.38714   35.349695
#  ---
# 160:  Br948 0.0639954  0.00695405 -0.0100903  413.58583 -263.70724    4.226894
# 161:  Br949 0.0712634 -0.02716360  0.0572070 -200.93232  265.80379   56.822449
# 162:  Br963 0.0120633  0.01905100 -0.0894283  -27.92241 -144.83283  -66.482063
# 163:  Br991 0.0436291  0.01022270 -0.0078481  -42.06156 -116.78523 -130.518346
# 164:  Br993 0.0646887  0.01978440 -0.0513997  -19.51001 -109.27932  -76.972489
#          methPC4    methPC5     methPC6     methPC7     methPC8   methPC9
#            <num>      <num>       <num>       <num>       <num>     <num>
#   1:   28.587802 -165.83079   15.491404   27.347098   68.146346 -83.14472
#   2:  -48.368597   65.47954 -174.436205  -40.363495 -103.813378  11.08724
#   3:    8.047659  100.51821  112.404812  -44.079714  -13.331837 109.55059
#   4:    7.072870  -78.40472   77.029617  -33.334885  -34.948204  73.88633
#   5:   80.759933  123.87860  -39.433812 -122.191818   64.627124 -62.89107
#  ---
# 160:   89.551899   99.99237   49.852902  -83.637729  -21.617751  60.49754
# 161:   55.415802   85.21831   30.102630  -35.354101    8.835777  68.86163
# 162:   -1.418709 -178.63591   22.689742   12.902745   43.021195  18.93760
# 163: -121.402176  142.89865 -116.952419   42.139084  -77.185461 -27.19868
# 164:  -29.740514  -91.02831   -3.745881   -8.245914  -86.432950  20.17579
#        methPC10      Dx   Age    Sex
#           <num>  <char> <num> <char>
#   1:   74.40552 Control 52.57      F
#   2:  -84.67051 Control 21.01      M
#   3:   55.89200 Control 57.10      M
#   4:   65.62252 Control 48.42      F
#   5:  -25.93989     SCZ 63.18      M
#  ---
# 160:  -77.51143 Control 45.91      M
# 161: -100.62874 Control 18.05      M
# 162:   25.76437     SCZ 62.63      F
# 163:  -91.46101 Control 35.24      M
# 164:   54.41147 Control 30.48      F
#
#
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/full_covariates