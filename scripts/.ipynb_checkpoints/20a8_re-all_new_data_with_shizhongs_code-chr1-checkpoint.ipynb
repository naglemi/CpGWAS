# %% [markdown]
# # Compare MWAS methods for sanity tests and troubleshooting

# %% [markdown]
# In this version, we use the full new SNP set with a selected window

# %% [markdown]
# # Pick the regions we will test

# %%
library(data.table)

prev_hits <- fread("
Chr     pos        old_z       old_p
11   38247902        -27.1535308285104       2.30024742330298e-162
2    47933357        18.3327793004811        4.53147699327216e-75
7    1987910         10.1255085321387        4.25759742738181e-24
7    1987896         10.1255085321387        4.25759742738189e-24
7    1987797         10.0241523897721        1.19379483108027e-23
7    1987778         10.0105851568856        1.36940148731912e-23
12   2194742         -10.0072634920486       1.41615523554955e-23
")

# %%
#df <- fread("09.5-OUT_matched_SNP_meth_cov_chunked_EXPANSE_a2.csv")

# %%
df <- fread("09-OUT_matched_SNP_meth_cov_a2.csv")

# %% [markdown]
# ## Try original code

# %%
###### model: learn elastic net model on training data 
######---------Input: trainX, trainY
######---------Return: selected features and coefficents

# original
elastic.net <- function(trainX,trainY){
    if(nrow(trainX)!=length(trainY)){
            stop("Number of observations is differerent")
    } 

    # optimize alpha---mixing parameter  
    a <- 0.5
    search <- foreach(ai = a, .combine = rbind) %dopar% {
        cv.fit <- cv.glmnet(
                        trainX,
                        trainY,
                        nfold = 5,
                        type.measure = "mse",
                        paralle = TRUE,
                        alpha = ai
                        )
        data.frame(
                        cvm = min(cv.fit$cvm),
                        lambda = cv.fit$lambda.min,
                        alpha = ai
                        )
        } 
    cv.opt <- search[search$cvm == min(search$cvm),] 

        # fit model by optimized alpha and lambda
        yfit = glmnet(
        trainX,
        trainY,
        lambda = cv.opt$lambda,
        alpha = cv.opt$alpha
                )       
        idf <- coef(yfit)
        idx <- which(idf != 0)
        selectf <- data.frame(
                features = idf@Dimnames[[1]][idx], 
                coefs = idf [idx]
        )
}

# modified to use lambda 1se and appropriate cvm
elastic.net <- function(trainX,trainY){
    if(nrow(trainX)!=length(trainY)){
            stop("Number of observations is differerent")
    } 

    # optimize alpha---mixing parameter  
    a <- 0.5
    search <- foreach(ai = a, .combine = rbind) %dopar% {
        set.seed(42)
        cv.fit <- cv.glmnet(
                        trainX,
                        trainY,
                        nfold = 5,
                        type.measure = "mse",
                        paralle = TRUE,
                        alpha = ai
                        )
        print(paste0("Dim of trainX: ", dim(trainX)))
        print(paste0("Len of trainY: ", length(trainY)))
        coef_matrix <- as.matrix(coef(cv.fit))

        non_zero_coefs <- coef_matrix[coef_matrix != 0, , drop = FALSE]
        print("Coefficients when fitting: ")
        print(non_zero_coefs)

        data.frame(
                        cvm = cv.fit$cvm[cv.fit$lambda == cv.fit$lambda.1se],
                        lambda = cv.fit$lambda.1se,
                        alpha = ai
                        )
        } 
    cv.opt <- search[search$cvm == min(search$cvm),] 

        # fit model by optimized alpha and lambda
    set.seed(42)
    yfit <- glmnet(
    trainX,
    trainY,
    lambda = cv.opt$lambda,
    alpha = cv.opt$alpha)

    coef_matrix <- as.matrix(coef(yfit))

    non_zero_coefs <- coef_matrix[coef_matrix != 0, , drop = FALSE]
    print("Coefficients when optimal: ")
    print(non_zero_coefs)

    idf <- coef(yfit)
    idx <- which(idf != 0)
    selectf <- data.frame(
            features = idf@Dimnames[[1]][idx], 
            coefs = idf [idx]
    )
}

MWAS <- function(gwas, weight, geno){
        z <- gwas %*% weight
        z.cor <- cor(geno)
        se <- sqrt(weight %*%  z.cor %*%  weight)
        z <- z/se
        p=pnorm(abs(z),lower.tail=F)*2
        return(c(z, p))
}

# %%
df <- df[which(df$Chr == 7), ]

# %%
i <- 2

# %%
library("glmnet")
library("e1071")
library("doParallel")

set.seed(2018)
wind <- c(5000,10000)
# output directory
#outd <- "/dcl02/lieber/shan/shizhong/finemapping/GWAS/tags/scz3/mwas/chr22/1/"
outd <- "20-OUT_original_mwas_sanity_test/"
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel

# %% [markdown]
# ## Replace all old objects with new objects in same format

# %%
load("p1.rda", verbose = TRUE)
# Out:
# Loading objects:
#   snp.gwas2
#   snp.1kg.eur2
#   map.1kg.eur2
#   snp2
#   map2
#   p
#   BSsample

# %% [markdown]
# ### SNPs

# %%
p[1:10, 1:10]
# Out:
#         [,1]      [,2]      [,3]      [,4]      [,5]      [,6]      [,7]
# 1980077 0.9623693 0.9533113 0.9488137 0.9382598 0.9446401 0.9215182 0.9263652
# 1980101 0.9623933 0.9536637 0.9487929 0.9372716 0.9453945 0.9216584 0.9256115
# 1980129 0.9623260 0.9543107 0.9485887 0.9362757 0.9460740 0.9218622 0.9248481
# 1980136 0.9622831 0.9545096 0.9484938 0.9360728 0.9462013 0.9219193 0.9247144
# 1980145 0.9622125 0.9547853 0.9483458 0.9358404 0.9463407 0.9219962 0.9245785
# 1980179 0.9617977 0.9560054 0.9475364 0.9352418 0.9466390 0.9223291 0.9244150
# 1980183 0.9617343 0.9561653 0.9474163 0.9351995 0.9466520 0.9223756 0.9244306
# 1980193 0.9615631 0.9565781 0.9470942 0.9351188 0.9466655 0.9224991 0.9244996
# 1980205 0.9613345 0.9570958 0.9466676 0.9350679 0.9466476 0.9226612 0.9246379
# 1980239 0.9605591 0.9586691 0.9452337 0.9351803 0.9464118 0.9231993 0.9253325
#         [,8]      [,9]      [,10]
# 1980077 0.9588217 0.9330597 0.9588301
# 1980101 0.9593576 0.9326077 0.9595451
# 1980129 0.9598699 0.9323198 0.9601973
# 1980136 0.9599708 0.9323138 0.9603281
# 1980145 0.9600847 0.9323456 0.9604767
# 1980179 0.9603628 0.9328418 0.9608582
# 1980183 0.9603806 0.9329368 0.9608897
# 1980193 0.9604121 0.9332054 0.9609580
# 1980205 0.9604260 0.9335838 0.9610206
# 1980239 0.9603334 0.9349537 0.9610909

# %% [markdown]
# ### Methylation data

# %%
suppressWarnings(library(bsseq))
# Out:
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, unname
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians

# %%
# load data for mwas
# load("./rda/caudate_mwas_data_chr22.rda")
load(df$methylation_data[i])

p <- getMeth(BSobj2)


rownames(p) <- start(BSobj2)

sites_to_test <- which(start(BSobj2) >= (1987910 - 500) & start(BSobj2) <= (1987910 + 500))
p <- p[sites_to_test, ]

# candidate cg
cg <- as.numeric(rownames(p))

# regress out covariates
#load("covs_for_meqtl.rda")

# %% [markdown]
# ### covariates

# %%
covs <- fread(df$cov_file[i])
covs <- t(covs)
colnames(covs) <- covs[1, ]
covs <- covs[2:nrow(covs), ]
# transpose so we have same orientation as original code

# %% [markdown]
# ### Regress methylation data over covariates

# %%
BSobj2$brnum <- gsub("Br0", "Br", BSobj2$brnum)
colnames(covs) <- gsub("Br0", "Br", colnames(covs))

# %%
mat <- match(BSobj2$brnum,colnames(covs)) 
covs <- t(covs[,mat])
p.residual=matrix(NA,dim(p)[1],dim(p)[2])

# %%
rownames(covs)[is.na(covs[, 'genoPC1'])] <- BSobj2$brnum[is.na(covs[, 'genoPC1'])]

# %%
colnames(p.residual) <- BSobj2$brnum

# %%
covs <- as.data.frame(covs)
# Convert all columns except Dx and Sex from character to numeric
cols_to_convert <- setdiff(names(covs), c("Dx", "Sex"))

for (col in cols_to_convert) {
  covs[[col]] <- as.numeric(covs[[col]])
}

# Print the modified data frame to check the conversion
#print(dat)

# %%
for (i in 1:dim(p)[1]) { # For each methylation site
    dat <- as.data.frame(cbind(y = p[i,], covs))
    
    # Check for rows with NAs (the ones for which we don't have covariate data)
    valid_rows <- complete.cases(dat)
    
    if (sum(valid_rows) > 0) {
        dat_valid <- dat[valid_rows,]
        model.res <- lm(y ~ ., data = dat_valid)
        
        # Store residuals in the corresponding positions
        p.residual[i, valid_rows] <- resid(model.res)
    }
}


# for(i in 1:dim(p)[1]){ # foro each methylation site
#         dat <- as.data.frame(cbind(p[i,],covs))
#         colnames(dat) <- c("y",paste0("x",1:ncol(covs)))
#         model.res <- lm(reformulate(paste0("x",1:ncol(covs)), "y"),dat)
#         p.residual[i,] = resid(model.res) 
# }

# %%
snp.gwas2 <- NULL

# %%
#load("p1.rda")

# %%
# min(snp.gwas2$pos_hg38)
# max(snp.gwas2$pos_hg38)

# %%
# load("p1.rda")
# pos_we_got <- snp.gwas2$pos_hg38
# saveRDS(pos_we_got, "20-intermediate_positions_in_old_set.csv")

# %%
pos_we_got <- readRDS("20-intermediate_positions_in_old_set.csv")

# %%
# head(snp.gwas2)

# %% [markdown]
# ### summary stats

# %%
library(data.table)
library(CpGWAS)

# %%
ss_path <- "/home/naglemi/mwas/gwas/gwas_stat_scz"

# %%
snp.gwas2 <- fread(ss_path, skip = 1, header = FALSE)
colnames(snp.gwas2) <- strsplit(readLines(ss_path, n = 1), "\t")[[1]]

# %%
snp.gwas2$z <- log(snp.gwas2$OR)/snp.gwas2$SE

# %%
snp.gwas2 <- snp.gwas2[, c(2, 1, 3, 3, 8, 4, 5, 20, 11)]

# %%
head(snp.gwas2, n = 1)
# Out:
#   SNP        CHR BP        BP        INFO  A1 A2 z         P
# 1 rs62513865 8   100579985 100579985 0.963 C  T  0.7016221 0.4847

# %%
colnames(snp.gwas2)[1:5] <- c("snp", "chr", "pos_hg38", "pos_hg38", "info")

# %%
snp.gwas2 <- snp.gwas2[which(snp.gwas2$chr == 7 & snp.gwas2$pos_hg38 >= 1963098 & snp.gwas2$pos_hg38 <= 2009071), ]

# %%
dim(snp.gwas2)
# Out:
# [1] 98  9

# %%
snp.gwas2 <- snp.gwas2[order(snp.gwas2$pos_hg38), ]

# %%
head(snp.gwas2)
# Out:
#   snp        chr pos_hg38 pos_hg38 info  A1 A2 z         P
# 1 rs11773627 7   1963098  1963098  0.987 T  C  -5.211806 1.955e-07
# 2 rs6972374  7   1963408  1963408  0.982 C  T  -5.288320 1.220e-07
# 3 rs7795303  7   1963697  1963697  0.995 T  C  -2.367885 1.805e-02
# 4 rs6946691  7   1964758  1964758  0.995 A  T  -2.339622 1.912e-02
# 5 rs12666575 7   1964786  1964786  0.993 C  T   8.855337 6.441e-19
# 6 rs61467855 7   1964869  1964869  0.994 G  A   2.490830 1.263e-02

# %%
snp.gwas2 <- snp.gwas2[which(snp.gwas2$pos_hg38 %in% pos_we_got), ]

# %%
dim(snp.gwas2)
# Out:
# [1] 56  9

# %%
# built predition models
idx.ea <- BSobj2$race == "CAUC"

# %%
snp2_sorted <- snp2[, order(names(snp2))]

# %%
colnames(snp2) <- gsub("Br0", "Br", colnames(snp2))

# %%
snp2 <- snp2[, colnames(snp2) %in% colnames(p.residual)]

# %%
dim(snp2)
# Out:
# [1]  56 297

# %%
head(snp2)
# Out:
#                  Br836 Br845 Br848 Br863 Br914 Br948 Br949 Br963 Br983 Br991 ⋯
# chr7:1963098:T:C 2.000 2     2.000 2     2.000 1.999 2.000 1.974 1.000 2     ⋯
# chr7:1963408:C:T 0.001 2     1.991 0     1.969 0.006 0.004 0.140 2.000 0     ⋯
# chr7:1964786:C:T 2.000 2     1.000 2     2.000 2.000 2.000 2.000 1.000 2     ⋯
# chr7:1966112:T:C 2.000 2     1.001 2     2.000 2.000 2.000 2.000 1.002 2     ⋯
# chr7:1973362:G:A 2.000 2     1.095 2     2.000 2.000 0.004 2.000 1.002 2     ⋯
# chr7:1975412:T:G 2.000 2     2.000 2     2.000 2.000 2.000 2.000 1.000 2     ⋯
#                  Br5373 Br5398 Br5422 Br5426 Br5460 Br5467 Br5475 Br5488 Br5584
# chr7:1963098:T:C 1.954  2      2      2      2      2      2      1      1
# chr7:1963408:C:T 2.000  0      1      2      2      1      1      2      2
# chr7:1964786:C:T 0.001  2      2      0      2      2      2      1      1
# chr7:1966112:T:C 0.015  2      2      0      2      2      2      1      1
# chr7:1973362:G:A 0.015  2      2      0      2      1      2      1      1
# chr7:1975412:T:G 2.000  2      2      2      2      2      2      1      1
#                  Br5590
# chr7:1963098:T:C 1
# chr7:1963408:C:T 2
# chr7:1964786:C:T 2
# chr7:1966112:T:C 2
# chr7:1973362:G:A 2
# chr7:1975412:T:G 1

# %%
snp2_positions <- stringr::str_split_fixed(rownames(snp2), ":", 3)[, 2]

# %%
snp3 <- readRDS("20-IN_check_SNP_window_pos1987413_win50000.rds")

# %%
dim(snp3)
# Out:
# [1] 297 264

# %%
length(rownames(snp3))
# Out:
# [1] 297

# %%
map3 <- data.frame(POS = stringr::str_split_fixed(colnames(snp3), ":", 3)[, 2])

# %%
snp3 <- t(snp3)

# %%
snp3 <- snp3[which(map3$POS %in% pos_we_got), ]

# %%
map3 <- data.frame(POS = stringr::str_split_fixed(rownames(snp3), ":", 3)[, 2])

# %%
dim(map3)
# Out:
# [1] 56  1

# %% [markdown]
# Once we filter down to same SNPs, are data structures same? Must reorder old one too to make sure

# %%
colnames(snp2) <- gsub("Br0", "Br", colnames(snp2))

# %%
snp2 <- snp2[, order(colnames(snp2))]

# %%
head(snp3)
# Out:
#                  Br1003 Br1004    Br1007 Br1016 Br1017    Br1021 Br1023
# chr7:1963098:T:C 1      0.0000000 1      0      0.0000000 0      1.0000000
# chr7:1963408:C:T 0      0.9970093 0      1      0.9920044 2      0.0000000
# chr7:1964786:C:T 1      0.0000000 0      1      0.0000000 0      2.0000000
# chr7:1966112:T:C 1      0.0000000 0      1      0.0000000 0      1.9840088
# chr7:1973362:G:A 1      0.0000000 0      1      0.0000000 1      0.9780273
# chr7:1975412:T:G 1      0.0000000 1      0      0.0000000 0      1.0009766
#                  Br1030       Br1033      Br1034     ⋯ Br845 Br848       Br863
# chr7:1963098:T:C 0.0100097656 0.002990723 0.04699707 ⋯ 0     0.000000000 0
# chr7:1963408:C:T 0.9710083008 0.994995117 0.93200684 ⋯ 0     0.008972168 2
# chr7:1964786:C:T 1.0000000000 1.000000000 1.00000000 ⋯ 0     1.000000000 0
# chr7:1966112:T:C 1.0130004883 1.000000000 0.99798584 ⋯ 0     0.999023438 0
# chr7:1973362:G:A 1.0000000000 1.000000000 0.99298096 ⋯ 0     0.905029297 0
# chr7:1975412:T:G 0.0009765625 0.000000000 0.00000000 ⋯ 0     0.000000000 0
#                  Br914      Br948        Br949    Br963      Br983     Br991
# chr7:1963098:T:C 0.00000000 0.0009765625 0.000000 0.02600098 1.0000000 0
# chr7:1963408:C:T 0.03100586 1.9940185547 1.995972 1.85998535 0.0000000 2
# chr7:1964786:C:T 0.00000000 0.0000000000 0.000000 0.00000000 1.0000000 0
# chr7:1966112:T:C 0.00000000 0.0000000000 0.000000 0.00000000 0.9979858 0
# chr7:1973362:G:A 0.00000000 0.0000000000 1.995972 0.00000000 0.9979858 0
# chr7:1975412:T:G 0.00000000 0.0000000000 0.000000 0.00000000 1.0000000 0
#                  Br993
# chr7:1963098:T:C 0.000000
# chr7:1963408:C:T 1.999023
# chr7:1964786:C:T 0.000000
# chr7:1966112:T:C 0.000000
# chr7:1973362:G:A 0.000000
# chr7:1975412:T:G 0.000000

# %%
head(snp2)
# Out:
#                  Br1003 Br1004 Br1007 Br1016 Br1017 Br1021 Br1023 Br1030 Br1033
# chr7:1963098:T:C 1      2.000  1      2      2.000  2      1.000  1.990  1.997
# chr7:1963408:C:T 2      1.003  2      1      1.008  0      2.000  1.029  1.005
# chr7:1964786:C:T 1      2.000  2      1      2.000  2      0.000  1.000  1.000
# chr7:1966112:T:C 1      2.000  2      1      2.000  2      0.016  0.987  1.000
# chr7:1973362:G:A 1      2.000  2      1      2.000  1      1.022  1.000  1.000
# chr7:1975412:T:G 1      2.000  1      2      2.000  2      0.999  1.999  2.000
#                  Br1034 ⋯ Br845 Br848 Br863 Br914 Br948 Br949 Br963 Br983 Br991
# chr7:1963098:T:C 1.953  ⋯ 2     2.000 2     2.000 1.999 2.000 1.974 1.000 2
# chr7:1963408:C:T 1.068  ⋯ 2     1.991 0     1.969 0.006 0.004 0.140 2.000 0
# chr7:1964786:C:T 1.000  ⋯ 2     1.000 2     2.000 2.000 2.000 2.000 1.000 2
# chr7:1966112:T:C 1.002  ⋯ 2     1.001 2     2.000 2.000 2.000 2.000 1.002 2
# chr7:1973362:G:A 1.007  ⋯ 2     1.095 2     2.000 2.000 0.004 2.000 1.002 2
# chr7:1975412:T:G 2.000  ⋯ 2     2.000 2     2.000 2.000 2.000 2.000 1.000 2
#                  Br993
# chr7:1963098:T:C 2.000
# chr7:1963408:C:T 0.001
# chr7:1964786:C:T 2.000
# chr7:1966112:T:C 2.000
# chr7:1973362:G:A 2.000
# chr7:1975412:T:G 2.000

# %% [markdown]
# We also must flip the new one, round to 3 decimals, and convert to df

# %%
snp3 <- 2-snp3
snp3 <- as.data.frame(snp3)
snp3[] <- lapply(snp3, function(x) if(is.numeric(x)) round(x, 3) else x)

# %%
head(snp3)
# Out:
#                  Br1003 Br1004 Br1007 Br1016 Br1017 Br1021 Br1023 Br1030 Br1033
# chr7:1963098:T:C 1      2.000  1      2      2.000  2      1.000  1.990  1.997
# chr7:1963408:C:T 2      1.003  2      1      1.008  0      2.000  1.029  1.005
# chr7:1964786:C:T 1      2.000  2      1      2.000  2      0.000  1.000  1.000
# chr7:1966112:T:C 1      2.000  2      1      2.000  2      0.016  0.987  1.000
# chr7:1973362:G:A 1      2.000  2      1      2.000  1      1.022  1.000  1.000
# chr7:1975412:T:G 1      2.000  1      2      2.000  2      0.999  1.999  2.000
#                  Br1034 ⋯ Br845 Br848 Br863 Br914 Br948 Br949 Br963 Br983 Br991
# chr7:1963098:T:C 1.953  ⋯ 2     2.000 2     2.000 1.999 2.000 1.974 1.000 2
# chr7:1963408:C:T 1.068  ⋯ 2     1.991 0     1.969 0.006 0.004 0.140 2.000 0
# chr7:1964786:C:T 1.000  ⋯ 2     1.000 2     2.000 2.000 2.000 2.000 1.000 2
# chr7:1966112:T:C 1.002  ⋯ 2     1.001 2     2.000 2.000 2.000 2.000 1.002 2
# chr7:1973362:G:A 1.007  ⋯ 2     1.095 2     2.000 2.000 0.004 2.000 1.002 2
# chr7:1975412:T:G 2.000  ⋯ 2     2.000 2     2.000 2.000 2.000 2.000 1.000 2
#                  Br993
# chr7:1963098:T:C 2.000
# chr7:1963408:C:T 0.001
# chr7:1964786:C:T 2.000
# chr7:1966112:T:C 2.000
# chr7:1973362:G:A 2.000
# chr7:1975412:T:G 2.000

# %%
# compare_data_frames <- function(df1, df2) {
#   # Initialize lists to store differences
#   differences <- list()
  
#   # Check if column names are identical
#   if (!identical(colnames(df1), colnames(df2))) {
#     differing_cols <- setdiff(union(colnames(df1), colnames(df2)), intersect(colnames(df1), colnames(df2)))
#     differences$column_names <- differing_cols
#   }
  
#   # Check if row names are identical
#   if (!identical(rownames(df1), rownames(df2))) {
#     differing_rows <- setdiff(union(rownames(df1), rownames(df2)), intersect(rownames(df1), rownames(df2)))
#     differences$row_names <- differing_rows
#   }
  
#   # Check for differing values
#   for (i in seq_len(nrow(df1))) {
#     for (j in seq_len(ncol(df1))) {
#       if (df1[i, j] != df2[i, j]) {
#         differences$values <- rbind(
#           differences$values, 
#           data.frame(
#             row = i, 
#             column = j, 
#             df1_value = df1[i, j], 
#             df2_value = df2[i, j]
#           )
#         )
#       }
#     }
#   }
  
#   return(differences)
# }

# # Example usage:
# # Assuming snp2 and snp3 are your data frames
# result <- compare_data_frames(snp2, snp3)

# # Print results
# if (!is.null(result$column_names)) {
#   cat("Differing column names:\n")
#   print(result$column_names)
# }

# if (!is.null(result$row_names)) {
#   cat("Differing row names:\n")
#   print(result$row_names)
# }

# if (!is.null(result$values)) {
#   cat("Differing values:\n")
#   print(result$values)
# } else {
#   cat("No differing values found.\n")
# }

# %% [markdown]
# Not quite the same but very close. Let's proceed with snp2 (old version) for now.

# %%
identical(snp2, snp3)
# Out:
# [1] FALSE

# %%
snp3 <- snp2

# %%
dim(snp3)
# Out:
# [1]  56 297

# %%
head(snp3)
# Out:
#                  Br1003 Br1004 Br1007 Br1016 Br1017 Br1021 Br1023 Br1030 Br1033
# chr7:1963098:T:C 1      2.000  1      2      2.000  2      1.000  1.990  1.997
# chr7:1963408:C:T 2      1.003  2      1      1.008  0      2.000  1.029  1.005
# chr7:1964786:C:T 1      2.000  2      1      2.000  2      0.000  1.000  1.000
# chr7:1966112:T:C 1      2.000  2      1      2.000  2      0.016  0.987  1.000
# chr7:1973362:G:A 1      2.000  2      1      2.000  1      1.022  1.000  1.000
# chr7:1975412:T:G 1      2.000  1      2      2.000  2      0.999  1.999  2.000
#                  Br1034 ⋯ Br845 Br848 Br863 Br914 Br948 Br949 Br963 Br983 Br991
# chr7:1963098:T:C 1.953  ⋯ 2     2.000 2     2.000 1.999 2.000 1.974 1.000 2
# chr7:1963408:C:T 1.068  ⋯ 2     1.991 0     1.969 0.006 0.004 0.140 2.000 0
# chr7:1964786:C:T 1.000  ⋯ 2     1.000 2     2.000 2.000 2.000 2.000 1.000 2
# chr7:1966112:T:C 1.002  ⋯ 2     1.001 2     2.000 2.000 2.000 2.000 1.002 2
# chr7:1973362:G:A 1.007  ⋯ 2     1.095 2     2.000 2.000 0.004 2.000 1.002 2
# chr7:1975412:T:G 2.000  ⋯ 2     2.000 2     2.000 2.000 2.000 2.000 1.000 2
#                  Br993
# chr7:1963098:T:C 2.000
# chr7:1963408:C:T 0.001
# chr7:1964786:C:T 2.000
# chr7:1966112:T:C 2.000
# chr7:1973362:G:A 2.000
# chr7:1975412:T:G 2.000

# %%
dim(map3)
# Out:
# [1] 56  1

# %% [markdown]
# ### Set window size and any other parameters

# %%
wind <- 10000

# %% [markdown]
# Is 1se vs min for lambda the problem?

# %% [markdown]
# ## Run for all

# %%
head(map3)
# Out:
#   POS
# 1 1963098
# 2 1963408
# 3 1964786
# 4 1966112
# 5 1973362
# 6 1975412

# %%
dim(map3)
# Out:
# [1] 56  1

# %%
dim(snp3)
# Out:
# [1]  56 297

# %%
p.residual <- p.residual[, order(colnames(p.residual))]

# %%
for(k in 1:length(wind)){
    models.ea <- c()
    models.all <- c()
    for(i in 1:length(cg)){
    #for(i in 1){
            cat(i,"\n")
            print(paste0("This cg is: ", cg[i]))
            range1 <- ifelse(cg[i] - wind[k] > 0,cg[i] - wind[k],0)
            range2 <- cg[i] + wind[k]
            idx <- map3$POS > range1 & map3$POS < range2
            # go to next cg if no snps within window
            if(sum(idx) <= 1){
                    next
            }
            geno <- snp3[idx,] # changed snp2 to snp3
            rownames(geno) <- map3$POS[idx]
            trainX <- t(geno)
            trainY <- p.residual[i,]
            fit <- elastic.net(trainX,trainY)
            fit <- tryCatch(
                    elastic.net(trainX,trainY),
                    error = function(e) {return ("err")})
            if(!is.data.frame(fit)){
                if(fit == "err"){
                    next
                }
            }
            if(nrow(fit) == 0) next

            fit$cg <- cg[i]
            models.all <- rbind(models.all,fit)
            # EA only
            trainX <- trainX[idx.ea,]
            if(sum(apply(trainX,2,var)!=0) <= 1){
                    next
            }
            trainY <- trainY[idx.ea]
            fit <- tryCatch(
                    elastic.net(trainX,trainY),
                    error = function(e) {return ("err")})
            if(!is.data.frame(fit)){
                if(fit == "err"){
                    next
                }
            }
            if(nrow(fit) == 0) next
            fit$cg <- cg[i]
            models.ea <- rbind(models.ea,fit)
    }
}
# Out:
# 1
# [1] "This cg is: 1987413"
# Warning message:
# “executing %dopar% sequentially: no parallel backend registered”
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0032126124
# 1977810     -0.0006411674
# 1981360      0.0011125459
# 1987719      0.0010922703
# 1987813     -0.0001080420
# 1990232      0.0011776407
# 1994382     -0.0008559913
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -3.221430e-03
# 1977810     -6.513013e-04
# 1981360      1.122917e-03
# 1987719      1.092965e-03
# 1987813     -9.810545e-05
# 1990232      1.171648e-03
# 1994382     -8.527303e-04
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0032126124
# 1977810     -0.0006411674
# 1981360      0.0011125459
# 1987719      0.0010922703
# 1987813     -0.0001080420
# 1990232      0.0011776407
# 1994382     -0.0008559913
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -3.221430e-03
# 1977810     -6.513013e-04
# 1981360      1.122917e-03
# 1987719      1.092965e-03
# 1987813     -9.810545e-05
# 1990232      1.171648e-03
# 1994382     -8.527303e-04
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0036474120
# 1987676      0.0001814140
# 1987719      0.0006954072
# 1990232      0.0007887558
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0036451950
# 1987676      0.0001807873
# 1987719      0.0006905409
# 1990232      0.0007928422
# 2
# [1] "This cg is: 1987418"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0034403777
# 1977810     -0.0007812247
# 1981360      0.0011158987
# 1987719      0.0013177394
# 1987813     -0.0002152152
# 1990232      0.0013323843
# 1994382     -0.0009738068
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0034470342
# 1977810     -0.0007874910
# 1981360      0.0011228911
# 1987719      0.0013192354
# 1987813     -0.0002091439
# 1990232      0.0013276740
# 1994382     -0.0009713944
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0034403777
# 1977810     -0.0007812247
# 1981360      0.0011158987
# 1987719      0.0013177394
# 1987813     -0.0002152152
# 1990232      0.0013323843
# 1994382     -0.0009738068
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0034470342
# 1977810     -0.0007874910
# 1981360      0.0011228911
# 1987719      0.0013192354
# 1987813     -0.0002091439
# 1990232      0.0013276740
# 1994382     -0.0009713944
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0045502467
# 1987676      0.0004142840
# 1987719      0.0009258509
# 1990232      0.0010634414
# 1994382     -0.0001275656
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0045504106
# 1987676      0.0004155808
# 1987719      0.0009248922
# 1990232      0.0010631838
# 1994382     -0.0001275474
# 3
# [1] "This cg is: 1987434"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0042930046
# 1977810     -0.0009185477
# 1981360      0.0010909280
# 1987676      0.0001296780
# 1987719      0.0016430667
# 1987813     -0.0003885030
# 1990232      0.0016132923
# 1994382     -0.0008817702
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0043203875
# 1977810     -0.0009303977
# 1981360      0.0011063315
# 1987676      0.0001360277
# 1987719      0.0016506118
# 1987813     -0.0003695942
# 1990232      0.0015975811
# 1994382     -0.0008776677
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0042930046
# 1977810     -0.0009185477
# 1981360      0.0010909280
# 1987676      0.0001296780
# 1987719      0.0016430667
# 1987813     -0.0003885030
# 1990232      0.0016132923
# 1994382     -0.0008817702
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0043203875
# 1977810     -0.0009303977
# 1981360      0.0011063315
# 1987676      0.0001360277
# 1987719      0.0016506118
# 1987813     -0.0003695942
# 1990232      0.0015975811
# 1994382     -0.0008776677
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -5.346786e-03
# 1987676      6.656468e-04
# 1987719      1.183924e-03
# 1987813     -2.325098e-04
# 1990232      1.313064e-03
# 1994382     -1.291378e-04
# 1997034      6.948733e-06
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -5.347575e-03
# 1987676      6.672871e-04
# 1987719      1.184092e-03
# 1987813     -2.324181e-04
# 1990232      1.311947e-03
# 1994382     -1.288849e-04
# 1997034      6.543009e-06
# 4
# [1] "This cg is: 1987449"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0051322139
# 1977810     -0.0010720304
# 1981360      0.0010755532
# 1987676      0.0004042321
# 1987719      0.0018806130
# 1987813     -0.0005414524
# 1990232      0.0018222303
# 1994382     -0.0008033279
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0051511965
# 1977810     -0.0011105266
# 1981360      0.0011018045
# 1987676      0.0004424476
# 1987719      0.0018546697
# 1987813     -0.0004994673
# 1990232      0.0017940990
# 1994382     -0.0007990849
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0051322139
# 1977810     -0.0010720304
# 1981360      0.0010755532
# 1987676      0.0004042321
# 1987719      0.0018806130
# 1987813     -0.0005414524
# 1990232      0.0018222303
# 1994382     -0.0008033279
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0051511965
# 1977810     -0.0011105266
# 1981360      0.0011018045
# 1987676      0.0004424476
# 1987719      0.0018546697
# 1987813     -0.0004994673
# 1990232      0.0017940990
# 1994382     -0.0007990849
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0055238623
# 1987676      0.0006564061
# 1987719      0.0012036341
# 1987813     -0.0003546170
# 1990232      0.0013243129
# 1997034      0.0001674995
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0055305845
# 1987676      0.0006623091
# 1987719      0.0012041045
# 1987813     -0.0003510359
# 1990232      0.0013211393
# 1997034      0.0001669186
# 5
# [1] "This cg is: 1987458"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0055690263
# 1977810     -0.0012250294
# 1981360      0.0010388327
# 1987676      0.0006115062
# 1987719      0.0020562584
# 1987813     -0.0006683249
# 1990232      0.0019587705
# 1994382     -0.0008358932
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0055890912
# 1977810     -0.0012596951
# 1981360      0.0010666614
# 1987676      0.0006347330
# 1987719      0.0020298616
# 1987813     -0.0006285341
# 1990232      0.0019448756
# 1994382     -0.0008314906
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0055690263
# 1977810     -0.0012250294
# 1981360      0.0010388327
# 1987676      0.0006115062
# 1987719      0.0020562584
# 1987813     -0.0006683249
# 1990232      0.0019587705
# 1994382     -0.0008358932
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0055890912
# 1977810     -0.0012596951
# 1981360      0.0010666614
# 1987676      0.0006347330
# 1987719      0.0020298616
# 1987813     -0.0006285341
# 1990232      0.0019448756
# 1994382     -0.0008314906
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.076263e-03
# 1977810     -1.545266e-04
# 1985405      9.343272e-05
# 1987676      7.861929e-04
# 1987719      1.324110e-03
# 1987813     -5.852247e-04
# 1990232      1.449671e-03
# 1997034      3.332815e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -6.076392e-03
# 1977810     -1.595146e-04
# 1985405      9.477233e-05
# 1987676      7.813861e-04
# 1987719      1.318422e-03
# 1987813     -5.787578e-04
# 1990232      1.451951e-03
# 1997034      3.397441e-04
# 6
# [1] "This cg is: 1987468"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0060726560
# 1977810     -0.0012442007
# 1981360      0.0010362597
# 1987676      0.0007470384
# 1987719      0.0021154541
# 1987813     -0.0007309417
# 1990232      0.0020550798
# 1994382     -0.0006753842
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0060929370
# 1977810     -0.0012809831
# 1981360      0.0010651252
# 1987676      0.0007705089
# 1987719      0.0020866364
# 1987813     -0.0006885595
# 1990232      0.0020424378
# 1994382     -0.0006710666
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0060726560
# 1977810     -0.0012442007
# 1981360      0.0010362597
# 1987676      0.0007470384
# 1987719      0.0021154541
# 1987813     -0.0007309417
# 1990232      0.0020550798
# 1994382     -0.0006753842
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0060929370
# 1977810     -0.0012809831
# 1981360      0.0010651252
# 1987676      0.0007705089
# 1987719      0.0020866364
# 1987813     -0.0006885595
# 1990232      0.0020424378
# 1994382     -0.0006710666
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.117712e-03
# 1977810     -1.776361e-04
# 1985405      1.972927e-04
# 1987676      7.737947e-04
# 1987719      1.302949e-03
# 1987813     -6.222653e-04
# 1990232      1.427032e-03
# 1990652      4.258271e-07
# 1997034      4.004441e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0061246038
# 1977810     -0.0001995369
# 1985405      0.0002243081
# 1987676      0.0007924181
# 1987719      0.0012929324
# 1987813     -0.0005973906
# 1990232      0.0013990623
# 1997034      0.0003975917
# 7
# [1] "This cg is: 1987492"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -7.228705e-03
# 1977810     -1.555785e-03
# 1981360      9.151532e-04
# 1987676      9.495687e-04
# 1987719      2.313744e-03
# 1987813     -1.041158e-03
# 1989028      9.308182e-05
# 1989994      9.325083e-05
# 1990232      2.280023e-03
# 1990305      1.048607e-04
# 1990372      1.067143e-04
# 1990469      1.067369e-04
# 1990652      1.016315e-04
# 1994382     -6.348427e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -7.211981e-03
# 1977810     -1.567574e-03
# 1981360      8.943636e-04
# 1987676      8.414915e-04
# 1987719      2.224350e-03
# 1987813     -1.031028e-03
# 1989028      1.043314e-04
# 1989994      1.488338e-04
# 1990232      2.298147e-03
# 1990305      1.492185e-04
# 1990372      1.551528e-04
# 1990469      1.395453e-04
# 1990652      9.503513e-05
# 1994382     -6.407413e-04
# 1997034      4.228912e-06
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -7.228705e-03
# 1977810     -1.555785e-03
# 1981360      9.151532e-04
# 1987676      9.495687e-04
# 1987719      2.313744e-03
# 1987813     -1.041158e-03
# 1989028      9.308182e-05
# 1989994      9.325083e-05
# 1990232      2.280023e-03
# 1990305      1.048607e-04
# 1990372      1.067143e-04
# 1990469      1.067369e-04
# 1990652      1.016315e-04
# 1994382     -6.348427e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -7.211981e-03
# 1977810     -1.567574e-03
# 1981360      8.943636e-04
# 1987676      8.414915e-04
# 1987719      2.224350e-03
# 1987813     -1.031028e-03
# 1989028      1.043314e-04
# 1989994      1.488338e-04
# 1990232      2.298147e-03
# 1990305      1.492185e-04
# 1990372      1.551528e-04
# 1990469      1.395453e-04
# 1990652      9.503513e-05
# 1994382     -6.407413e-04
# 1997034      4.228912e-06
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.793121e-03
# 1977810     -4.062802e-04
# 1985405      4.589505e-04
# 1987676      7.856428e-04
# 1987719      1.297259e-03
# 1987813     -8.921838e-04
# 1989028      8.155416e-05
# 1989994      8.718086e-05
# 1990232      1.452617e-03
# 1990305      7.333527e-05
# 1990372      6.383562e-05
# 1990469      5.074594e-05
# 1990652      4.533326e-05
# 1997034      5.503820e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -6.772697e-03
# 1977810     -4.381325e-04
# 1985405      4.907248e-04
# 1987676      8.065375e-04
# 1987719      1.289783e-03
# 1987813     -8.646376e-04
# 1989028      1.494044e-05
# 1989994      2.560047e-05
# 1990232      1.414617e-03
# 1990305      4.572670e-05
# 1990372      7.471295e-05
# 1990469      9.370341e-05
# 1990652      1.047938e-04
# 1997034      5.759600e-04
# 8
# [1] "This cg is: 1987511"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0081095850
# 1977810     -0.0015816901
# 1981360      0.0008628773
# 1987676      0.0008968243
# 1987719      0.0022282572
# 1987813     -0.0011920740
# 1989028      0.0002085600
# 1989994      0.0001827682
# 1990232      0.0023507619
# 1990305      0.0001798294
# 1990372      0.0001756832
# 1990469      0.0001811257
# 1990652      0.0001813370
# 1994382     -0.0003583138
# 1997034      0.0001294475
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0080737556
# 1977810     -0.0015964663
# 1981360      0.0008543408
# 1987676      0.0008280064
# 1987719      0.0021699308
# 1987813     -0.0011787438
# 1989028      0.0001747559
# 1989994      0.0001778237
# 1990232      0.0023341146
# 1990305      0.0001880197
# 1990372      0.0002146237
# 1990469      0.0002426422
# 1990652      0.0002319414
# 1994382     -0.0003719364
# 1997034      0.0001439894
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0081095850
# 1977810     -0.0015816901
# 1981360      0.0008628773
# 1987676      0.0008968243
# 1987719      0.0022282572
# 1987813     -0.0011920740
# 1989028      0.0002085600
# 1989994      0.0001827682
# 1990232      0.0023507619
# 1990305      0.0001798294
# 1990372      0.0001756832
# 1990469      0.0001811257
# 1990652      0.0001813370
# 1994382     -0.0003583138
# 1997034      0.0001294475
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0080737556
# 1977810     -0.0015964663
# 1981360      0.0008543408
# 1987676      0.0008280064
# 1987719      0.0021699308
# 1987813     -0.0011787438
# 1989028      0.0001747559
# 1989994      0.0001778237
# 1990232      0.0023341146
# 1990305      0.0001880197
# 1990372      0.0002146237
# 1990469      0.0002426422
# 1990652      0.0002319414
# 1994382     -0.0003719364
# 1997034      0.0001439894
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0074105863
# 1977810     -0.0006271770
# 1985405      0.0006759118
# 1987676      0.0008077299
# 1987719      0.0013064085
# 1987813     -0.0011570874
# 1989028      0.0001424312
# 1989994      0.0001423517
# 1990232      0.0014951726
# 1990305      0.0001267022
# 1990372      0.0001158697
# 1990469      0.0001058127
# 1990652      0.0001050374
# 1997034      0.0006886523
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -7.399264e-03
# 1977810     -6.342605e-04
# 1985405      6.956075e-04
# 1987676      8.542985e-04
# 1987719      1.340111e-03
# 1987813     -1.154929e-03
# 1989028      1.305940e-04
# 1989994      1.088572e-04
# 1990232      1.480169e-03
# 1990305      9.731218e-05
# 1990372      9.299302e-05
# 1990469      1.002828e-04
# 1990652      1.203611e-04
# 1997034      6.884674e-04
# 9
# [1] "This cg is: 1987527"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0087420304
# 1977810     -0.0017477166
# 1981360      0.0007879710
# 1987676      0.0009438611
# 1987719      0.0022679976
# 1987813     -0.0013808221
# 1989028      0.0002237142
# 1989994      0.0002249547
# 1990232      0.0024617840
# 1990305      0.0002419934
# 1990372      0.0002496527
# 1990469      0.0002525379
# 1990652      0.0002446059
# 1994382     -0.0002912925
# 1997034      0.0002628997
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0086814884
# 1977810     -0.0017527638
# 1981360      0.0007511344
# 1987676      0.0008381894
# 1987719      0.0021948076
# 1987813     -0.0013842541
# 1989028      0.0002280268
# 1989994      0.0002367561
# 1990232      0.0024714870
# 1990305      0.0002472659
# 1990372      0.0002754988
# 1990469      0.0003096322
# 1990652      0.0003020775
# 1994382     -0.0003099153
# 1997034      0.0002774631
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0087420304
# 1977810     -0.0017477166
# 1981360      0.0007879710
# 1987676      0.0009438611
# 1987719      0.0022679976
# 1987813     -0.0013808221
# 1989028      0.0002237142
# 1989994      0.0002249547
# 1990232      0.0024617840
# 1990305      0.0002419934
# 1990372      0.0002496527
# 1990469      0.0002525379
# 1990652      0.0002446059
# 1994382     -0.0002912925
# 1997034      0.0002628997
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0086814884
# 1977810     -0.0017527638
# 1981360      0.0007511344
# 1987676      0.0008381894
# 1987719      0.0021948076
# 1987813     -0.0013842541
# 1989028      0.0002280268
# 1989994      0.0002367561
# 1990232      0.0024714870
# 1990305      0.0002472659
# 1990372      0.0002754988
# 1990469      0.0003096322
# 1990652      0.0003020775
# 1994382     -0.0003099153
# 1997034      0.0002774631
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0075171004
# 1977810     -0.0006631884
# 1985405      0.0007977634
# 1987676      0.0007319373
# 1987719      0.0012294227
# 1987813     -0.0012481291
# 1989028      0.0001766507
# 1989994      0.0001849649
# 1990232      0.0014405365
# 1990305      0.0001710288
# 1990372      0.0001629733
# 1990469      0.0001496147
# 1990652      0.0001425488
# 1997034      0.0007263444
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0075063854
# 1977810     -0.0006677082
# 1985405      0.0008172827
# 1987676      0.0007850599
# 1987719      0.0012725766
# 1987813     -0.0012478633
# 1989028      0.0001778064
# 1989994      0.0001538410
# 1990232      0.0014352227
# 1990305      0.0001377390
# 1990372      0.0001264396
# 1990469      0.0001298708
# 1990652      0.0001489373
# 1997034      0.0007266671
# 10
# [1] "This cg is: 1987565"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0100860271
# 1977810     -0.0018888797
# 1981360      0.0006317336
# 1985405      0.0001186164
# 1987676      0.0009220487
# 1987719      0.0021844823
# 1987813     -0.0017273659
# 1989028      0.0003679824
# 1989994      0.0003523940
# 1990232      0.0026656591
# 1990305      0.0003550349
# 1990372      0.0003553822
# 1990469      0.0003595943
# 1990652      0.0003519299
# 1997034      0.0004948534
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.000274e-02
# 1977810     -1.885523e-03
# 1981360      5.903239e-04
# 1985405      6.884296e-05
# 1987676      8.495825e-04
# 1987719      2.164183e-03
# 1987813     -1.770072e-03
# 1989028      4.170715e-04
# 1989994      4.119508e-04
# 1990232      2.684441e-03
# 1990305      3.708857e-04
# 1990372      3.607737e-04
# 1990469      3.642140e-04
# 1990652      3.218194e-04
# 1997034      5.116018e-04
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0100860271
# 1977810     -0.0018888797
# 1981360      0.0006317336
# 1985405      0.0001186164
# 1987676      0.0009220487
# 1987719      0.0021844823
# 1987813     -0.0017273659
# 1989028      0.0003679824
# 1989994      0.0003523940
# 1990232      0.0026656591
# 1990305      0.0003550349
# 1990372      0.0003553822
# 1990469      0.0003595943
# 1990652      0.0003519299
# 1997034      0.0004948534
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.000274e-02
# 1977810     -1.885523e-03
# 1981360      5.903239e-04
# 1985405      6.884296e-05
# 1987676      8.495825e-04
# 1987719      2.164183e-03
# 1987813     -1.770072e-03
# 1989028      4.170715e-04
# 1989994      4.119508e-04
# 1990232      2.684441e-03
# 1990305      3.708857e-04
# 1990372      3.607737e-04
# 1990469      3.642140e-04
# 1990652      3.218194e-04
# 1997034      5.116018e-04
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0086754939
# 1977810     -0.0010771376
# 1985405      0.0012305889
# 1987676      0.0007499850
# 1987719      0.0012125041
# 1987813     -0.0018229930
# 1989028      0.0002632749
# 1989994      0.0002549220
# 1990232      0.0015041384
# 1990305      0.0002880819
# 1990372      0.0002934164
# 1990469      0.0002825018
# 1990652      0.0002702979
# 1997034      0.0010138253
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0086656725
# 1977810     -0.0010792758
# 1985405      0.0012426511
# 1987676      0.0007864141
# 1987719      0.0012451795
# 1987813     -0.0018227241
# 1989028      0.0002836074
# 1989994      0.0002639942
# 1990232      0.0015031574
# 1990305      0.0002500456
# 1990372      0.0002448195
# 1990469      0.0002494057
# 1990652      0.0002667326
# 1997034      0.0010238932
# 11
# [1] "This cg is: 1987604"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0108140175
# 1977810     -0.0019558433
# 1981360      0.0003926096
# 1985405      0.0004514257
# 1987676      0.0007833091
# 1987719      0.0019695259
# 1987813     -0.0020083787
# 1989028      0.0003494002
# 1989994      0.0003338032
# 1990232      0.0027941999
# 1990305      0.0003387977
# 1990372      0.0003423740
# 1990469      0.0003486319
# 1990652      0.0003391351
# 1997034      0.0004098991
# 1997580      0.0010064134
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0107671272
# 1977810     -0.0019657166
# 1981360      0.0003758817
# 1985405      0.0004263062
# 1987676      0.0007171708
# 1987719      0.0019261374
# 1987813     -0.0020179725
# 1989028      0.0003876462
# 1989994      0.0003772444
# 1990232      0.0028173999
# 1990305      0.0003622555
# 1990372      0.0003475938
# 1990469      0.0003393972
# 1990652      0.0003102129
# 1997034      0.0004079833
# 1997580      0.0010391994
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0108140175
# 1977810     -0.0019558433
# 1981360      0.0003926096
# 1985405      0.0004514257
# 1987676      0.0007833091
# 1987719      0.0019695259
# 1987813     -0.0020083787
# 1989028      0.0003494002
# 1989994      0.0003338032
# 1990232      0.0027941999
# 1990305      0.0003387977
# 1990372      0.0003423740
# 1990469      0.0003486319
# 1990652      0.0003391351
# 1997034      0.0004098991
# 1997580      0.0010064134
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0107671272
# 1977810     -0.0019657166
# 1981360      0.0003758817
# 1985405      0.0004263062
# 1987676      0.0007171708
# 1987719      0.0019261374
# 1987813     -0.0020179725
# 1989028      0.0003876462
# 1989994      0.0003772444
# 1990232      0.0028173999
# 1990305      0.0003622555
# 1990372      0.0003475938
# 1990469      0.0003393972
# 1990652      0.0003102129
# 1997034      0.0004079833
# 1997580      0.0010391994
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0097161750
# 1977810     -0.0014253597
# 1985405      0.0016351300
# 1987676      0.0006577725
# 1987719      0.0010935560
# 1987813     -0.0024220537
# 1989028      0.0003041753
# 1989994      0.0002919054
# 1990232      0.0015363666
# 1990305      0.0003259115
# 1990372      0.0003176757
# 1990469      0.0003045991
# 1990652      0.0003014872
# 1997034      0.0011819633
# 1997580      0.0007309206
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0097048314
# 1977810     -0.0014327726
# 1985405      0.0016481025
# 1987676      0.0006713916
# 1987719      0.0010966008
# 1987813     -0.0024138545
# 1989028      0.0003207078
# 1989994      0.0003118807
# 1990232      0.0015311557
# 1990305      0.0002958890
# 1990372      0.0002860746
# 1990469      0.0002777105
# 1990652      0.0002802951
# 1997034      0.0011909115
# 1997580      0.0007640926
# 12
# [1] "This cg is: 1987616"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0109472156
# 1977810     -0.0019264563
# 1981360      0.0003340516
# 1985405      0.0005633945
# 1987676      0.0007510062
# 1987719      0.0018900923
# 1987813     -0.0020527744
# 1989028      0.0003699372
# 1989994      0.0003540459
# 1990232      0.0028061004
# 1990305      0.0003592855
# 1990372      0.0003628482
# 1990469      0.0003688860
# 1990652      0.0003582035
# 1997034      0.0004430696
# 1997580      0.0009995350
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0108834997
# 1977810     -0.0019322381
# 1981360      0.0003065357
# 1985405      0.0005284937
# 1987676      0.0006790200
# 1987719      0.0018487287
# 1987813     -0.0020737373
# 1989028      0.0004143747
# 1989994      0.0003996011
# 1990232      0.0028375836
# 1990305      0.0003834071
# 1990372      0.0003672050
# 1990469      0.0003592265
# 1990652      0.0003238966
# 1997034      0.0004387983
# 1997580      0.0010392594
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0109472156
# 1977810     -0.0019264563
# 1981360      0.0003340516
# 1985405      0.0005633945
# 1987676      0.0007510062
# 1987719      0.0018900923
# 1987813     -0.0020527744
# 1989028      0.0003699372
# 1989994      0.0003540459
# 1990232      0.0028061004
# 1990305      0.0003592855
# 1990372      0.0003628482
# 1990469      0.0003688860
# 1990652      0.0003582035
# 1997034      0.0004430696
# 1997580      0.0009995350
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0108834997
# 1977810     -0.0019322381
# 1981360      0.0003065357
# 1985405      0.0005284937
# 1987676      0.0006790200
# 1987719      0.0018487287
# 1987813     -0.0020737373
# 1989028      0.0004143747
# 1989994      0.0003996011
# 1990232      0.0028375836
# 1990305      0.0003834071
# 1990372      0.0003672050
# 1990469      0.0003592265
# 1990652      0.0003238966
# 1997034      0.0004387983
# 1997580      0.0010392594
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0097903495
# 1977810     -0.0014333294
# 1985405      0.0017170654
# 1987676      0.0005901000
# 1987719      0.0010254781
# 1987813     -0.0024918138
# 1989028      0.0003217938
# 1989994      0.0003068850
# 1990232      0.0014979804
# 1990305      0.0003503024
# 1990372      0.0003469097
# 1990469      0.0003338972
# 1990652      0.0003283768
# 1997034      0.0012041848
# 1997580      0.0007756077
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0097631325
# 1977810     -0.0014519576
# 1985405      0.0017454713
# 1987676      0.0006392705
# 1987719      0.0010587387
# 1987813     -0.0024803798
# 1989028      0.0003313575
# 1989994      0.0003034427
# 1990232      0.0014604965
# 1990305      0.0002770030
# 1990372      0.0002885957
# 1990469      0.0003082434
# 1990652      0.0003350590
# 1997034      0.0012352688
# 1997580      0.0008034985
# 13
# [1] "This cg is: 1987627"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0110453108
# 1977810     -0.0018983123
# 1981360      0.0002795936
# 1985405      0.0006629622
# 1987676      0.0007222682
# 1987719      0.0018189449
# 1987813     -0.0020911333
# 1989028      0.0003875940
# 1989994      0.0003709855
# 1990232      0.0028180325
# 1990305      0.0003758276
# 1990372      0.0003785744
# 1990469      0.0003841361
# 1990652      0.0003725516
# 1997034      0.0004703454
# 1997580      0.0009924762
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0110010655
# 1977810     -0.0019057601
# 1981360      0.0002730633
# 1985405      0.0006479314
# 1987676      0.0006770331
# 1987719      0.0017889777
# 1987813     -0.0020986217
# 1989028      0.0004077026
# 1989994      0.0003832575
# 1990232      0.0028276828
# 1990305      0.0003736955
# 1990372      0.0003677496
# 1990469      0.0003757868
# 1990652      0.0003539576
# 1997034      0.0004946189
# 1997580      0.0010392563
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0110453108
# 1977810     -0.0018983123
# 1981360      0.0002795936
# 1985405      0.0006629622
# 1987676      0.0007222682
# 1987719      0.0018189449
# 1987813     -0.0020911333
# 1989028      0.0003875940
# 1989994      0.0003709855
# 1990232      0.0028180325
# 1990305      0.0003758276
# 1990372      0.0003785744
# 1990469      0.0003841361
# 1990652      0.0003725516
# 1997034      0.0004703454
# 1997580      0.0009924762
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0110010655
# 1977810     -0.0019057601
# 1981360      0.0002730633
# 1985405      0.0006479314
# 1987676      0.0006770331
# 1987719      0.0017889777
# 1987813     -0.0020986217
# 1989028      0.0004077026
# 1989994      0.0003832575
# 1990232      0.0028276828
# 1990305      0.0003736955
# 1990372      0.0003677496
# 1990469      0.0003757868
# 1990652      0.0003539576
# 1997034      0.0004946189
# 1997580      0.0010392563
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0098486758
# 1977810     -0.0014328303
# 1985405      0.0017896880
# 1987676      0.0005340170
# 1987719      0.0009679241
# 1987813     -0.0025463736
# 1989028      0.0003412689
# 1989994      0.0003265610
# 1990232      0.0014645617
# 1990305      0.0003702136
# 1990372      0.0003680916
# 1990469      0.0003552418
# 1990652      0.0003488810
# 1997034      0.0012175368
# 1997580      0.0008047577
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0098186200
# 1977810     -0.0014511735
# 1985405      0.0018195759
# 1987676      0.0005884944
# 1987719      0.0010067396
# 1987813     -0.0025356085
# 1989028      0.0003517312
# 1989994      0.0003222366
# 1990232      0.0014255160
# 1990305      0.0002938392
# 1990372      0.0003045495
# 1990469      0.0003238620
# 1990652      0.0003509978
# 1997034      0.0012507931
# 1997580      0.0008367958
# 14
# [1] "This cg is: 1987648"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0112842434
# 1977810     -0.0019636574
# 1981360      0.0001182697
# 1985405      0.0008442729
# 1987676      0.0006963113
# 1987719      0.0017409547
# 1987813     -0.0022816020
# 1989028      0.0003991577
# 1989994      0.0003817123
# 1990232      0.0029768254
# 1990305      0.0003885330
# 1990372      0.0003926964
# 1990469      0.0003991155
# 1990652      0.0003854643
# 1997034      0.0005576779
# 1997580      0.0010625058
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0112368527
# 1977810     -0.0019719618
# 1981360      0.0001108317
# 1985405      0.0008280744
# 1987676      0.0006495532
# 1987719      0.0017117078
# 1987813     -0.0022898652
# 1989028      0.0004211159
# 1989994      0.0003929280
# 1990232      0.0029866751
# 1990305      0.0003842819
# 1990372      0.0003797882
# 1990469      0.0003907693
# 1990652      0.0003670177
# 1997034      0.0005842161
# 1997580      0.0011115860
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0112842434
# 1977810     -0.0019636574
# 1981360      0.0001182697
# 1985405      0.0008442729
# 1987676      0.0006963113
# 1987719      0.0017409547
# 1987813     -0.0022816020
# 1989028      0.0003991577
# 1989994      0.0003817123
# 1990232      0.0029768254
# 1990305      0.0003885330
# 1990372      0.0003926964
# 1990469      0.0003991155
# 1990652      0.0003854643
# 1997034      0.0005576779
# 1997580      0.0010625058
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0112368527
# 1977810     -0.0019719618
# 1981360      0.0001108317
# 1985405      0.0008280744
# 1987676      0.0006495532
# 1987719      0.0017117078
# 1987813     -0.0022898652
# 1989028      0.0004211159
# 1989994      0.0003929280
# 1990232      0.0029866751
# 1990305      0.0003842819
# 1990372      0.0003797882
# 1990469      0.0003907693
# 1990652      0.0003670177
# 1997034      0.0005842161
# 1997580      0.0011115860
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0099442295
# 1977810     -0.0014217941
# 1985405      0.0019234417
# 1987676      0.0004304131
# 1987719      0.0008606375
# 1987813     -0.0026382552
# 1989028      0.0003753887
# 1989994      0.0003607987
# 1990232      0.0014017425
# 1990305      0.0004050616
# 1990372      0.0004056978
# 1990469      0.0003937854
# 1990652      0.0003863611
# 1997034      0.0012362091
# 1997580      0.0008545991
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0099426991
# 1977810     -0.0014352706
# 1985405      0.0019393696
# 1987676      0.0004267761
# 1987719      0.0008344875
# 1987813     -0.0026225388
# 1989028      0.0003711650
# 1989994      0.0003815887
# 1990232      0.0014101254
# 1990305      0.0003916263
# 1990372      0.0003901097
# 1990469      0.0003871397
# 1990652      0.0003873324
# 1997034      0.0012404983
# 1997580      0.0008732414
# 15
# [1] "This cg is: 1987656"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.131211e-02
# 1977810     -1.939310e-03
# 1981360      7.737321e-05
# 1985405      9.157722e-04
# 1987676      6.728472e-04
# 1987719      1.684507e-03
# 1987813     -2.306521e-03
# 1989028      4.061127e-04
# 1989994      3.896529e-04
# 1990232      2.986382e-03
# 1990305      3.973977e-04
# 1990372      4.020817e-04
# 1990469      4.080335e-04
# 1990652      3.930776e-04
# 1997034      5.741808e-04
# 1997580      1.055880e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0113462161
# 1977810     -0.0019656650
# 1981360      0.0001131592
# 1985405      0.0009419654
# 1987676      0.0006587319
# 1987719      0.0016471554
# 1987813     -0.0022641071
# 1989028      0.0004123222
# 1989994      0.0004325020
# 1990232      0.0029743712
# 1990305      0.0003633258
# 1990372      0.0003725917
# 1990469      0.0003970599
# 1990652      0.0004215264
# 1997034      0.0005960073
# 1997580      0.0010527824
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.131211e-02
# 1977810     -1.939310e-03
# 1981360      7.737321e-05
# 1985405      9.157722e-04
# 1987676      6.728472e-04
# 1987719      1.684507e-03
# 1987813     -2.306521e-03
# 1989028      4.061127e-04
# 1989994      3.896529e-04
# 1990232      2.986382e-03
# 1990305      3.973977e-04
# 1990372      4.020817e-04
# 1990469      4.080335e-04
# 1990652      3.930776e-04
# 1997034      5.741808e-04
# 1997580      1.055880e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0113462161
# 1977810     -0.0019656650
# 1981360      0.0001131592
# 1985405      0.0009419654
# 1987676      0.0006587319
# 1987719      0.0016471554
# 1987813     -0.0022641071
# 1989028      0.0004123222
# 1989994      0.0004325020
# 1990232      0.0029743712
# 1990305      0.0003633258
# 1990372      0.0003725917
# 1990469      0.0003970599
# 1990652      0.0004215264
# 1997034      0.0005960073
# 1997580      0.0010527824
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0103019067
# 1977810     -0.0015447488
# 1985405      0.0020711260
# 1987676      0.0004352408
# 1987719      0.0008363085
# 1987813     -0.0028603753
# 1989028      0.0003921985
# 1989994      0.0003758444
# 1990232      0.0014405596
# 1990305      0.0004212733
# 1990372      0.0004181645
# 1990469      0.0004059745
# 1990652      0.0004010637
# 1997034      0.0013364992
# 1997580      0.0009442778
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0103017452
# 1977810     -0.0015589205
# 1985405      0.0020866637
# 1987676      0.0004252337
# 1987719      0.0008028488
# 1987813     -0.0028437246
# 1989028      0.0003859533
# 1989994      0.0003983180
# 1990232      0.0014482678
# 1990305      0.0004081257
# 1990372      0.0004080309
# 1990469      0.0004054086
# 1990652      0.0004053110
# 1997034      0.0013411644
# 1997580      0.0009630803
# 16
# [1] "This cg is: 1987659"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.131894e-02
# 1977810     -1.929980e-03
# 1981360      6.152001e-05
# 1985405      9.418934e-04
# 1987676      6.639831e-04
# 1987719      1.663717e-03
# 1987813     -2.315926e-03
# 1989028      4.091465e-04
# 1989994      3.926067e-04
# 1990232      2.990433e-03
# 1990305      4.003522e-04
# 1990372      4.049402e-04
# 1990469      4.107855e-04
# 1990652      3.955401e-04
# 1997034      5.798777e-04
# 1997580      1.053281e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.135335e-02
# 1977810     -1.957089e-03
# 1981360      9.778682e-05
# 1985405      9.680783e-04
# 1987676      6.474364e-04
# 1987719      1.623954e-03
# 1987813     -2.272831e-03
# 1989028      4.163822e-04
# 1989994      4.370156e-04
# 1990232      2.977780e-03
# 1990305      3.656169e-04
# 1990372      3.764466e-04
# 1990469      4.021029e-04
# 1990652      4.256898e-04
# 1997034      6.010518e-04
# 1997580      1.049143e-03
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.131894e-02
# 1977810     -1.929980e-03
# 1981360      6.152001e-05
# 1985405      9.418934e-04
# 1987676      6.639831e-04
# 1987719      1.663717e-03
# 1987813     -2.315926e-03
# 1989028      4.091465e-04
# 1989994      3.926067e-04
# 1990232      2.990433e-03
# 1990305      4.003522e-04
# 1990372      4.049402e-04
# 1990469      4.107855e-04
# 1990652      3.955401e-04
# 1997034      5.798777e-04
# 1997580      1.053281e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.135335e-02
# 1977810     -1.957089e-03
# 1981360      9.778682e-05
# 1985405      9.680783e-04
# 1987676      6.474364e-04
# 1987719      1.623954e-03
# 1987813     -2.272831e-03
# 1989028      4.163822e-04
# 1989994      4.370156e-04
# 1990232      2.977780e-03
# 1990305      3.656169e-04
# 1990372      3.764466e-04
# 1990469      4.021029e-04
# 1990652      4.256898e-04
# 1997034      6.010518e-04
# 1997580      1.049143e-03
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0103133398
# 1977810     -0.0015411210
# 1985405      0.0020903847
# 1987676      0.0004195735
# 1987719      0.0008201781
# 1987813     -0.0028727358
# 1989028      0.0003966213
# 1989994      0.0003801310
# 1990232      0.0014312252
# 1990305      0.0004265162
# 1990372      0.0004239472
# 1990469      0.0004118247
# 1990652      0.0004065555
# 1997034      0.0013380153
# 1997580      0.0009506091
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0103131313
# 1977810     -0.0015554616
# 1985405      0.0021062938
# 1987676      0.0004100011
# 1987719      0.0007867019
# 1987813     -0.0028558705
# 1989028      0.0003904309
# 1989994      0.0004030015
# 1990232      0.0014391855
# 1990305      0.0004131126
# 1990372      0.0004131285
# 1990469      0.0004106563
# 1990652      0.0004105223
# 1997034      0.0013426774
# 1997580      0.0009697394
# 17
# [1] "This cg is: 1987665"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.132755e-02
# 1977810     -1.911075e-03
# 1981360      2.966147e-05
# 1985405      9.936210e-04
# 1987676      6.462006e-04
# 1987719      1.622155e-03
# 1987813     -2.334363e-03
# 1989028      4.147602e-04
# 1989994      3.980693e-04
# 1990232      2.998587e-03
# 1990305      4.058225e-04
# 1990372      4.102271e-04
# 1990469      4.158658e-04
# 1990652      4.000476e-04
# 1997034      5.907594e-04
# 1997580      1.047982e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.135538e-02
# 1977810     -1.937808e-03
# 1981360      6.386914e-05
# 1985405      1.017082e-03
# 1987676      6.244526e-04
# 1987719      1.578533e-03
# 1987813     -2.294176e-03
# 1989028      4.207077e-04
# 1989994      4.394192e-04
# 1990232      2.985481e-03
# 1990305      3.756159e-04
# 1990372      3.851344e-04
# 1990469      4.093253e-04
# 1990652      4.288310e-04
# 1997034      6.130433e-04
# 1997580      1.049032e-03
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.132755e-02
# 1977810     -1.911075e-03
# 1981360      2.966147e-05
# 1985405      9.936210e-04
# 1987676      6.462006e-04
# 1987719      1.622155e-03
# 1987813     -2.334363e-03
# 1989028      4.147602e-04
# 1989994      3.980693e-04
# 1990232      2.998587e-03
# 1990305      4.058225e-04
# 1990372      4.102271e-04
# 1990469      4.158658e-04
# 1990652      4.000476e-04
# 1997034      5.907594e-04
# 1997580      1.047982e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.135538e-02
# 1977810     -1.937808e-03
# 1981360      6.386914e-05
# 1985405      1.017082e-03
# 1987676      6.244526e-04
# 1987719      1.578533e-03
# 1987813     -2.294176e-03
# 1989028      4.207077e-04
# 1989994      4.394192e-04
# 1990232      2.985481e-03
# 1990305      3.756159e-04
# 1990372      3.851344e-04
# 1990469      4.093253e-04
# 1990652      4.288310e-04
# 1997034      6.130433e-04
# 1997580      1.049032e-03
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0103257693
# 1977810     -0.0015399733
# 1985405      0.0021415173
# 1987676      0.0003980059
# 1987719      0.0007830391
# 1987813     -0.0028880911
# 1989028      0.0004351373
# 1989994      0.0004251789
# 1990232      0.0014112168
# 1990305      0.0004043814
# 1990372      0.0003969987
# 1990469      0.0003907648
# 1990652      0.0003918442
# 1997034      0.0013484751
# 1997580      0.0009954445
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0103350388
# 1977810     -0.0015520732
# 1985405      0.0021518495
# 1987676      0.0003915427
# 1987719      0.0007596180
# 1987813     -0.0028747732
# 1989028      0.0003963891
# 1989994      0.0004057868
# 1990232      0.0014149003
# 1990305      0.0004234007
# 1990372      0.0004207476
# 1990469      0.0004194430
# 1990652      0.0004199914
# 1997034      0.0013443190
# 1997580      0.0009802247
# 18
# [1] "This cg is: 1987669"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.132922e-02
# 1977810     -1.898352e-03
# 1981360      8.334464e-06
# 1985405      1.027588e-03
# 1987676      6.332960e-04
# 1987719      1.593567e-03
# 1987813     -2.346482e-03
# 1989028      4.173011e-04
# 1989994      4.012031e-04
# 1990232      3.003642e-03
# 1990305      4.095194e-04
# 1990372      4.144462e-04
# 1990469      4.199674e-04
# 1990652      4.034039e-04
# 1997034      5.977095e-04
# 1997580      1.044534e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.135751e-02
# 1977810     -1.924623e-03
# 1981360      4.247759e-05
# 1985405      1.051579e-03
# 1987676      6.153217e-04
# 1987719      1.553184e-03
# 1987813     -2.306361e-03
# 1989028      4.229439e-04
# 1989994      4.419471e-04
# 1990232      2.991569e-03
# 1990305      3.785194e-04
# 1990372      3.861567e-04
# 1990469      4.095551e-04
# 1990652      4.309922e-04
# 1997034      6.211540e-04
# 1997580      1.046156e-03
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.132922e-02
# 1977810     -1.898352e-03
# 1981360      8.334464e-06
# 1985405      1.027588e-03
# 1987676      6.332960e-04
# 1987719      1.593567e-03
# 1987813     -2.346482e-03
# 1989028      4.173011e-04
# 1989994      4.012031e-04
# 1990232      3.003642e-03
# 1990305      4.095194e-04
# 1990372      4.144462e-04
# 1990469      4.199674e-04
# 1990652      4.034039e-04
# 1997034      5.977095e-04
# 1997580      1.044534e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.135751e-02
# 1977810     -1.924623e-03
# 1981360      4.247759e-05
# 1985405      1.051579e-03
# 1987676      6.153217e-04
# 1987719      1.553184e-03
# 1987813     -2.306361e-03
# 1989028      4.229439e-04
# 1989994      4.419471e-04
# 1990232      2.991569e-03
# 1990305      3.785194e-04
# 1990372      3.861567e-04
# 1990469      4.095551e-04
# 1990652      4.309922e-04
# 1997034      6.211540e-04
# 1997580      1.046156e-03
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0103384868
# 1977810     -0.0015344239
# 1985405      0.0021671916
# 1987676      0.0003782647
# 1987719      0.0007620535
# 1987813     -0.0029030710
# 1989028      0.0004414795
# 1989994      0.0004318034
# 1990232      0.0013989999
# 1990305      0.0004108920
# 1990372      0.0004034731
# 1990469      0.0003970593
# 1990652      0.0003978814
# 1997034      0.0013490745
# 1997580      0.0010033580
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0103375075
# 1977810     -0.0015448237
# 1985405      0.0021842733
# 1987676      0.0004030601
# 1987719      0.0007654683
# 1987813     -0.0028927511
# 1989028      0.0003999482
# 1989994      0.0003795774
# 1990232      0.0013850592
# 1990305      0.0003868960
# 1990372      0.0004027048
# 1990469      0.0004237247
# 1990652      0.0004429940
# 1997034      0.0013659205
# 1997580      0.0010026629
# 19
# [1] "This cg is: 1987680"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0113616999
# 1977810     -0.0018561384
# 1985405      0.0011164329
# 1987676      0.0005744269
# 1987719      0.0015014332
# 1987813     -0.0023637714
# 1989028      0.0004355576
# 1989994      0.0004152180
# 1990232      0.0030151197
# 1990305      0.0004161742
# 1990372      0.0004203297
# 1990469      0.0004260858
# 1990652      0.0004089283
# 1997034      0.0006144208
# 1997580      0.0010432981
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0113656827
# 1977810     -0.0018801692
# 1985405      0.0011448247
# 1987676      0.0005936824
# 1987719      0.0014888636
# 1987813     -0.0023372289
# 1989028      0.0004246272
# 1989994      0.0004431836
# 1990232      0.0030075145
# 1990305      0.0003886724
# 1990372      0.0003845321
# 1990469      0.0004010089
# 1990652      0.0004290052
# 1997034      0.0006450381
# 1997580      0.0010406912
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0113616999
# 1977810     -0.0018561384
# 1985405      0.0011164329
# 1987676      0.0005744269
# 1987719      0.0015014332
# 1987813     -0.0023637714
# 1989028      0.0004355576
# 1989994      0.0004152180
# 1990232      0.0030151197
# 1990305      0.0004161742
# 1990372      0.0004203297
# 1990469      0.0004260858
# 1990652      0.0004089283
# 1997034      0.0006144208
# 1997580      0.0010432981
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0113656827
# 1977810     -0.0018801692
# ...
# 1990305      0.0002399369
# 1990372      0.0002513149
# 1990469      0.0002607732
# 1990652      0.0002555149
# 1997034      0.0002648202
# 1997580      0.0005817381
# 36
# [1] "This cg is: 1988039"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) -0.002971249
# 1985405      0.001949759
# 1987813     -0.001435939
# 1990232      0.001076941
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) -0.002975211
# 1985405      0.001947089
# 1987813     -0.001433095
# 1990232      0.001080710
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) -0.002971249
# 1985405      0.001949759
# 1987813     -0.001435939
# 1990232      0.001076941
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) -0.002975211
# 1985405      0.001947089
# 1987813     -0.001433095
# 1990232      0.001080710
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -4.213145e-03
# 1985405      2.857100e-03
# 1987813     -2.338051e-03
# 1989028      1.625885e-04
# 1989994      1.842922e-04
# 1990232      1.653729e-04
# 1990305      1.919284e-04
# 1990372      1.967731e-04
# 1990469      1.913056e-04
# 1990652      1.727166e-04
# 1997034      8.993006e-05
# 1997580      4.363250e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0042003228
# 1985405      0.0028751956
# 1987813     -0.0023417573
# 1989028      0.0001689119
# 1989994      0.0001558658
# 1990232      0.0001662625
# 1990305      0.0001656967
# 1990372      0.0001716188
# 1990469      0.0001806626
# 1990652      0.0001897272
# 1997034      0.0001186515
# 1997580      0.0004506935
# 37
# [1] "This cg is: 1988059"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0022328742
# 1985405      0.0016937580
# 1987813     -0.0012947811
# 1990232      0.0007134673
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) -0.002234818
# 1985405      0.001690479
# 1987813     -0.001292972
# 1990232      0.000716965
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0022328742
# 1985405      0.0016937580
# 1987813     -0.0012947811
# 1990232      0.0007134673
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) -0.002234818
# 1985405      0.001690479
# 1987813     -0.001292972
# 1990232      0.000716965
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0031523566
# 1985405      0.0026620325
# 1987813     -0.0021014878
# 1989028      0.0001024916
# 1989994      0.0001147242
# 1990232      0.0001064287
# 1990305      0.0001246389
# 1990372      0.0001334554
# 1990469      0.0001322096
# 1990652      0.0001162240
# 1997580      0.0003307106
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -3.153805e-03
# 1985405      2.658611e-03
# 1987813     -2.097845e-03
# 1989028      9.867779e-05
# 1989994      1.115772e-04
# 1990232      1.175368e-04
# 1990305      1.229295e-04
# 1990372      1.260948e-04
# 1990469      1.312287e-04
# 1990652      1.129827e-04
# 1997580      3.427287e-04
# 38
# [1] "This cg is: 1988066"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0020877547
# 1985405      0.0016670441
# 1987813     -0.0013116032
# 1990232      0.0006448244
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0020898170
# 1985405      0.0016639716
# 1987813     -0.0013097745
# 1990232      0.0006481977
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0020877547
# 1985405      0.0016670441
# 1987813     -0.0013116032
# 1990232      0.0006448244
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0020898170
# 1985405      0.0016639716
# 1987813     -0.0013097745
# 1990232      0.0006481977
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -2.962744e-03
# 1985405      2.656906e-03
# 1987813     -2.106082e-03
# 1989028      1.025544e-04
# 1989994      1.154268e-04
# 1990232      1.025945e-04
# 1990305      1.138150e-04
# 1990372      1.130243e-04
# 1990469      1.060788e-04
# 1990652      9.251743e-05
# 1997580      3.026217e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.956781e-03
# 1985405      2.656322e-03
# 1987813     -2.103963e-03
# 1989028      8.644604e-05
# 1989994      9.666689e-05
# 1990232      1.065537e-04
# 1990305      1.062861e-04
# 1990372      1.092453e-04
# 1990469      1.151267e-04
# 1990652      9.953316e-05
# 1997580      3.245329e-04
# 39
# [1] "This cg is: 1988078"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0015365008
# 1985405      0.0014445973
# 1987813     -0.0011578099
# 1990232      0.0003758696
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0015373614
# 1985405      0.0014419763
# 1987813     -0.0011567508
# 1990232      0.0003783898
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0015365008
# 1985405      0.0014445973
# 1987813     -0.0011578099
# 1990232      0.0003758696
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0015373614
# 1985405      0.0014419763
# 1987813     -0.0011567508
# 1990232      0.0003783898
# [1] "Dim of trainX: 133" "Dim of trainX: 31"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -2.618202e-03
# 1985405      2.651038e-03
# 1987813     -2.117822e-03
# 1989028      6.270712e-05
# 1989994      7.616682e-05
# 1990232      7.806700e-05
# 1990305      8.574023e-05
# 1990372      9.371732e-05
# 1990469      9.124993e-05
# 1990652      7.410882e-05
# 1997580      2.794185e-04
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.616089e-03
# 1985405      2.646220e-03
# 1987813     -2.115444e-03
# 1989028      6.546230e-05
# 1989994      7.377562e-05
# 1990232      8.706316e-05
# 1990305      7.849002e-05
# 1990372      8.340585e-05
# 1990469      9.299406e-05
# 1990652      6.817175e-05
# 1997580      2.941518e-04
# 40
# [1] "This cg is: 1988129"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0004639349
# 1985405      0.0009934173
# 1987813     -0.0010866464
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0004653858
# 1985405      0.0009941828
# 1987813     -0.0010861105
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0004639349
# 1985405      0.0009934173
# 1987813     -0.0010866464
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0004653858
# 1985405      0.0009941828
# 1987813     -0.0010861105
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0005319013
# 1985405      0.0016510969
# 1987813     -0.0012991242
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0005322765
# 1985405      0.0016512990
# 1987813     -0.0012989978
# 41
# [1] "This cg is: 1988133"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0004154921
# 1985405      0.0009594990
# 1987813     -0.0010904941
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0004143418
# 1985405      0.0009588923
# 1987813     -0.0010909195
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0004154921
# 1985405      0.0009594990
# 1987813     -0.0010904941
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0004143418
# 1985405      0.0009588923
# 1987813     -0.0010909195
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0004895706
# 1985405      0.0016242051
# 1987813     -0.0012995089
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0004899446
# 1985405      0.0016244065
# 1987813     -0.0012993827
# 42
# [1] "This cg is: 1988141"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0003168588
# 1985405      0.0008909827
# 1987813     -0.0010992428
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0003157280
# 1985405      0.0008903868
# 1987813     -0.0010996618
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0003168588
# 1985405      0.0008909827
# 1987813     -0.0010992428
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0003157280
# 1985405      0.0008903868
# 1987813     -0.0010996618
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0004043008
# 1985405      0.0015699884
# 1987813     -0.0013009481
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0004046731
# 1985405      0.0015701888
# 1987813     -0.0013008222
# 43
# [1] "This cg is: 1988201"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  0.0005462445
# 1985405      0.0001841893
# 1987813     -0.0009956033
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  0.0005462010
# 1985405      0.0001842122
# 1987813     -0.0009955871
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  0.0005462445
# 1985405      0.0001841893
# 1987813     -0.0009956033
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  0.0005462010
# 1985405      0.0001842122
# 1987813     -0.0009955871
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  0.0007974596
# 1985405      0.0002406181
# 1987813     -0.0003948017
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  0.0007974596
# 1985405      0.0002406181
# 1987813     -0.0003948017
# 44
# [1] "This cg is: 1988216"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  7.567847e-04
# 1985405      5.365033e-05
# 1987813     -1.040684e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  7.550041e-04
# 1985405      5.458574e-05
# 1987813     -1.040020e-03
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  7.567847e-04
# 1985405      5.365033e-05
# 1987813     -1.040684e-03
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  7.550041e-04
# 1985405      5.458574e-05
# 1987813     -1.040020e-03
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008378378
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  8.378378e-04
# 1987813     -4.248440e-18
# 45
# [1] "This cg is: 1988292"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  0.0002426284
# 1987813     -0.0003047438
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  0.0002426284
# 1987813     -0.0003047438
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  0.0002426284
# 1987813     -0.0003047438
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  0.0002426284
# 1987813     -0.0003047438
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008302045
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  8.302045e-04
# 1987813     -1.359443e-18
# 46
# [1] "This cg is: 1988321"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -7.792703e-20
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  5.087886e-19
# 1987813     -7.369210e-19
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -7.792703e-20
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  5.087886e-19
# 1987813     -7.369210e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000812691
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  8.126910e-04
# 1987813     -1.359169e-18
# 47
# [1] "This cg is: 1988325"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.067262e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  1.653251e-18
# 1987813     -2.210550e-18
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.067262e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  1.653251e-18
# 1987813     -2.210550e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008096687
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  8.096687e-04
# 1987813     -1.360154e-18
# 48
# [1] "This cg is: 1988332"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 2.55804e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  2.309365e-18
# 1987813     -2.579294e-18
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 2.55804e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  2.309365e-18
# 1987813     -2.579294e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000804038
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  8.040380e-04
# 1987813     -2.043722e-18
# 49
# [1] "This cg is: 1988401"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.030875e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -6.030875e-19
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.030875e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -6.030875e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000728097
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  7.280970e-04
# 1987813     -2.138701e-18

# %%
models.ea <- models.ea[models.ea[,1] != "(Intercept)",]
models.all <- models.all[models.all[,1] != "(Intercept)",]

# %%
if(!dir.exists(outd)) dir.create(outd)

# %%
head(models.all)
# Out:
#   features coefs         cg
# 2 1977810  -6.513013e-04 1987413
# 3 1981360   1.122917e-03 1987413
# 4 1987719   1.092965e-03 1987413
# 5 1987813  -9.810545e-05 1987413
# 6 1990232   1.171648e-03 1987413
# 7 1994382  -8.527303e-04 1987413

# %%
dim(models.all)
# Out:
# [1] 457   3

# %%
# mwas by models of all samples
cg2 <- unique(models.all$cg)
mwas.all <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.all[models.all$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.all[models.all$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.all[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.all) <- cg2
colnames(mwas.all) <- c("z","p")

# mwas by models of EA samples
cg2 <- unique(models.ea$cg)
mwas.ea <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.ea[models.ea$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.ea[models.ea$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.ea[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.ea) <- cg2
colnames(mwas.ea) <- c("z","p")

# output models and mwas results
outf <- paste0(outd,"/models-a6-covnew.all.wind.",wind[k])
write.csv(models.all,outf)
outf <- paste0(outd,"/models-a6-covnew.ea.wind.",wind[k])
write.csv(models.ea,outf)
outf <- paste0(outd,"/mwas-a6-covnew.all.wind.",wind[k])
write.csv(mwas.all,outf)
outf <- paste0(outd,"/mwas-a6-covnew.ea.wind.",wind[k])
write.csv(mwas.ea,outf)

# %%
mwas.all
# Out:
#         z         p
# 1987413  9.970513 2.051655e-23
# 1987418  9.966191 2.142890e-23
# 1987434 10.000412 1.517646e-23
# 1987449 10.009792 1.380421e-23
# 1987458 10.005523 1.441276e-23
# 1987468 10.017199 1.280820e-23
# 1987492 10.014167 1.320695e-23
# 1987511 10.019431 1.252220e-23
# 1987527 10.017114 1.281911e-23
# 1987565 10.015289 1.305801e-23
# 1987604 10.023224 1.205070e-23
# 1987616 10.021194 1.230075e-23
# 1987627 10.018093 1.269285e-23
# 1987648 10.018436 1.264889e-23
# 1987656 10.015430 1.303936e-23
# 1987659 10.015148 1.307662e-23
# 1987665 10.014793 1.312369e-23
# 1987669 10.014457 1.316829e-23
# 1987680 10.014083 1.321816e-23
# 1987684 10.014248 1.319616e-23
# 1987688 10.014565 1.315395e-23
# 1987697 10.014992 1.309725e-23
# 1987705 10.015516 1.302803e-23
# 1987725 10.017438 1.277723e-23
# 1987732 10.018320 1.266370e-23
# 1987778 10.029526 1.130586e-23
# 1987797 10.028748 1.139528e-23
# 1987808 10.032094 1.101549e-23
# 1987853 10.041310 1.003326e-23
# 1987858 10.036786 1.050414e-23
# 1987861 10.038267 1.034757e-23
# 1987896 10.047735 9.400312e-24
# 1987910 10.048559 9.322049e-24
# 1987930 10.056686 8.583937e-24
# 1988010 10.077813 6.925025e-24
# 1988039 10.066085 7.802219e-24
# 1988059 10.052601 8.947380e-24
# 1988066 10.050352 9.153996e-24
# 1988078 10.033125 1.090109e-23
# 1988129 10.028030 1.147836e-23
# 1988133 10.033651 1.084311e-23
# 1988141 10.044511 9.712834e-24
# 1988201 10.130990 4.025527e-24
# 1988216 10.131053 4.022946e-24
# 1988292 10.125509 4.257597e-24
# 1988321 10.125509 4.257597e-24
# 1988325 10.125509 4.257597e-24
# 1988332 10.125509 4.257597e-24

# %% [markdown]
# We get the same results with old SNPs,

# %% [markdown]
# ## Compare with results from CpGWAS

# %%
# results <- fread("16a9par-OUT_stage2_MWAS_scz.csv")

# results <- results[which(results$chr == 7 & results$pos >= 1987413 & results$pos <= 1988332), ]

# results <- results[which(results$population == "EA" & results$region == "caud"), ]

# head(results)
