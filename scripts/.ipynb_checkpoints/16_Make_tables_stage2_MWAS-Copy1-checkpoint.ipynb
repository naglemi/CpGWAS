# %% [markdown]
# # Produce tables of stage 2 MWAS results

# %%
library(data.table)
library(foreach)
library(doParallel)
# Out:
# Loading required package: iterators
#
# Loading required package: parallel

# %%
getwd()
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts"

# %%
df <- fread("12-OUT_matched_SNP_meth_cov_outputs.csv")

# %%
print(nrow(df))
# Out:
# [1] 16098

# %%
library(data.table)
library(ggplot2)

# Initialize logging
log_file <- file("processing_log.txt", open = "wt")
sink(log_file, type = "message")
sink(log_file, type = "output", append = TRUE)

traits <- c("bp", "mdd", "scz")
df$stage2_paths <- gsub(".rds", "_gwas_stat_", df$path)
df$final_paths <- vector("list", length(df$stage2_paths))

for (trait in traits) {
  message("Processing trait: ", trait)
  df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
  output_file <- paste0("16a6-OUT_stage2_MWAS_", trait, ".csv")
  header_written <- FALSE

  for (i in seq_along(df$final_paths)) {
    if (grepl("empty", df$final_paths[i])) next
    
    message("Processing file ", i, " of ", length(df$final_paths))
    stage2_in <- readRDS(df$final_paths[i])
    stage1_in <- readRDS(df$path[i])
    
    if (length(stage1_in@models) != length(stage2_in@MWASmodels)) {
      stop("Files don't match")
    }

    data_list <- vector("list", length(stage1_in@models))
    for (j in seq_along(stage1_in@models)) {
      model1 <- stage1_in@models[[j]]
      model2 <- stage2_in@MWASmodels[[j]]

      this_z <- model2["z"]
      this_p <- model2["p"]
      this_n <- model2["n"]
      this_pos <- model1@methylationPosition
      this_stats <- stage2_in@summary_stats_path
      this_scaff <- stage1_in@scaffoldIdentifier

      data_list[[j]] <- data.table(
        z = this_z,
        p = this_p,
        n = this_n,
        pos = this_pos,
        stats = this_stats,
        scaff = this_scaff
      )
    }

    combined_data <- rbindlist(data_list, use.names = TRUE, fill = TRUE)

    # Write data incrementally
    if (!header_written) {
      fwrite(combined_data, output_file)
      header_written <- TRUE
    } else {
      fwrite(combined_data, output_file, append = TRUE)
    }
  }
}

# Close the log file
sink(type = "message")
sink(type = "output")
close(log_file)
# Out:
# Processing trait: bp
#
# Processing file 1 of 16098
#
# Processing file 2 of 16098
#
# Processing file 3 of 16098
#
# Processing file 4 of 16098
#
# Processing file 5 of 16098
#
# Processing file 6 of 16098
#
# Processing file 7 of 16098
#
# Processing file 8 of 16098
#
# Processing file 9 of 16098
#
# Processing file 10 of 16098
#
# Processing file 11 of 16098
#
# Processing file 12 of 16098
#
# Processing file 13 of 16098
#
# Processing file 14 of 16098
#
# Processing file 15 of 16098
#
# Processing file 16 of 16098
#
# Processing file 17 of 16098
#
# Processing file 18 of 16098
#
# Processing file 19 of 16098
#
# Processing file 20 of 16098
#
# Processing file 21 of 16098
#
# Processing file 22 of 16098
#
# Processing file 23 of 16098
#
# Processing file 24 of 16098
#
# Processing file 25 of 16098
#
# Processing file 26 of 16098
#
# Processing file 27 of 16098
#
# Processing file 28 of 16098
#
# Processing file 29 of 16098
#
# Processing file 30 of 16098
#
# Processing file 31 of 16098
#
# Processing file 32 of 16098
#
# Processing file 33 of 16098
#
# Processing file 34 of 16098
#
# Processing file 35 of 16098
#
# Processing file 36 of 16098
#
# Processing file 37 of 16098
#
# Processing file 38 of 16098
#
# Processing file 39 of 16098
#
# Processing file 40 of 16098
#
# Processing file 41 of 16098
#
# Processing file 42 of 16098
#
# Processing file 43 of 16098
#
# Processing file 44 of 16098
#
# Processing file 45 of 16098
#
# Processing file 46 of 16098
#
# Processing file 47 of 16098
#
# Processing file 48 of 16098
#
# Processing file 49 of 16098
#
# Processing file 50 of 16098
#
# Processing file 51 of 16098
#
# Processing file 52 of 16098
#
# Processing file 53 of 16098
#
# Processing file 54 of 16098
#
# Processing file 55 of 16098
#
# Processing file 56 of 16098
#
# Processing file 57 of 16098
#
# Processing file 58 of 16098
#
# Processing file 59 of 16098
#
# Processing file 60 of 16098
#
# Processing file 61 of 16098
#
# Processing file 62 of 16098
#
# Processing file 63 of 16098
#
# Processing file 64 of 16098
#
# Processing file 65 of 16098
#
# Processing file 66 of 16098
#
# Processing file 67 of 16098
#
# Processing file 68 of 16098
#
# Processing file 69 of 16098
#
# Processing file 70 of 16098
#
# Processing file 71 of 16098
#
# Processing file 72 of 16098
#
# Processing file 73 of 16098
#
# Processing file 74 of 16098
#
# Processing file 75 of 16098
#
# Processing file 76 of 16098
#
# Processing file 77 of 16098
#
# Processing file 78 of 16098
#
# Processing file 79 of 16098
#
# Processing file 80 of 16098
#
# Processing file 81 of 16098
#
# Processing file 82 of 16098
#
# Processing file 83 of 16098
#
# Processing file 84 of 16098
#
# Processing file 85 of 16098
#
# Processing file 86 of 16098
#
# Processing file 87 of 16098
#
# Processing file 88 of 16098
#
# Processing file 89 of 16098
#
# Processing file 90 of 16098
#
# Processing file 91 of 16098
#
# Processing file 92 of 16098
#
# Processing file 93 of 16098
#
# Processing file 94 of 16098
#
# Processing file 95 of 16098
#
# Processing file 96 of 16098
#
# Processing file 97 of 16098
#
# Processing file 98 of 16098
#
# Processing file 99 of 16098
#
# Processing file 100 of 16098
#
# Processing file 101 of 16098
#
# Processing file 102 of 16098
#
# Processing file 103 of 16098
#
# Processing file 104 of 16098
#
# Processing file 105 of 16098
#
# Processing file 106 of 16098
#
# Processing file 107 of 16098
#
# Processing file 108 of 16098
#
# Processing file 109 of 16098
#
# Processing file 110 of 16098
#
# Processing file 111 of 16098
#
# Processing file 112 of 16098
#
# Processing file 113 of 16098
#
# Processing file 114 of 16098
#
# Processing file 115 of 16098
#
# Processing file 116 of 16098
#
# Processing file 117 of 16098
#
# Processing file 118 of 16098
#
# Processing file 119 of 16098
#
# Processing file 120 of 16098
#
# Processing file 121 of 16098
#
# Processing file 122 of 16098
#
# Processing file 123 of 16098
#
# Processing file 124 of 16098
#
# Processing file 129 of 16098
#
# Processing file 130 of 16098
#
# Processing file 131 of 16098
#
# Processing file 132 of 16098
#
# Processing file 133 of 16098
#
# Processing file 134 of 16098
#
# Processing file 135 of 16098
#
# Processing file 136 of 16098
#
# Processing file 137 of 16098
#
# Processing file 138 of 16098
#
# Processing file 139 of 16098
#
# Processing file 140 of 16098
#
# Processing file 141 of 16098
#
# Processing file 142 of 16098
#
# Processing file 143 of 16098
#
# Processing file 144 of 16098
#
# Processing file 145 of 16098
#
# Processing file 146 of 16098
#
# Processing file 147 of 16098
#
# Processing file 148 of 16098
#
# Processing file 149 of 16098
#
# Processing file 150 of 16098
#
# Processing file 151 of 16098
#
# Processing file 152 of 16098
#
# Processing file 153 of 16098
#
# Processing file 154 of 16098
#
# Processing file 155 of 16098
#
# Processing file 156 of 16098
#
# Processing file 157 of 16098
#
# Processing file 158 of 16098
#
# Processing file 159 of 16098
#
# Processing file 160 of 16098
#
# Processing file 161 of 16098
#
# Processing file 162 of 16098
#
# Processing file 163 of 16098
#
# Processing file 164 of 16098
#
# Processing file 165 of 16098
#
# Processing file 166 of 16098
#
# Processing file 167 of 16098
#
# Processing file 168 of 16098
#
# Processing file 169 of 16098
#
# Processing file 170 of 16098
#
# Processing file 171 of 16098
#
# Processing file 172 of 16098
#
# Processing file 173 of 16098
#
# Processing file 174 of 16098
#
# Processing file 175 of 16098
#
# Processing file 176 of 16098
#
# Processing file 177 of 16098
#
# Processing file 178 of 16098
#
# Processing file 179 of 16098
#
# Processing file 180 of 16098
#
# Processing file 181 of 16098
#
# Processing file 182 of 16098
#
# Processing file 183 of 16098
#
# Processing file 184 of 16098
#
# Processing file 185 of 16098
#
# Processing file 186 of 16098
#
# Processing file 187 of 16098
#
# Processing file 188 of 16098
#
# Processing file 189 of 16098
#
# Processing file 190 of 16098
#
# Processing file 191 of 16098
#
# Processing file 192 of 16098
#
# Processing file 193 of 16098
#
# Processing file 194 of 16098
#
# Processing file 195 of 16098
#
# Processing file 196 of 16098
#
# Processing file 197 of 16098
#
# Processing file 198 of 16098
#
# Processing file 199 of 16098
#
# Processing file 200 of 16098
#
# Processing file 201 of 16098
#
# Processing file 202 of 16098
#
# Processing file 203 of 16098
#
# Processing file 204 of 16098
#
# Processing file 205 of 16098
#
# Processing file 206 of 16098
#
# Processing file 207 of 16098
#
# Processing file 208 of 16098
#
# Processing file 209 of 16098
#
# Processing file 210 of 16098
#
# Processing file 211 of 16098
#
# Processing file 212 of 16098
#
# Processing file 213 of 16098
#
# Processing file 214 of 16098
#
# Processing file 215 of 16098
#
# Processing file 216 of 16098
#
# Processing file 217 of 16098
#
# Processing file 218 of 16098
#
# Processing file 219 of 16098
#
# Processing file 220 of 16098
#
# Processing file 221 of 16098
#
# Processing file 222 of 16098
#
# Processing file 223 of 16098
#
# Processing file 224 of 16098
#
# Processing file 225 of 16098
#
# Processing file 226 of 16098
#
# Processing file 227 of 16098
#
# Processing file 228 of 16098
#
# Processing file 229 of 16098
#
# Processing file 230 of 16098
#
# Processing file 231 of 16098
#
# Processing file 232 of 16098
#
# Processing file 233 of 16098
#
# Processing file 234 of 16098
#
# Processing file 235 of 16098
#
# Processing file 236 of 16098
#
# Processing file 237 of 16098
#
# Processing file 238 of 16098
#
# Processing file 239 of 16098
#
# Processing file 240 of 16098
#
# Processing file 241 of 16098
#
# Processing file 242 of 16098
#
# Processing file 243 of 16098
#
# Processing file 244 of 16098
#
# Processing file 245 of 16098
#
# Processing file 246 of 16098
#
# Processing file 247 of 16098
#
# Processing file 248 of 16098
#
# Processing file 249 of 16098
#
# Processing file 250 of 16098
#
# Processing file 251 of 16098
#
# Processing file 252 of 16098
#
# Processing file 253 of 16098
#
# Processing file 254 of 16098
#
# Processing file 255 of 16098
#
# Processing file 256 of 16098
#
# Processing file 257 of 16098
#
# Processing file 258 of 16098
#
# Processing file 259 of 16098
#
# Processing file 260 of 16098
#
# Processing file 261 of 16098
#
# Processing file 262 of 16098
#
# Processing file 263 of 16098
#
# Processing file 264 of 16098
#
# Processing file 265 of 16098
#
# Processing file 266 of 16098
#
# Processing file 267 of 16098
#
# Processing file 268 of 16098
#
# Processing file 269 of 16098
#
# Processing file 270 of 16098
#
# Processing file 271 of 16098
#
# Processing file 272 of 16098
#
# Processing file 273 of 16098
#
# Processing file 274 of 16098
#
# Processing file 275 of 16098
#
# Processing file 276 of 16098
#
# Processing file 277 of 16098
#
# Processing file 278 of 16098
#
# Processing file 279 of 16098
#
# Processing file 280 of 16098
#
# Processing file 281 of 16098
#
# Processing file 282 of 16098
#
# Processing file 283 of 16098
#
# Processing file 284 of 16098
#
# Processing file 285 of 16098
#
# Processing file 286 of 16098
#
# Processing file 287 of 16098
#
# Processing file 288 of 16098
#
# Processing file 289 of 16098
#
# Processing file 290 of 16098
#
# Processing file 291 of 16098
#
# Processing file 292 of 16098
#
# Processing file 293 of 16098
#
# Processing file 294 of 16098
#
# Processing file 295 of 16098
#
# Processing file 296 of 16098
#
# Processing file 297 of 16098
#
# Processing file 298 of 16098
#
# Processing file 299 of 16098
#
# Processing file 300 of 16098
#
# Processing file 301 of 16098
#
# Processing file 302 of 16098
#
# Processing file 303 of 16098
#
# Processing file 304 of 16098
#
# Processing file 305 of 16098
#
# Processing file 306 of 16098
#
# Processing file 307 of 16098
#
# Processing file 308 of 16098
#
# Processing file 309 of 16098
#
# Processing file 310 of 16098
#
# Processing file 311 of 16098
#
# Processing file 312 of 16098
#
# Processing file 313 of 16098
#
# Processing file 314 of 16098
#
# Processing file 315 of 16098
#
# Processing file 316 of 16098
#
# Processing file 317 of 16098
#
# Processing file 318 of 16098
#
# Processing file 319 of 16098
#
# Processing file 320 of 16098
#
# Processing file 321 of 16098
#
# Processing file 322 of 16098
#
# Processing file 323 of 16098
#
# Processing file 324 of 16098
#
# Processing file 325 of 16098
#
# Processing file 326 of 16098
#
# Processing file 327 of 16098
#
# Processing file 328 of 16098
#
# Processing file 329 of 16098
#
# Processing file 330 of 16098
#
# Processing file 331 of 16098
#
# Processing file 332 of 16098
#
# Processing file 333 of 16098
#
# Processing file 334 of 16098
#
# Processing file 335 of 16098
#
# Processing file 336 of 16098
#
# Processing file 337 of 16098
#
# Processing file 338 of 16098
#
# Processing file 339 of 16098
#
# Processing file 340 of 16098
#
# Processing file 341 of 16098
#
# Processing file 342 of 16098
#
# Processing file 343 of 16098
#
# Processing file 344 of 16098
#
# Processing file 349 of 16098
#
# Processing file 350 of 16098
#
# Processing file 351 of 16098
#
# Processing file 352 of 16098
#
# Processing file 353 of 16098
#
# Processing file 354 of 16098
#
# Processing file 355 of 16098
#
# Processing file 356 of 16098
#
# Processing file 357 of 16098
#
# Processing file 358 of 16098
#
# Processing file 359 of 16098
#
# Processing file 360 of 16098
#
# Processing file 361 of 16098
#
# Processing file 362 of 16098
#
# Processing file 363 of 16098
#
# Processing file 364 of 16098
#
# Processing file 365 of 16098
#
# Processing file 366 of 16098
#
# Processing file 367 of 16098
#
# Processing file 368 of 16098
#
# Processing file 369 of 16098
#
# Processing file 370 of 16098
#
# Processing file 371 of 16098
#
# Processing file 372 of 16098
#
# Processing file 373 of 16098
#
# Processing file 374 of 16098
#
# Processing file 375 of 16098
#
# Processing file 376 of 16098
#
# Processing file 377 of 16098
#
# Processing file 378 of 16098
#
# Processing file 379 of 16098
#
# Processing file 380 of 16098
#
# Processing file 381 of 16098
#
# Processing file 382 of 16098
#
# Processing file 383 of 16098
#
# Processing file 384 of 16098
#
# Processing file 385 of 16098
#
# Processing file 386 of 16098
#
# Processing file 387 of 16098
#
# Processing file 388 of 16098
#
# Processing file 389 of 16098
#
# Processing file 390 of 16098
#
# Processing file 391 of 16098
#
# Processing file 392 of 16098
#
# Processing file 393 of 16098
#
# Processing file 394 of 16098
#
# Processing file 395 of 16098
#
# Processing file 396 of 16098
#
# Processing file 397 of 16098
#
# Processing file 398 of 16098
#
# Processing file 399 of 16098
#
# Processing file 400 of 16098
#
# Processing file 401 of 16098
#
# Processing file 402 of 16098
#
# Processing file 403 of 16098
#
# Processing file 404 of 16098
#
# Processing file 405 of 16098
#
# Processing file 406 of 16098
#
# Processing file 407 of 16098
#
# Processing file 408 of 16098
#
# Processing file 409 of 16098
#
# Processing file 410 of 16098
#
# Processing file 411 of 16098
#
# Processing file 412 of 16098
#
# Processing file 413 of 16098
#
# Processing file 414 of 16098
#
# Processing file 415 of 16098
#
# Processing file 416 of 16098
#
# Processing file 417 of 16098
#
# Processing file 418 of 16098
#
# Processing file 419 of 16098
#
# Processing file 420 of 16098
#
# Processing file 421 of 16098
#
# Processing file 422 of 16098
#
# Processing file 423 of 16098
#
# Processing file 424 of 16098
#
# Processing file 425 of 16098
#
# Processing file 426 of 16098
#
# Processing file 427 of 16098
#
# Processing file 428 of 16098
#
# Processing file 429 of 16098
#
# Processing file 430 of 16098
#
# Processing file 431 of 16098
#
# Processing file 432 of 16098
#
# Processing file 433 of 16098
#
# Processing file 434 of 16098
#
# Processing file 435 of 16098
#
# Processing file 436 of 16098
#
# Processing file 437 of 16098
#
# Processing file 438 of 16098
#
# Processing file 439 of 16098
#
# Processing file 440 of 16098
#
# Processing file 441 of 16098
#
# Processing file 442 of 16098
#
# Processing file 443 of 16098
#
# Processing file 444 of 16098
#
# Processing file 445 of 16098
#
# Processing file 446 of 16098
#
# Processing file 447 of 16098
#
# Processing file 448 of 16098
#
# Processing file 449 of 16098
#
# Processing file 450 of 16098
#
# Processing file 451 of 16098
#
# Processing file 452 of 16098
#
# Processing file 453 of 16098
#
# Processing file 454 of 16098
#
# Processing file 455 of 16098
#
# Processing file 456 of 16098
#
# Processing file 457 of 16098
#
# Processing file 458 of 16098
#
# Processing file 459 of 16098
#
# Processing file 460 of 16098
#
# Processing file 461 of 16098
#
# Processing file 462 of 16098
#
# Processing file 463 of 16098
#
# Processing file 464 of 16098
#
# Processing file 465 of 16098
#
# Processing file 466 of 16098
#
# Processing file 467 of 16098
#
# Processing file 468 of 16098
#
# Processing file 469 of 16098
#
# Processing file 470 of 16098
#
# Processing file 471 of 16098
#
# Processing file 472 of 16098
#
# Processing file 473 of 16098
#
# Processing file 474 of 16098
#
# Processing file 475 of 16098
#
# Processing file 476 of 16098
#
# Processing file 477 of 16098
#
# Processing file 478 of 16098
#
# Processing file 479 of 16098
#
# Processing file 480 of 16098
#
# Processing file 481 of 16098
#
# Processing file 482 of 16098
#
# Processing file 483 of 16098
#
# Processing file 484 of 16098
#
# Processing file 485 of 16098
#
# Processing file 486 of 16098
#
# Processing file 487 of 16098
#
# Processing file 488 of 16098
#
# Processing file 489 of 16098
#
# Processing file 490 of 16098
#
# Processing file 491 of 16098
#
# Processing file 492 of 16098
#
# Processing file 493 of 16098
#
# Processing file 494 of 16098
#
# Processing file 495 of 16098
#
# Processing file 496 of 16098
#
# Processing file 497 of 16098
#
# Processing file 498 of 16098
#
# Processing file 499 of 16098
#
# Processing file 500 of 16098
#
# Processing file 501 of 16098
#
# Processing file 502 of 16098
#
# Processing file 503 of 16098
#
# Processing file 504 of 16098
#
# Processing file 505 of 16098
#
# Processing file 506 of 16098
#
# Processing file 507 of 16098
#
# Processing file 508 of 16098
#
# Processing file 509 of 16098
#
# Processing file 510 of 16098
#
# Processing file 511 of 16098
#
# Processing file 512 of 16098
#
# Processing file 513 of 16098
#
# Processing file 514 of 16098
#
# Processing file 515 of 16098
#
# Processing file 516 of 16098
#
# Processing file 517 of 16098
#
# Processing file 518 of 16098
#
# Processing file 519 of 16098
#
# Processing file 520 of 16098
#
# Processing file 521 of 16098
#
# Processing file 522 of 16098
#
# Processing file 523 of 16098
#
# Processing file 524 of 16098
#
# Processing file 525 of 16098
#
# Processing file 526 of 16098
#
# Processing file 527 of 16098
#
# Processing file 528 of 16098
#
# Processing file 529 of 16098
#
# Processing file 530 of 16098
#
# Processing file 531 of 16098
#
# Processing file 532 of 16098
#
# Processing file 533 of 16098
#
# Processing file 534 of 16098
#
# Processing file 535 of 16098
#
# Processing file 536 of 16098
#
# Processing file 537 of 16098
#
# Processing file 538 of 16098
#
# Processing file 539 of 16098
#
# Processing file 540 of 16098
#
# Processing file 541 of 16098
#
# Processing file 542 of 16098
#
# Processing file 543 of 16098
#
# Processing file 544 of 16098
#
# Processing file 545 of 16098
#
# Processing file 546 of 16098
#
# Processing file 547 of 16098
#
# Processing file 548 of 16098
#
# Processing file 549 of 16098
#
# Processing file 550 of 16098
#
# Processing file 551 of 16098
#
# Processing file 552 of 16098
#
# Processing file 553 of 16098
#
# Processing file 554 of 16098
#
# Processing file 555 of 16098
#
# Processing file 556 of 16098
#
# Processing file 557 of 16098
#
# Processing file 558 of 16098
#
# Processing file 559 of 16098
#
# Processing file 560 of 16098
#
# Processing file 565 of 16098
#
# Processing file 566 of 16098
#
# Processing file 567 of 16098
#
# Processing file 568 of 16098
#
# Processing file 569 of 16098
#
# Processing file 570 of 16098
#
# Processing file 571 of 16098
#
# Processing file 572 of 16098
#
# Processing file 573 of 16098
#
# Processing file 574 of 16098
#
# Processing file 575 of 16098
#
# Processing file 576 of 16098
#
# Processing file 577 of 16098
#
# Processing file 578 of 16098
#
# Processing file 579 of 16098
#
# Processing file 580 of 16098
#
# Processing file 581 of 16098
#
# Processing file 582 of 16098
#
# Processing file 583 of 16098
#
# Processing file 584 of 16098
#
# Processing file 585 of 16098
#
# Processing file 586 of 16098
#
# Processing file 587 of 16098
#
# Processing file 588 of 16098
#
# Processing file 589 of 16098
#
# Processing file 590 of 16098
#
# Processing file 591 of 16098
#
# Processing file 592 of 16098
#
# Processing file 593 of 16098
#
# Processing file 594 of 16098
#
# Processing file 595 of 16098
#
# Processing file 596 of 16098
#
# Processing file 597 of 16098
#
# Processing file 598 of 16098
#
# Processing file 599 of 16098
#
# Processing file 600 of 16098
#
# Processing file 601 of 16098
#
# Processing file 602 of 16098
#
# Processing file 603 of 16098
#
# Processing file 604 of 16098
#
# Processing file 605 of 16098
#
# Processing file 606 of 16098
#
# Processing file 607 of 16098
#
# Processing file 608 of 16098
#
# Processing file 609 of 16098
#
# Processing file 610 of 16098
#
# Processing file 611 of 16098
#
# Processing file 612 of 16098
#
# Processing file 613 of 16098
#
# Processing file 614 of 16098
#
# Processing file 615 of 16098
#
# Processing file 616 of 16098
#
# Processing file 617 of 16098
#
# Processing file 618 of 16098
#
# Processing file 619 of 16098
#
# Processing file 620 of 16098
#
# Processing file 621 of 16098
#
# Processing file 622 of 16098
#
# Processing file 623 of 16098
#
# Processing file 624 of 16098
#
# Processing file 625 of 16098
#
# Processing file 626 of 16098
#
# Processing file 627 of 16098
#
# Processing file 628 of 16098
#
# Processing file 629 of 16098
#
# Processing file 630 of 16098
#
# Processing file 631 of 16098
#
# Processing file 632 of 16098
#
# Processing file 633 of 16098
#
# Processing file 634 of 16098
#
# Processing file 635 of 16098
#
# Processing file 636 of 16098
#
# Processing file 637 of 16098
#
# Processing file 638 of 16098
#
# Processing file 639 of 16098
#
# Processing file 640 of 16098
#
# Processing file 641 of 16098
#
# Processing file 642 of 16098
#
# Processing file 643 of 16098
#
# Processing file 644 of 16098
#
# Processing file 645 of 16098
#
# Processing file 646 of 16098
#
# Processing file 647 of 16098
#
# Processing file 648 of 16098
#
# Processing file 649 of 16098
#
# Processing file 650 of 16098
#
# Processing file 651 of 16098
#
# Processing file 652 of 16098
#
# Processing file 653 of 16098
#
# Processing file 654 of 16098
#
# Processing file 655 of 16098
#
# Processing file 656 of 16098
#
# Processing file 657 of 16098
#
# Processing file 658 of 16098
#
# Processing file 659 of 16098
#
# Processing file 660 of 16098
#
# Processing file 661 of 16098
#
# Processing file 662 of 16098
#
# Processing file 663 of 16098
#
# Processing file 664 of 16098
#
# Processing file 665 of 16098
#
# Processing file 666 of 16098
#
# Processing file 667 of 16098
#
# Processing file 668 of 16098
#
# Processing file 669 of 16098
#
# Processing file 670 of 16098
#
# Processing file 671 of 16098
#
# Processing file 672 of 16098
#
# Processing file 673 of 16098
#
# Processing file 674 of 16098
#
# Processing file 675 of 16098
#
# Processing file 676 of 16098
#
# Processing file 677 of 16098
#
# Processing file 678 of 16098
#
# Processing file 679 of 16098
#
# Processing file 680 of 16098
#
# Processing file 681 of 16098
#
# Processing file 682 of 16098
#
# Processing file 683 of 16098
#
# Processing file 684 of 16098
#
# Processing file 685 of 16098
#
# Processing file 686 of 16098
#
# Processing file 687 of 16098
#
# Processing file 688 of 16098
#
# Processing file 689 of 16098
#
# Processing file 690 of 16098
#
# Processing file 691 of 16098
#
# Processing file 692 of 16098
#
# Processing file 693 of 16098
#
# Processing file 694 of 16098
#
# Processing file 695 of 16098
#
# Processing file 696 of 16098
#
# Processing file 697 of 16098
#
# Processing file 698 of 16098
#
# Processing file 699 of 16098
#
# Processing file 700 of 16098
#
# Processing file 701 of 16098
#
# Processing file 702 of 16098
#
# Processing file 703 of 16098
#
# Processing file 704 of 16098
#
# Processing file 705 of 16098
#
# Processing file 706 of 16098
#
# Processing file 707 of 16098
#
# Processing file 708 of 16098
#
# Processing file 709 of 16098
#
# Processing file 710 of 16098
#
# Processing file 711 of 16098
#
# Processing file 712 of 16098
#
# Processing file 713 of 16098
#
# Processing file 714 of 16098
#
# Processing file 715 of 16098
#
# Processing file 716 of 16098
#
# Processing file 717 of 16098
#
# Processing file 718 of 16098
#
# Processing file 719 of 16098
#
# Processing file 720 of 16098
#
# Processing file 721 of 16098
#
# Processing file 722 of 16098
#
# Processing file 723 of 16098
#
# Processing file 724 of 16098
#
# Processing file 725 of 16098
#
# Processing file 726 of 16098
#
# Processing file 727 of 16098
#
# Processing file 728 of 16098
#
# Processing file 729 of 16098
#
# Processing file 730 of 16098
#
# Processing file 731 of 16098
#
# Processing file 732 of 16098
#
# Processing file 733 of 16098
#
# Processing file 734 of 16098
#
# Processing file 735 of 16098
#
# Processing file 736 of 16098
#
# Processing file 737 of 16098
#
# Processing file 738 of 16098
#
# Processing file 739 of 16098
#
# Processing file 740 of 16098
#
# Processing file 741 of 16098
#
# Processing file 742 of 16098
#
# Processing file 743 of 16098
#
# Processing file 744 of 16098
#
# Processing file 745 of 16098
#
# Processing file 746 of 16098
#
# Processing file 747 of 16098
#
# Processing file 748 of 16098
#
# Processing file 749 of 16098
#
# Processing file 750 of 16098
#
# Processing file 751 of 16098
#
# Processing file 752 of 16098
#
# Processing file 753 of 16098
#
# Processing file 754 of 16098
#
# Processing file 755 of 16098
#
# Processing file 756 of 16098
#
# Processing file 757 of 16098
#
# Processing file 758 of 16098
#
# Processing file 759 of 16098
#
# Processing file 760 of 16098
#
# Processing file 761 of 16098
#
# Processing file 762 of 16098
#
# Processing file 763 of 16098
#
# Processing file 764 of 16098
#
# Processing file 765 of 16098
#
# Processing file 766 of 16098
#
# Processing file 767 of 16098
#
# Processing file 768 of 16098
#
# Processing file 769 of 16098
#
# Processing file 770 of 16098
#
# Processing file 771 of 16098
#
# Processing file 772 of 16098
#
# Processing file 773 of 16098
#
# Processing file 774 of 16098
#
# Processing file 775 of 16098
#
# Processing file 776 of 16098
#
# Processing file 777 of 16098
#
# Processing file 782 of 16098
#
# Processing file 783 of 16098
#
# Processing file 784 of 16098
#
# Processing file 785 of 16098
#
# Processing file 786 of 16098
#
# Processing file 787 of 16098
#
# Processing file 788 of 16098
#
# Processing file 789 of 16098
#
# Processing file 790 of 16098
#
# Processing file 791 of 16098
#
# Processing file 792 of 16098
#
# Processing file 793 of 16098
#
# Processing file 794 of 16098
#
# Processing file 795 of 16098
#
# Processing file 796 of 16098
#
# Processing file 797 of 16098
#
# Processing file 798 of 16098
#
# Processing file 799 of 16098
#
# Processing file 800 of 16098
#
# Processing file 801 of 16098
#
# Processing file 802 of 16098
#
# Processing file 803 of 16098
#
# Processing file 804 of 16098
#
# Processing file 805 of 16098
#
# Processing file 806 of 16098
#
# Processing file 807 of 16098
#
# Processing file 808 of 16098
#
# Processing file 809 of 16098
#
# Processing file 810 of 16098
#
# Processing file 811 of 16098
#
# Processing file 812 of 16098
#
# Processing file 813 of 16098
#
# Processing file 814 of 16098
#
# Processing file 815 of 16098
#
# Processing file 816 of 16098
#
# Processing file 817 of 16098
#
# Processing file 818 of 16098
#
# Processing file 819 of 16098
#
# Processing file 820 of 16098
#
# Processing file 821 of 16098
#
# Processing file 822 of 16098
#
# Processing file 823 of 16098
#
# Processing file 824 of 16098
#
# Processing file 825 of 16098
#
# Processing file 826 of 16098
#
# Processing file 827 of 16098
#
# Processing file 828 of 16098
#
# Processing file 829 of 16098
#
# Processing file 830 of 16098
#
# Processing file 831 of 16098
#
# Processing file 832 of 16098
#
# Processing file 833 of 16098
#
# Processing file 834 of 16098
#
# Processing file 835 of 16098
#
# Processing file 836 of 16098
#
# Processing file 837 of 16098
#
# Processing file 838 of 16098
#
# Processing file 839 of 16098
#
# Processing file 840 of 16098
#
# Processing file 841 of 16098
#
# Processing file 842 of 16098
#
# Processing file 843 of 16098
#
# Processing file 844 of 16098
#
# Processing file 845 of 16098
#
# Processing file 846 of 16098
#
# Processing file 847 of 16098
#
# Processing file 848 of 16098
#
# Processing file 849 of 16098
#
# Processing file 850 of 16098
#
# Processing file 851 of 16098
#
# Processing file 852 of 16098
#
# Processing file 853 of 16098
#
# Processing file 854 of 16098
#
# Processing file 855 of 16098
#
# Processing file 856 of 16098
#
# Processing file 857 of 16098
#
# Processing file 858 of 16098
#
# Processing file 859 of 16098
#
# Processing file 860 of 16098
#
# Processing file 861 of 16098
#
# Processing file 862 of 16098
#
# Processing file 863 of 16098
#
# Processing file 864 of 16098
#
# Processing file 865 of 16098
#
# Processing file 866 of 16098
#
# Processing file 867 of 16098
#
# Processing file 868 of 16098
#
# Processing file 869 of 16098
#
# Processing file 870 of 16098
#
# Processing file 871 of 16098
#
# Processing file 872 of 16098
#
# Processing file 873 of 16098
#
# Processing file 874 of 16098
#
# Processing file 875 of 16098
#
# Processing file 876 of 16098
#
# Processing file 877 of 16098
#
# Processing file 878 of 16098
#
# Processing file 879 of 16098
#
# Processing file 880 of 16098
#
# Processing file 881 of 16098
#
# Processing file 882 of 16098
#
# Processing file 883 of 16098
#
# Processing file 884 of 16098
#
# Processing file 885 of 16098
#
# Processing file 886 of 16098
#
# Processing file 887 of 16098
#
# Processing file 888 of 16098
#
# Processing file 889 of 16098
#
# Processing file 890 of 16098
#
# Processing file 891 of 16098
#
# Processing file 892 of 16098
#
# Processing file 893 of 16098
#
# Processing file 894 of 16098
#
# Processing file 895 of 16098
#
# Processing file 896 of 16098
#
# Processing file 897 of 16098
#
# Processing file 898 of 16098
#
# Processing file 899 of 16098
#
# Processing file 900 of 16098
#
# Processing file 901 of 16098
#
# Processing file 902 of 16098
#
# Processing file 903 of 16098
#
# Processing file 904 of 16098
#
# Processing file 905 of 16098
#
# Processing file 906 of 16098
#
# Processing file 907 of 16098
#
# Processing file 908 of 16098
#
# Processing file 909 of 16098
#
# Processing file 910 of 16098
#
# Processing file 911 of 16098
#
# Processing file 912 of 16098
#
# Processing file 913 of 16098
#
# Processing file 914 of 16098
#
# Processing file 915 of 16098
#
# Processing file 916 of 16098
#
# Processing file 917 of 16098
#
# Processing file 918 of 16098
#
# Processing file 919 of 16098
#
# Processing file 920 of 16098
#
# Processing file 921 of 16098
#
# Processing file 922 of 16098
#
# Processing file 923 of 16098
#
# Processing file 924 of 16098
#
# Processing file 925 of 16098
#
# Processing file 926 of 16098
#
# Processing file 927 of 16098
#
# Processing file 928 of 16098
#
# Processing file 929 of 16098
#
# Processing file 930 of 16098
#
# Processing file 931 of 16098
#
# Processing file 932 of 16098
#
# Processing file 933 of 16098
#
# Processing file 934 of 16098
#
# Processing file 935 of 16098
#
# Processing file 936 of 16098
#
# Processing file 937 of 16098
#
# Processing file 938 of 16098
#
# Processing file 939 of 16098
#
# Processing file 940 of 16098
#
# Processing file 941 of 16098
#
# Processing file 942 of 16098
#
# Processing file 943 of 16098
#
# Processing file 944 of 16098
#
# Processing file 945 of 16098
#
# Processing file 946 of 16098
#
# Processing file 947 of 16098
#
# Processing file 948 of 16098
#
# Processing file 949 of 16098
#
# Processing file 950 of 16098
#
# Processing file 951 of 16098
#
# Processing file 952 of 16098
#
# Processing file 953 of 16098
#
# Processing file 954 of 16098
#
# Processing file 955 of 16098
#
# Processing file 956 of 16098
#
# Processing file 957 of 16098
#
# Processing file 958 of 16098
#
# Processing file 959 of 16098
#
# Processing file 960 of 16098
#
# Processing file 961 of 16098
#
# Processing file 962 of 16098
#
# Processing file 963 of 16098
#
# Processing file 964 of 16098
#
# Processing file 965 of 16098
#
# Processing file 966 of 16098
#
# Processing file 967 of 16098
#
# Processing file 968 of 16098
#
# Processing file 969 of 16098
#
# Processing file 970 of 16098
#
# Processing file 971 of 16098
#
# Processing file 972 of 16098
#
# Processing file 973 of 16098
#
# Processing file 974 of 16098
#
# Processing file 975 of 16098
#
# Processing file 976 of 16098
#
# Processing file 977 of 16098
#
# Processing file 978 of 16098
#
# Processing file 979 of 16098
#
# Processing file 980 of 16098
#
# Processing file 981 of 16098
#
# Processing file 982 of 16098
#
# Processing file 983 of 16098
#
# Processing file 984 of 16098
#
# Processing file 985 of 16098
#
# Processing file 986 of 16098
#
# Processing file 987 of 16098
#
# Processing file 988 of 16098
#
# Processing file 989 of 16098
#
# Processing file 990 of 16098
#
# Processing file 991 of 16098
#
# Processing file 992 of 16098
#
# Processing file 993 of 16098
#
# Processing file 994 of 16098
#
# Processing file 995 of 16098
#
# Processing file 996 of 16098
#
# Processing file 997 of 16098
#
# Processing file 1002 of 16098
#
# Processing file 1003 of 16098
#
# Processing file 1004 of 16098
#
# Processing file 1005 of 16098
#
# Processing file 1006 of 16098
#
# Processing file 1007 of 16098
#
# Processing file 1008 of 16098
#
# Processing file 1009 of 16098
#
# Processing file 1010 of 16098
#
# Processing file 1011 of 16098
#
# Processing file 1012 of 16098
#
# Processing file 1013 of 16098
#
# Processing file 1014 of 16098
#
# Processing file 1015 of 16098
#
# Processing file 1016 of 16098
#
# Processing file 1017 of 16098
#
# Processing file 1018 of 16098
#
# Processing file 1019 of 16098
#
# Processing file 1020 of 16098
#
# Processing file 1021 of 16098
#
# Processing file 1022 of 16098
#
# Processing file 1023 of 16098
#
# Processing file 1024 of 16098
#
# Processing file 1025 of 16098
#
# Processing file 1026 of 16098
#
# Processing file 1027 of 16098
#
# Processing file 1028 of 16098
#
# Processing file 1029 of 16098
#
# Processing file 1030 of 16098
#
# Processing file 1031 of 16098
#
# Processing file 1032 of 16098
#
# Processing file 1033 of 16098
#
# Processing file 1034 of 16098
#
# Processing file 1035 of 16098
#
# Processing file 1036 of 16098
#
# Processing file 1037 of 16098
#
# Processing file 1038 of 16098
#
# Processing file 1039 of 16098
#
# Processing file 1040 of 16098
#
# Processing file 1041 of 16098
#
# Processing file 1042 of 16098
#
# Processing file 1043 of 16098
#
# Processing file 1044 of 16098
#
# Processing file 1045 of 16098
#
# Processing file 1046 of 16098
#
# Processing file 1047 of 16098
#
# Processing file 1048 of 16098
#
# Processing file 1049 of 16098
#
# Processing file 1050 of 16098
#
# Processing file 1051 of 16098
#
# Processing file 1052 of 16098
#
# Processing file 1053 of 16098
#
# Processing file 1054 of 16098
#
# Processing file 1055 of 16098
#
# Processing file 1056 of 16098
#
# Processing file 1057 of 16098
#
# Processing file 1058 of 16098
#
# Processing file 1059 of 16098
#
# Processing file 1060 of 16098
#
# Processing file 1061 of 16098
#
# Processing file 1062 of 16098
#
# Processing file 1063 of 16098
#
# Processing file 1064 of 16098
#
# Processing file 1065 of 16098
#
# Processing file 1066 of 16098
#
# Processing file 1067 of 16098
#
# Processing file 1068 of 16098
#
# Processing file 1069 of 16098
#
# Processing file 1070 of 16098
#
# Processing file 1071 of 16098
#
# Processing file 1072 of 16098
#
# Processing file 1073 of 16098
#
# Processing file 1074 of 16098
#
# Processing file 1075 of 16098
#
# Processing file 1076 of 16098
#
# Processing file 1077 of 16098
#
# Processing file 1078 of 16098
#
# Processing file 1079 of 16098
#
# Processing file 1080 of 16098
#
# Processing file 1081 of 16098
#
# Processing file 1082 of 16098
#
# Processing file 1083 of 16098
#
# Processing file 1084 of 16098
#
# Processing file 1085 of 16098
#
# Processing file 1086 of 16098
#
# Processing file 1087 of 16098
#
# Processing file 1088 of 16098
#
# Processing file 1089 of 16098
#
# Processing file 1090 of 16098
#
# Processing file 1091 of 16098
#
# Processing file 1092 of 16098
#
# Processing file 1093 of 16098
#
# Processing file 1094 of 16098
#
# Processing file 1095 of 16098
#
# Processing file 1096 of 16098
#
# Processing file 1097 of 16098
#
# Processing file 1098 of 16098
#
# Processing file 1099 of 16098
#
# Processing file 1100 of 16098
#
# Processing file 1101 of 16098
#
# Processing file 1102 of 16098
#
# Processing file 1103 of 16098
#
# Processing file 1104 of 16098
#
# Processing file 1105 of 16098
#
# Processing file 1106 of 16098
#
# Processing file 1107 of 16098
#
# Processing file 1108 of 16098
#
# Processing file 1109 of 16098
#
# Processing file 1110 of 16098
#
# Processing file 1111 of 16098
#
# Processing file 1112 of 16098
#
# Processing file 1113 of 16098
#
# Processing file 1114 of 16098
#
# Processing file 1115 of 16098
#
# Processing file 1116 of 16098
#
# Processing file 1117 of 16098
#
# Processing file 1118 of 16098
#
# Processing file 1119 of 16098
#
# Processing file 1120 of 16098
#
# Processing file 1121 of 16098
#
# Processing file 1122 of 16098
#
# Processing file 1123 of 16098
#
# Processing file 1124 of 16098
#
# Processing file 1125 of 16098
#
# Processing file 1126 of 16098
#
# Processing file 1127 of 16098
#
# Processing file 1128 of 16098
#
# Processing file 1129 of 16098
#
# Processing file 1130 of 16098
#
# Processing file 1131 of 16098
#
# Processing file 1132 of 16098
#
# Processing file 1133 of 16098
#
# Processing file 1134 of 16098
#
# Processing file 1135 of 16098
#
# Processing file 1136 of 16098
#
# Processing file 1137 of 16098
#
# Processing file 1138 of 16098
#
# Processing file 1139 of 16098
#
# Processing file 1140 of 16098
#
# Processing file 1141 of 16098
#
# Processing file 1142 of 16098
#
# Processing file 1143 of 16098
#
# Processing file 1144 of 16098
#
# Processing file 1145 of 16098
#
# Processing file 1146 of 16098
#
# Processing file 1147 of 16098
#
# Processing file 1148 of 16098
#
# Processing file 1149 of 16098
#
# Processing file 1150 of 16098
#
# Processing file 1151 of 16098
#
# Processing file 1152 of 16098
#
# Processing file 1153 of 16098
#
# Processing file 1154 of 16098
#
# Processing file 1155 of 16098
#
# Processing file 1156 of 16098
#
# Processing file 1157 of 16098

# %% [markdown]
# ## Trust but verify

# %%
getwd()
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts"

# %%
# Function to check for errors in the log file
check_log_for_errors <- function(log_path) {
  log_contents <- readLines(log_path)
  errors <- grep("error|stop|interrupted", tolower(log_contents), value = TRUE)
  if (length(errors) > 0) {
    return(list(success = FALSE, messages = errors))
  }
  return(list(success = TRUE))
}

# Usage
log_result <- check_log_for_errors("processing_log.txt")
if (log_result$success) {
  cat("No errors found in log.\n")
} else {
  cat("Errors found in log:\n", paste(log_result$messages, collapse = "\n"))
}
# Out:
# No errors found in log.

# %%
library(data.table)

# %%
# SLOW Function to validate output files
validate_output_files <- function(trait_names, output_path_template) {
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      cat(sprintf("Output file for %s does not exist.\n", trait))
      next
    }
    dt <- fread(file_path)
    if (nrow(dt) == 0) {
      cat(sprintf("Output file for %s is empty.\n", trait))
    } else {
      cat(sprintf("Output file for %s has %d rows.\n", trait, nrow(dt)))
    }
  }
}

# Usage
#validate_output_files(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")

# %%
# Function to check if output files exist and are not empty
check_output_files_existence_and_size <- function(trait_names, output_path_template) {
  results <- list()
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      results[[trait]] <- sprintf("Output file for %s does not exist.", trait)
    } else {
      file_size <- file.info(file_path)$size
      if (file_size > 0) {
        results[[trait]] <- sprintf("Output file for %s is valid with size %d bytes.", trait, file_size)
      } else {
        results[[trait]] <- sprintf("Output file for %s exists but is empty.", trait)
      }
    }
  }
  return(results)
}

# Usage
file_check_results <- check_output_files_existence_and_size(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")
for (result in file_check_results) {
  cat(result, "\n")
}
# Out:
# Error in sprintf("Output file for %s is valid with size %d bytes.", trait, : invalid format '%d'; use format %f, %e, %g or %a for numeric objects
# Traceback:
#
# 1. check_output_files_existence_and_size(c("bp", "mdd", "scz"),
#  .     "16a5-OUT_stage2_MWAS_%s.csv")
# 2. sprintf("Output file for %s is valid with size %d bytes.", trait,
#  .     file_size)   # at line 11 of file <text>

# %%
# Function to check if output files exist and are not empty
check_output_files_existence_and_size <- function(trait_names, output_path_template) {
  results <- list()
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      results[[trait]] <- sprintf("Output file for %s does not exist.", trait)
    } else {
      file_size <- as.integer(file.info(file_path)$size)  # Ensure integer format
      if (file_size > 0) {
        results[[trait]] <- sprintf("Output file for %s is valid with size %d bytes.", trait, file_size)
      } else {
        results[[trait]] <- sprintf("Output file for %s exists but is empty.", trait)
      }
    }
  }
  return(results)
}

# Usage
file_check_results <- check_output_files_existence_and_size(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")
for (result in file_check_results) {
  cat(result, "\n")
}
# Out:
# Warning message in check_output_files_existence_and_size(c("bp", "mdd", "scz"), :
# “NAs introduced by coercion to integer range”
# Error in if (file_size > 0) {: missing value where TRUE/FALSE needed
# Traceback:
#
# 1. check_output_files_existence_and_size(c("bp", "mdd", "scz"),
#  .     "16a5-OUT_stage2_MWAS_%s.csv")

# %%
# Function to check if output files exist and are not empty
check_output_files_existence_and_size <- function(trait_names, output_path_template) {
  results <- list()
  for (trait in trait_names) {
    file_path <- sprintf(output_path_template, trait)
    if (!file.exists(file_path)) {
      results[[trait]] <- sprintf("Output file for %s does not exist.", trait)
    } else {
      file_size <- file.info(file_path)$size  # Get the file size without casting
      if (!is.na(file_size) && file_size > 0) {
        results[[trait]] <- sprintf("Output file for %s is valid with size %f bytes.", trait, file_size)
      } else if (is.na(file_size)) {
        results[[trait]] <- sprintf("Error retrieving file size for %s.", trait)
      } else {
        results[[trait]] <- sprintf("Output file for %s exists but is empty.", trait)
      }
    }
  }
  return(results)
}

# Usage
file_check_results <- check_output_files_existence_and_size(c("bp", "mdd", "scz"), "16a5-OUT_stage2_MWAS_%s.csv")
for (result in file_check_results) {
  cat(result, "\n")
}
# Out:
# Output file for bp is valid with size 16912150884.000000 bytes.
# Output file for mdd does not exist.
# Output file for scz does not exist.

# %% [markdown]
# ## Second attempt

# %%
library(data.table)
library(ggplot2)

# Initialize logging
log_file <- file("processing_log.txt", open = "wt")
sink(log_file, type = "message")
sink(log_file, type = "output", append = TRUE)

tryCatch({
    traits <- c("bp", "mdd", "scz")
    df$stage2_paths <- gsub(".rds", "_gwas_stat_", df$path)
    df$final_paths <- vector("list", length(df$stage2_paths))

    for (trait in traits) {
        message("Processing trait: ", trait)
        df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
        output_file <- paste0("16a6-OUT_stage2_MWAS_", trait, ".csv")
        header_written <- FALSE

        for (i in seq_along(df$final_paths)) {
            if (grepl("empty", df$final_paths[i])) next
            
            message("Processing file ", i, " of ", length(df$final_paths))
            stage2_in <- readRDS(df$final_paths[i])
            stage1_in <- readRDS(df$path[i])
            
            if (length(stage1_in@models) != length(stage2_in@MWASmodels)) {
                stop("Files don't match")
            }

            data_list <- vector("list", length(stage1_in@models))
            for (j in seq_along(stage1_in@models)) {
                model1 <- stage1_in@models[[j]]
                model2 <- stage2_in@MWASmodels[[j]]

                data_list[[j]] <- data.table(
                    z = model2["z"],
                    p = model2["p"],
                    n = model2["n"],
                    pos = model1@methylationPosition,
                    stats = stage2_in@summary_stats_path,
                    scaff = stage1_in@scaffoldIdentifier
                )
            }

            combined_data <- rbindlist(data_list, use.names = TRUE, fill = TRUE)

            # Write data incrementally
            if (!header_written) {
                fwrite(combined_data, output_file)
                header_written <- TRUE
            } else {
                fwrite(combined_data, output_file, append = TRUE)
            }
        }
    }
}, error = function(e) {
    message("An error occurred: ", e$message)
}, finally = {
    sink(NULL)  # Turn off logging
    close(log_file)
    message("Logging ended.")
})
# Out:
# An error occurred: object of type 'closure' is not subsettable
# Error in close.connection(log_file): cannot close 'message' sink connection
# Traceback:
#
# 1. tryCatch({
#  .     traits <- c("bp", "mdd", "scz")
#  .     df$stage2_paths <- gsub(".rds", "_gwas_stat_", df$path)
#  .     df$final_paths <- vector("list", length(df$stage2_paths))
#  .     for (trait in traits) {
#  .         message("Processing trait: ", trait)
#  .         df$final_paths <- paste0(df$stage2_paths, trait, "_results.rds")
#  .         output_file <- paste0("16a6-OUT_stage2_MWAS_", trait,
#  .             ".csv")
#  .         header_written <- FALSE
#  .         for (i in seq_along(df$final_paths)) {
#  .             if (grepl("empty", df$final_paths[i]))
#  .                 next
#  .             message("Processing file ", i, " of ", length(df$final_paths))
#  .             stage2_in <- readRDS(df$final_paths[i])
#  .             stage1_in <- readRDS(df$path[i])
#  .             if (length(stage1_in@models) != length(stage2_in@MWASmodels)) {
#  .                 stop("Files don't match")
#  .             }
#  .             data_list <- vector("list", length(stage1_in@models))
#  .             for (j in seq_along(stage1_in@models)) {
#  .                 model1 <- stage1_in@models[[j]]
#  .                 model2 <- stage2_in@MWASmodels[[j]]
#  .                 data_list[[j]] <- data.table(z = model2["z"],
#  .                   p = model2["p"], n = model2["n"], pos = model1@methylationPosition,
#  .                   stats = stage2_in@summary_stats_path, scaff = stage1_in@scaffoldIdentifier)
#  .             }
#  .             combined_data <- rbindlist(data_list, use.names = TRUE,
#  .                 fill = TRUE)
#  .             if (!header_written) {
#  .                 fwrite(combined_data, output_file)
#  .                 header_written <- TRUE
#  .             }
#  .             else {
#  .                 fwrite(combined_data, output_file, append = TRUE)
#  .             }
#  .         }
#  .     }
#  . }, error = function(e) {
#  .     message("An error occurred: ", e$message)
#  . }, finally = {
#  .     sink(NULL)
#  .     close(log_file)
#  .     message("Logging ended.")
#  . })
# 2. close(log_file)   # at line 61 of file <text>
# 3. close.connection(log_file)
