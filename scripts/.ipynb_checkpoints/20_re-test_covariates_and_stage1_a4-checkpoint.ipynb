# %% [markdown]
# # Try MWAS with covariates prepared in various ways

# %% [markdown]
# # Pick the regions we will test

# %%
library(data.table)

prev_hits <- fread("
Chr     pos        old_z       old_p
11   38247902        -27.1535308285104       2.30024742330298e-162
2    47933357        18.3327793004811        4.53147699327216e-75
7    1987910         10.1255085321387        4.25759742738181e-24
7    1987896         10.1255085321387        4.25759742738189e-24
7    1987797         10.0241523897721        1.19379483108027e-23
7    1987778         10.0105851568856        1.36940148731912e-23
12   2194742         -10.0072634920486       1.41615523554955e-23
")

# %%
#df <- fread("09.5-OUT_matched_SNP_meth_cov_chunked_EXPANSE_a2.csv")

# %%
df <- fread("09-OUT_matched_SNP_meth_cov_a2.csv")

# %% [markdown]
# ## Try original code

# %%
###### model: learn elastic net model on training data 
######---------Input: trainX, trainY
######---------Return: selected features and coefficents

# original
elastic.net <- function(trainX,trainY){
    if(nrow(trainX)!=length(trainY)){
            stop("Number of observations is differerent")
    } 

    # optimize alpha---mixing parameter  
    a <- 0.5
    search <- foreach(ai = a, .combine = rbind) %dopar% {
        cv.fit <- cv.glmnet(
                        trainX,
                        trainY,
                        nfold = 5,
                        type.measure = "mse",
                        paralle = TRUE,
                        alpha = ai
                        )
        data.frame(
                        cvm = min(cv.fit$cvm),
                        lambda = cv.fit$lambda.min,
                        alpha = ai
                        )
        } 
    cv.opt <- search[search$cvm == min(search$cvm),] 

        # fit model by optimized alpha and lambda
        yfit = glmnet(
        trainX,
        trainY,
        lambda = cv.opt$lambda,
        alpha = cv.opt$alpha
                )       
        idf <- coef(yfit)
        idx <- which(idf != 0)
        selectf <- data.frame(
                features = idf@Dimnames[[1]][idx], 
                coefs = idf [idx]
        )
}

# modified to use lambda 1se and appropriate cvm
elastic.net <- function(trainX,trainY){
    if(nrow(trainX)!=length(trainY)){
            stop("Number of observations is differerent")
    } 

    # optimize alpha---mixing parameter  
    a <- 0.5
    search <- foreach(ai = a, .combine = rbind) %dopar% {
        set.seed(42)
        cv.fit <- cv.glmnet(
                        trainX,
                        trainY,
                        nfold = 5,
                        type.measure = "mse",
                        paralle = TRUE,
                        alpha = ai
                        )
        print(paste0("Dim of trainX: ", dim(trainX)))
        print(paste0("Len of trainY: ", length(trainY)))
        coef_matrix <- as.matrix(coef(cv.fit))

        non_zero_coefs <- coef_matrix[coef_matrix != 0, , drop = FALSE]
        print("Coefficients when fitting: ")
        print(non_zero_coefs)

        data.frame(
                        cvm = cv.fit$cvm[cv.fit$lambda == cv.fit$lambda.1se],
                        lambda = cv.fit$lambda.1se,
                        alpha = ai
                        )
        } 
    cv.opt <- search[search$cvm == min(search$cvm),] 

        # fit model by optimized alpha and lambda
    set.seed(42)
    yfit <- glmnet(
    trainX,
    trainY,
    lambda = cv.opt$lambda,
    alpha = cv.opt$alpha)

    coef_matrix <- as.matrix(coef(yfit))

    non_zero_coefs <- coef_matrix[coef_matrix != 0, , drop = FALSE]
    print("Coefficients when optimal: ")
    print(non_zero_coefs)

    idf <- coef(yfit)
    idx <- which(idf != 0)
    selectf <- data.frame(
            features = idf@Dimnames[[1]][idx], 
            coefs = idf [idx]
    )
}

MWAS <- function(gwas, weight, geno){
        z <- gwas %*% weight
        z.cor <- cor(geno)
        se <- sqrt(weight %*%  z.cor %*%  weight)
        z <- z/se
        p=pnorm(abs(z),lower.tail=F)*2
        return(c(z, p))
}

# %%
df <- df[which(df$Chr == 7), ]

# %%
i <- 2

# %%
library("glmnet")
library("e1071")
library("doParallel")

set.seed(2018)
wind <- c(5000,10000)
# output directory
#outd <- "/dcl02/lieber/shan/shizhong/finemapping/GWAS/tags/scz3/mwas/chr22/1/"
outd <- "20-OUT_original_mwas_sanity_test/"
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel

# %%
suppressWarnings(library(bsseq))
# Out:
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, unname
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians

# %%
# load data for mwas
# load("./rda/caudate_mwas_data_chr22.rda")
load(df$methylation_data[i])

p <- getMeth(BSobj2)


rownames(p) <- start(BSobj2)

sites_to_test <- which(start(BSobj2) >= (1987910 - 500) & start(BSobj2) <= (1987910 + 500))
p <- p[sites_to_test, ]

# candidate cg
cg <- as.numeric(rownames(p))

# regress out covariates
#load("covs_for_meqtl.rda")

# %%
sites_to_test
# Out:
#  [1] 58792 58793 58794 58795 58796 58797 58798 58799 58800 58801 58802 58803
# [13] 58804 58805 58806 58807 58808 58809 58810 58811 58812 58813 58814 58815
# [25] 58816 58817 58818 58819 58820 58821 58822 58823 58824 58825 58826 58827
# [37] 58828 58829 58830 58831 58832 58833 58834 58835 58836 58837 58838 58839
# [49] 58840

# %%
covs <- fread(df$cov_file[i])
covs <- t(covs)
colnames(covs) <- covs[1, ]
covs <- covs[2:nrow(covs), ]
# transpose so we have same orientation as original code

# %%
BSobj2$brnum <- gsub("Br0", "Br", BSobj2$brnum)
colnames(covs) <- gsub("Br0", "Br", colnames(covs))

# %%
length(match(BSobj2$brnum,colnames(covs)))
# Out:
# [1] 297

# %%
mat <- match(BSobj2$brnum,colnames(covs)) 
covs <- t(covs[,mat])
p.residual=matrix(NA,dim(p)[1],dim(p)[2])

# %%
rownames(covs)[is.na(covs[, 'genoPC1'])] <- BSobj2$brnum[is.na(covs[, 'genoPC1'])]

# %%
colnames(p.residual) <- BSobj2$brnum

# %%
covs <- as.data.frame(covs)
# Convert all columns except Dx and Sex from character to numeric
cols_to_convert <- setdiff(names(covs), c("Dx", "Sex"))

for (col in cols_to_convert) {
  covs[[col]] <- as.numeric(covs[[col]])
}

# Print the modified data frame to check the conversion
#print(dat)

# %%
for (i in 1:dim(p)[1]) { # For each methylation site
    dat <- as.data.frame(cbind(y = p[i,], covs))
    
    # Check for rows with NAs (the ones for which we don't have covariate data)
    valid_rows <- complete.cases(dat)
    
    if (sum(valid_rows) > 0) {
        dat_valid <- dat[valid_rows,]
        model.res <- lm(y ~ ., data = dat_valid)
        
        # Store residuals in the corresponding positions
        p.residual[i, valid_rows] <- resid(model.res)
    }
}


# for(i in 1:dim(p)[1]){ # foro each methylation site
#         dat <- as.data.frame(cbind(p[i,],covs))
#         colnames(dat) <- c("y",paste0("x",1:ncol(covs)))
#         model.res <- lm(reformulate(paste0("x",1:ncol(covs)), "y"),dat)
#         p.residual[i,] = resid(model.res) 
# }

# %%
load("p1.rda")

# %%
wind <- 10000

# %%
# built predition models
idx.ea <- BSobj2$race == "CAUC"

# %%
snp2_sorted <- snp2[, order(names(snp2))]

# %%
colnames(snp2) <- gsub("Br0", "Br", colnames(snp2))

# %%
snp2 <- snp2[, colnames(snp2) %in% colnames(p.residual)]

# %%
dim(snp2)
# Out:
# [1]  56 297

# %%
snp2_positions <- stringr::str_split_fixed(rownames(snp2), ":", 3)[, 2]

# %% [markdown]
# ## Test for one

# %%
dim(snp2)
# Out:
# [1]  56 297

# %%
rownames(snp2)
# Out:
#  [1] "chr7:1963098:T:C" "chr7:1963408:C:T" "chr7:1964786:C:T" "chr7:1966112:T:C"
#  [5] "chr7:1973362:G:A" "chr7:1975412:T:G" "chr7:1976335:C:T" "chr7:1977810:C:T"
#  [9] "chr7:1978402:C:T" "chr7:1978783:G:T" "chr7:1979188:C:A" "chr7:1979235:G:A"
# [13] "chr7:1980240:G:A" "chr7:1981269:G:C" "chr7:1981360:G:A" "chr7:1982428:C:G"
# [17] "chr7:1985366:G:C" "chr7:1985405:A:G" "chr7:1987676:G:T" "chr7:1987689:G:A"
# [21] "chr7:1987719:C:T" "chr7:1987813:T:C" "chr7:1989028:A:C" "chr7:1989333:G:T"
# [25] "chr7:1989994:G:C" "chr7:1990232:T:C" "chr7:1990305:T:C" "chr7:1990372:G:C"
# [29] "chr7:1990469:G:A" "chr7:1990652:G:T" "chr7:1993168:C:T" "chr7:1993230:A:T"
# [33] "chr7:1994145:G:C" "chr7:1994382:C:T" "chr7:1994558:A:G" "chr7:1994714:G:A"
# [37] "chr7:1994927:A:G" "chr7:1997034:T:G" "chr7:1997580:G:A" "chr7:1998126:G:A"
# [41] "chr7:1999959:A:C" "chr7:2001797:A:G" "chr7:2002003:G:A" "chr7:2002813:C:T"
# [45] "chr7:2002912:C:G" "chr7:2004461:G:C" "chr7:2005716:T:C" "chr7:2006553:G:C"
# [49] "chr7:2006693:A:G" "chr7:2007195:C:T" "chr7:2008210:A:G" "chr7:2008240:G:A"
# [53] "chr7:2008501:T:C" "chr7:2008585:G:C" "chr7:2008700:A:G" "chr7:2009071:A:G"

# %%
k <- 1

i <- 1

range1 <- ifelse(cg[i] - wind[k] > 0,cg[i] - wind[k],0)
range2 <- cg[i] + wind[k]

range1
range2
# Out:
# [1] 1977413
# [1] 1997413

# %%
cat(i,"\n")
range1 <- ifelse(cg[i] - wind[k] > 0,cg[i] - wind[k],0)
range2 <- cg[i] + wind[k]
range1
range2

idx <- map2$POS > range1 & map2$POS < range2

length(idx)
# Out:
# 1
# [1] 1977413
# [1] 1997413
# [1] 56

# %%
range1
# Out:
# [1] 1977413

# %%
range2
# Out:
# [1] 1997413

# %%
# go to next cg if no snps within window
if(sum(idx) <= 1){
        next
}
geno <- snp2[idx,]
rownames(geno) <- map2$POS[idx]
trainX <- t(geno)
trainY <- p.residual[i,]

# %%
dim(snp2)

dim(geno)

head(trainY[order(names(trainY))])
# Out:
# [1]  56 297
# [1]  31 297
#       Br1003       Br1004       Br1007       Br1016       Br1017       Br1021
#  0.032737590  0.019424071  0.017150662  0.004945029 -0.007041670 -0.023944463

# %%
inspect <- t(snp2)
inspect <- inspect[order(rownames(inspect)), ]

# %%
fit <- elastic.net(trainX,trainY)
# Out:
# Warning message:
# “executing %dopar% sequentially: no parallel backend registered”
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 3.388132e-20
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.577859e-18
# 1979188      2.816307e-18

# %%
fit
# Out:
#   features    coefs
# 1 (Intercept) -2.577859e-18
# 2 1979188      2.816307e-18

# %% [markdown]
# We're getting different elasticnet results here than with our package. Why?

# %% [markdown]
# Let's go inside elastic.net function

# %%
dim(trainX)
# Out:
# [1] 297  31

# %% [markdown]
# Deeper still

# %%
trainX2 <- readRDS("20-IN_sanity_test_Xmatrix.rds")

# %%
trainy2 <- readRDS("20-IN_sanity_test_y.rds")

# %%
fold_id <- readRDS("20-IN_sanity_test_fold_id.rds")

# %%
set.seed(42)
cv.fit <- cv.glmnet(
                trainX,
                trainY,
    nfold = 5,
                #foldid = fold_id,                    
        type.measure = "mse",
                    paralle = TRUE,
                    alpha = 0.5
                    )

# %%
cv.fit
# Out:
# Call:  cv.glmnet(x = trainX, y = trainY, type.measure = "mse", nfolds = 5,      parallel = TRUE, alpha = 0.5)
#
# Measure: Mean-Squared Error
#
#       Lambda Index   Measure        SE Nonzero
# min 0.004499     5 0.0004443 3.844e-05       1
# 1se 0.006528     1 0.0004468 3.781e-05       0

# %%
coef(cv.fit)
# Out:
# 32 x 1 sparse Matrix of class "dgCMatrix"
#                       s1
# (Intercept) 3.388132e-20
# 1977810     .
# 1978402     .
# 1978783     .
# 1979188     .
# 1979235     .
# 1980240     .
# 1981269     .
# 1981360     .
# 1982428     .
# 1985366     .
# 1985405     .
# 1987676     .
# 1987689     .
# 1987719     .
# 1987813     .
# 1989028     .
# 1989333     .
# 1989994     .
# 1990232     .
# 1990305     .
# 1990372     .
# 1990469     .
# 1990652     .
# 1993168     .
# 1993230     .
# 1994145     .
# 1994382     .
# 1994558     .
# 1994714     .
# 1994927     .
# 1997034     .

# %%
head(fold_id)
# Out:
# [1] 4 3 4 3 1 2

# %%
a <- 0.5
search <- foreach(ai = a, .combine = rbind) %dopar% {
    set.seed(42)
    cv.fit <- cv.glmnet(
                trainX2,
                trainy2,
                foldid = fold_id,                    
        type.measure = "mse",
                    paralle = TRUE,
                    alpha = ai
                    )
    data.frame(
                    cvm = cv.fit$cvm[cv.fit$lambda == cv.fit$lambda.1se],
                    lambda = cv.fit$lambda.1se,
                    alpha = ai
                    )
    }

# %%
cv.opt <- search[search$cvm == min(search$cvm),]

# %%
cv.opt
# Out:
#   cvm          lambda      alpha
# 1 0.0004224127 0.007649007 0.5

# %%
cv.fit
# Out:
# Call:  cv.glmnet(x = trainX, y = trainY, type.measure = "mse", nfolds = 5,      parallel = TRUE, alpha = 0.5)
#
# Measure: Mean-Squared Error
#
#       Lambda Index   Measure        SE Nonzero
# min 0.004499     5 0.0004443 3.844e-05       1
# 1se 0.006528     1 0.0004468 3.781e-05       0

# %%
coef(cv.fit) # This matches what we get out of tune_alpha, without fitting optimized parameters on whole data
# Out:
# 32 x 1 sparse Matrix of class "dgCMatrix"
#                       s1
# (Intercept) 3.388132e-20
# 1977810     .
# 1978402     .
# 1978783     .
# 1979188     .
# 1979235     .
# 1980240     .
# 1981269     .
# 1981360     .
# 1982428     .
# 1985366     .
# 1985405     .
# 1987676     .
# 1987689     .
# 1987719     .
# 1987813     .
# 1989028     .
# 1989333     .
# 1989994     .
# 1990232     .
# 1990305     .
# 1990372     .
# 1990469     .
# 1990652     .
# 1993168     .
# 1993230     .
# 1994145     .
# 1994382     .
# 1994558     .
# 1994714     .
# 1994927     .
# 1997034     .

# %%
a <- 0.5

# %%
search <- foreach(ai = a, .combine = rbind) %dopar% {
    set.seed(42)
    cv.fit <- cv.glmnet(
                    trainX2,
                    trainy2,
                    foldid = fold_id,
                    type.measure = "mse",
                    paralle = TRUE,
                    alpha = ai
                    )
    data.frame(
                    cvm = cv.fit$cvm[cv.fit$lambda == cv.fit$lambda.1se],
                    lambda = cv.fit$lambda.1se,
                    alpha = ai
                    )
    } 
cv.opt <- search[search$cvm == min(search$cvm),] 

    # fit model by optimized alpha and lambda
    set.seed(42)
    yfit = glmnet(
    trainX2,
    trainy2,
    lambda = cv.opt$lambda,
    alpha = cv.opt$alpha
            )       
    idf <- coef(yfit)
    idx <- which(idf != 0)
    selectf <- data.frame(
            features = idf@Dimnames[[1]][idx], 
            coefs = idf [idx]
    )

# %%
cv.opt # GOOD! should be 
#cvm	lambda	alpha
#<dbl>	<dbl>	<dbl>
#1	0.0004224127	0.007649007	0.5
# Out:
#   cvm          lambda      alpha
# 1 0.0004224127 0.007649007 0.5

# %%
search
# Out:
#   cvm          lambda      alpha
# 1 0.0004224127 0.007649007 0.5

# %% [markdown]
# Make sure we have same results not only from fitting but for optimal model with fixed alpha, lambda also

# %%
selectf
# Out:
#   features         coefs
# 1 (Intercept)      -4.062561e-05
# 2 chr7:1977810:C:T  7.759077e-04
# 3 chr7:1981360:G:A -1.070675e-03
# 4 chr7:1987719:C:T -1.224151e-03
# 5 chr7:1987813:T:C  1.768736e-04
# 6 chr7:1990232:T:C -1.298076e-03
# 7 chr7:1994382:C:T  1.105434e-03

# %%
dim(trainX)
# Out:
# [1] 297  31

# %%
models.all <- c()

# %%
rbind(models.all, cv.fit)
# Out:
#        lambda       cvm          cvsd         cvup         cvlo
# cv.fit 0.006527.... 0.000446.... 3.781117.... 0.000484.... 0.000409....
#        nzero        call         name         glmnet.fit   lambda.min
# cv.fit 0, 1, 1,.... cv.glmne.... Mean-Squ.... c(s0 = 3.... 0.004499....
#        lambda.1se   index
# cv.fit 0.006527.... 5, 1

# %% [markdown]
# Is 1se vs min for lambda the problem?

# %% [markdown]
# ## Run for all

# %%
dim(snp2)
# Out:
# [1]  56 297

# %%
dim(snp2)
# Out:
# [1]  56 297

# %%
snp3 <- readRDS("20-IN_check_SNP_window_pos1987413_win50000.rds")

# %%
dim(snp2)
# Out:
# [1]  56 297

# %%
snp3 <- t(snp3)

# %%
map3 <- data.frame(POS = stringr::str_split_fixed(rownames(snp3), ":", 3)[, 2])

# %%
elastic.net(trainX, trainY)
# Out:
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 3.388132e-20
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.577859e-18
# 1979188      2.816307e-18

# %%
trainX[1:10, 1:10]
# Out:
#       1977810 1978402 1978783 1979188 1979235 1980240 1981269 1981360 1982428
# Br836 0       0.008   0.000   0.000   2       2.000   2       2.000   2.000
# Br845 1       2.000   2.000   0.000   2       2.000   2       2.000   2.000
# Br848 1       1.991   1.990   0.010   2       1.905   2       1.006   1.006
# Br863 0       0.000   0.000   0.000   2       2.000   2       2.000   2.000
# Br914 0       1.981   1.979   0.047   2       2.000   2       2.000   2.000
# Br948 0       0.024   0.024   1.001   2       2.000   2       2.000   2.000
# Br949 2       2.000   2.000   1.997   2       2.000   2       0.005   2.000
# Br963 0       0.015   0.019   1.997   2       2.000   2       2.000   2.000
# Br983 1       2.000   2.000   0.001   1       1.000   1       1.000   1.000
# Br991 0       0.000   0.000   1.000   2       2.000   2       2.000   2.000
#       1985366
# Br836 2
# Br845 2
# Br848 2
# Br863 2
# Br914 2
# Br948 2
# Br949 2
# Br963 2
# Br983 1
# Br991 2

# %%
trainY[1:10]
# Out:
#        Br1122        Br2285        Br1764        Br1464        Br5062
# -0.0138154121 -0.0225516889 -0.0004894733  0.0340564405 -0.0329548084
#        Br1446        Br1503        Br1946        Br5323        Br1297
#  0.0244990255 -0.0075554592  0.0427314728  0.0199602498 -0.0177260869

# %%
p.residual <- p.residual[, order(colnames(p.residual))]

# %%
for(k in 1:length(wind)){
    models.ea <- c()
    models.all <- c()
    for(i in 1:length(cg)){
    #for(i in 1){
            cat(i,"\n")
            print(paste0("This cg is: ", cg[i]))
            range1 <- ifelse(cg[i] - wind[k] > 0,cg[i] - wind[k],0)
            range2 <- cg[i] + wind[k]
            idx <- map3$POS > range1 & map3$POS < range2
            # go to next cg if no snps within window
            if(sum(idx) <= 1){
                    next
            }
            geno <- snp3[idx,] # changed snp2 to snp3
            rownames(geno) <- map3$POS[idx]
            trainX <- t(geno)
            trainY <- p.residual[i,]
            fit <- tryCatch(
                    elastic.net(trainX,trainY),
                    error = function(e) {return ("err")})
            if(!is.data.frame(fit)){
                if(fit == "err"){
                    next
                }
            }
            if(nrow(fit) == 0) next

            fit$cg <- cg[i]
            models.all <- rbind(models.all,fit)
            # EA only
            trainX <- trainX[idx.ea,]
            if(sum(apply(trainX,2,var)!=0) <= 1){
                    next
            }
            trainY <- trainY[idx.ea]
            fit <- tryCatch(
                    elastic.net(trainX,trainY),
                    error = function(e) {return ("err")})
            if(!is.data.frame(fit)){
                if(fit == "err"){
                    next
                }
            }
            if(nrow(fit) == 0) next
            fit$cg <- cg[i]
            models.ea <- rbind(models.ea,fit)
    }
}
# Out:
# 1
# [1] "This cg is: 1987413"
# [1] "Dim of trainX: 297" "Dim of trainX: 43"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0011900000
# 1985405     -0.0003743143
# 1987813      0.0011936815
# [1] "Dim of trainX: 133" "Dim of trainX: 43"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)  0.0005622240
# 1985405     -0.0002964193
# 1987813      0.0003629071
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept)  0.0005622240
# 1985405     -0.0002964193
# 1987813      0.0003629071
# 44
# [1] "This cg is: 1988216"
# [1] "Dim of trainX: 297" "Dim of trainX: 43"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) -0.001184243
# 1985405     -0.000076271
# 1987813      0.001025267
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.182767e-03
# 1985405     -7.724563e-05
# 1987813      1.024576e-03
# [1] "Dim of trainX: 133" "Dim of trainX: 43"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008378378
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 0.0008378378
# 45
# [1] "This cg is: 1988292"
# [1] "Dim of trainX: 297" "Dim of trainX: 43"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -0.0003668435
# 1987813      0.0003046258
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -0.0003668435
# 1987813      0.0003046258
# [1] "Dim of trainX: 133" "Dim of trainX: 43"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008302045
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 8.302045e-04
# 1987813     1.360118e-18
# 46
# [1] "This cg is: 1988321"
# [1] "Dim of trainX: 297" "Dim of trainX: 43"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -7.792703e-20
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.409492e-18
# 1987813      1.105727e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 43"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000812691
# [1] "Coefficients when optimal: "
#                      s0
# (Intercept) 8.12691e-04
# 1987813     3.40040e-18
# 47
# [1] "This cg is: 1988325"
# [1] "Dim of trainX: 297" "Dim of trainX: 43"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.067262e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.438183e-18
# 1987813      1.105638e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 43"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008096687
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 0.0008096687
# 48
# [1] "This cg is: 1988332"
# [1] "Dim of trainX: 297" "Dim of trainX: 43"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 2.55804e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.407513e-18
# 1987813      2.211611e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 43"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000804038
# [1] "Coefficients when optimal: "
#                      s0
# (Intercept) 0.000804038
# 49
# [1] "This cg is: 1988401"
# [1] "Dim of trainX: 297" "Dim of trainX: 44"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.030875e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -6.030875e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 44"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000728097
# [1] "Coefficients when optimal: "
#                      s0
# (Intercept) 0.000728097

# %%
wind[k]
# Out:
# [1] 10000

# %%
models.ea <- models.ea[models.ea[,1] != "(Intercept)",]
models.all <- models.all[models.all[,1] != "(Intercept)",]

# %%
if(!dir.exists(outd)) dir.create(outd)

# %%
head(models.all)
# Out:
#   features coefs         cg
# 2 1977810   0.0007759077 1987413
# 3 1981360  -0.0010706745 1987413
# 4 1987719  -0.0012241509 1987413
# 5 1987813   0.0001768736 1987413
# 6 1990232  -0.0012980759 1987413
# 7 1994382   0.0011054336 1987413

# %%
# mwas by models of all samples
cg2 <- unique(models.all$cg)
mwas.all <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.all[models.all$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.all[models.all$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.all[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.all) <- cg2
colnames(mwas.all) <- c("z","p")

# mwas by models of EA samples
cg2 <- unique(models.ea$cg)
mwas.ea <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.ea[models.ea$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.ea[models.ea$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.ea[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.ea) <- cg2
colnames(mwas.ea) <- c("z","p")

# output models and mwas results
outf <- paste0(outd,"/models-cov1.all.wind.",wind[k])
write.csv(models.all,outf)
outf <- paste0(outd,"/models-cov1.ea.wind.",wind[k])
write.csv(models.ea,outf)
outf <- paste0(outd,"/mwas-cov1.all.wind.",wind[k])
write.csv(mwas.all,outf)
outf <- paste0(outd,"/mwas-cov1.ea.wind.",wind[k])
write.csv(mwas.ea,outf)

# %%
max(abs(snp.gwas2$z))
# Out:
# [1] 10.18216

# %%
min(snp.gwas2$p)
# Out:
# [1] 2.235e-24

# %%
head(snp.gwas2)
# Out:
#         snp        chr  pos_hg38 pos_hg19 info  A1 A2 z         p
# 1580243 rs11773627 chr7 1963098  2002733  0.987 T  C  -5.211806 1.955e-07
# 1581305 rs6972374  chr7 1963408  2003043  0.982 C  T  -5.288320 1.220e-07
# 1585924 rs12666575 chr7 1964786  2004421  0.993 C  T   8.855337 6.441e-19
# 1608594 rs11766575 chr7 1966112  2005747  0.990 T  C   8.833789 6.381e-19
# 1605654 rs4721264  chr7 1973362  2012997  0.985 G  A   9.455969 3.503e-21
# 1592364 rs62442944 chr7 1975412  2015047  0.991 T  G  -5.266792 1.591e-07

# %% [markdown]
# ## Can we get the same thing if we read in our RDS instead of taking stage 1 results from this notebooks?

# %%
getwd()
# Out:
# [1] "/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/scripts"

# %% [markdown]
# This is the format we have, in s1

# %%
s1 <- readRDS("/expanse/lustre/projects/jhu152/naglemi/mwas/CpGWAS/output_EXPANSE_a2_caud/libd_chr7-chr7_all-libd_chr7-chr7_all-40001-60000-dynamic-1corestotal-allcorepera-20240422-130351.rds")

# %%
names(attributes(s1))
# Out:
# [1] "scaffoldIdentifier" "models"             "class"

# %%
s1@models[[1]]
# Out:
# Loading required package: CpGWAS
# An object of class "MethylationBase"
# Slot "methylationPosition":
# [1] 1358612
#
# Slot "windowSize":
# [1] 10000
#
# Slot "n_SNPs":
# [1] 25
#
# Slot "glmnetModel":
# NULL
#
# Slot "snpWeights":
# chr7:1361914:C:T
#     2.468965e-18
#
# Slot "intercept":
#           s0
# 2.957377e-15
#
# Slot "alpha":
# [1] 0.5
#
# Slot "lambda":
# [1] 0.01315051
#
# Slot "evaluation_results":
#         cor         mse
# 0.054232532 0.003816666
#
# Slot "cv_eval_mode":
# [1] "dynamic"
#
# Slot "full_model_metrics":
#          r        mse
# 0.10701621 0.00377508

# %% [markdown]
# This is the format we want to convert it to.

# %%
head(models.all)
# Out:
#   features coefs         cg
# 2 1977810   0.0007759077 1987413
# 3 1981360  -0.0010706745 1987413
# 4 1987719  -0.0012241509 1987413
# 5 1987813   0.0001768736 1987413
# 6 1990232  -0.0012980759 1987413
# 7 1994382   0.0011054336 1987413

# %%
#cg is methylationPosition. features is names of snpWeights. coefs is values of snpWeights.
#Should be one row for each SNP weight and group of rows for each methylationPosition

# %%
library(data.table)

# Function to convert model slot to desired format
convert_to_df <- function(model) {
  data.table(
    features = names(model@snpWeights),
    coefs = unname(model@snpWeights),
    cg = model@methylationPosition
  )
}

# Apply function to all models and combine
models.all.mine <- rbindlist(lapply(s1@models, convert_to_df))

# %%
models.all.mine$features <- stringr::str_split_fixed(models.all.mine$features, ":", 3)[, 2]

# %%
models.all.mine[which(models.all$cg == 1987413), ]
# Out:
#   features coefs         cg
# 1 1361914   2.468965e-18 1358612
# 2 1361914   3.706044e-18 1358615
# 3 1361914   4.956864e-18 1358629
# 4 1363760   2.133451e-18 1358673
# 5 1363760   4.259713e-18 1358748
# 6 1367891  -1.210614e-17 1359107

# %% [markdown]
# ## Try running Shizhong's code with our stage 1 results now

# %%
dim(models.all.mine)
# Out:
# [1] 75736     3

# %%
models.all.mine <- models.all.mine[which(models.all.mine$cg >= 1987413), ]

# %%
head(models.all.mine)
# Out:
#   features coefs         cg
# 1 1977810   0.0007759077 1987413
# 2 1981360  -0.0010706745 1987413
# 3 1987719  -0.0012241509 1987413
# 4 1987813   0.0001768736 1987413
# 5 1990232  -0.0012980759 1987413
# 6 1994382   0.0011054336 1987413

# %%
unname(unlist(models.all.mine[models.all.mine$cg == cg2[i],1]))
# Out:
# [1] "1979188" "1979926" "1987813" "1988307"

# %%
models.all[models.all$cg == cg2[i],1]
# Out:
# [1] "1987813"

# %%
pos <- models.all.mine[models.all.mine$cg == cg2[i],1]
gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
weight <- models.all.mine[models.all.mine$cg == cg2[i],2]

# %%
pos
# Out:
#   features
# 1 1979188
# 2 1979926
# 3 1987813
# 4 1988307

# %%
models.all.mine[models.all.mine$cg == cg2[i]]$features
# Out:
# [1] "1979188" "1979926" "1987813" "1988307"

# %%
models.all.mine[models.all.mine$cg == cg2[i]]
# Out:
#   features coefs         cg
# 1 1979188   7.692697e-05 1988321
# 2 1979926  -1.094253e-03 1988321
# 3 1987813   1.343605e-03 1988321
# 4 1988307  -1.378047e-03 1988321

# %%
gwas
# Out:
# numeric(0)

# %%
head(gwas)
# Out:
# numeric(0)

# %%
head(snp.gwas2)
# Out:
#         snp        chr  pos_hg38 pos_hg19 info  A1 A2 z         p
# 1580243 rs11773627 chr7 1963098  2002733  0.987 T  C  -5.211806 1.955e-07
# 1581305 rs6972374  chr7 1963408  2003043  0.982 C  T  -5.288320 1.220e-07
# 1585924 rs12666575 chr7 1964786  2004421  0.993 C  T   8.855337 6.441e-19
# 1608594 rs11766575 chr7 1966112  2005747  0.990 T  C   8.833789 6.381e-19
# 1605654 rs4721264  chr7 1973362  2012997  0.985 G  A   9.455969 3.503e-21
# 1592364 rs62442944 chr7 1975412  2015047  0.991 T  G  -5.266792 1.591e-07

# %%
models.all.mine <- models.all.mine[which(models.all.mine$features %in% snp.gwas2$pos_hg38)]

# %%
dim(models.all.mine)
# Out:
# [1] 1567    3

# %%
# mwas by models of all samples
cg2 <- unique(models.all.mine$cg)
mwas.all.mine <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.all.mine[models.all.mine$cg == cg2[i]]$features
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.all.mine[models.all.mine$cg == cg2[i]]$coefs
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.all.mine[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.all.mine) <- cg2
colnames(mwas.all.mine) <- c("z","p")

# mwas by models of EA samples
cg2 <- unique(models.ea$cg)
mwas.ea <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.ea[models.ea$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.ea[models.ea$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.ea[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.ea) <- cg2
colnames(mwas.ea) <- c("z","p")

# output models and mwas results
outf <- paste0(outd,"/models-mystage1-cov1.all.wind.",wind[k])
write.csv(models.all.mine,outf)
outf <- paste0(outd,"/models-mystage1-cov1.ea.wind.",wind[k])
write.csv(models.ea,outf)
outf <- paste0(outd,"/mwas-mystage1-cov1.all.wind.",wind[k])
write.csv(mwas.all.mine,outf)
outf <- paste0(outd,"/mwas-mystage1-cov1.ea.wind.",wind[k])
write.csv(mwas.ea,outf)

# %%
max(mwas.all[,2])
# Out:
# [1] 3.149753e-23

# %%
mwas.all
# Out:
#         z          p
# 1987413  -9.927849 3.149753e-23
# 1987418  -9.957674 2.334605e-23
# 1987434  -9.972340 2.014272e-23
# 1987449  -9.987919 1.721576e-23
# 1987458 -10.002652 1.483695e-23
# 1987468 -10.000385 1.518059e-23
# 1987492 -10.011781 1.352944e-23
# 1987511 -10.011545 1.356183e-23
# 1987527 -10.010634 1.368726e-23
# 1987565 -10.012276 1.346186e-23
# 1987604 -10.021398 1.227536e-23
# 1987616 -10.018900 1.258969e-23
# 1987627 -10.015487 1.303178e-23
# 1987648 -10.015894 1.297834e-23
# 1987656 -10.014902 1.310914e-23
# 1987659 -10.014622 1.314633e-23
# 1987665 -10.011802 1.352657e-23
# 1987669 -10.011454 1.357424e-23
# 1987680 -10.010878 1.365356e-23
# 1987684 -10.010626 1.368838e-23
# 1987688 -10.010377 1.372282e-23
# 1987697 -10.011067 1.362754e-23
# 1987705 -10.011490 1.356933e-23
# 1987725 -10.013165 1.334141e-23
# 1987732 -10.014286 1.319103e-23
# 1987778 -10.024403 1.190769e-23
# 1987797 -10.028969 1.136981e-23
# 1987808 -10.032265 1.099647e-23
# 1987853 -10.043003 9.862505e-24
# 1987858 -10.038445 1.032893e-23
# 1987861 -10.039873 1.018053e-23
# 1987896 -10.048149 9.360930e-24
# 1987910 -10.052787 8.930556e-24
# 1987930 -10.056980 8.558365e-24
# 1988010 -10.077659 6.935863e-24
# 1988039 -10.067413 7.697647e-24
# 1988059 -10.056313 8.616532e-24
# 1988066 -10.045492 9.616650e-24
# 1988078 -10.041439 1.002014e-23
# 1988129 -10.020603 1.237457e-23
# 1988133 -10.025346 1.179456e-23
# 1988141 -10.035120 1.068299e-23
# 1988201 -10.119473 4.528485e-24
# 1988216 -10.132299 3.972004e-24
# 1988292 -10.125509 4.257597e-24
# 1988321 -10.125509 4.257597e-24
# 1988325 -10.125509 4.257597e-24
# 1988332 -10.125509 4.257597e-24

# %% [markdown]
# ## Try running Shizhong's with old SNP data and new covariates

# %%
for(k in 1:length(wind)){
    models.ea <- c()
    models.all <- c()
    for(i in 1:length(cg)){
    #for(i in 1){
            cat(i,"\n")
            print(paste0("This cg is: ", cg[i]))
            range1 <- ifelse(cg[i] - wind[k] > 0,cg[i] - wind[k],0)
            range2 <- cg[i] + wind[k]
            idx <- map2$POS > range1 & map2$POS < range2
            # go to next cg if no snps within window
            if(sum(idx) <= 1){
                    next
            }
            geno <- snp2[idx,] # changed snp2 to snp2
            rownames(geno) <- map2$POS[idx]
            trainX <- t(geno)
            trainY <- p.residual[i,]
            fit <- tryCatch(
                    elastic.net(trainX,trainY),
                    error = function(e) {return ("err")})
            if(!is.data.frame(fit)){
                if(fit == "err"){
                    next
                }
            }
            if(nrow(fit) == 0) next

            fit$cg <- cg[i]
            models.all <- rbind(models.all,fit)
            # EA only
            trainX <- trainX[idx.ea,]
            if(sum(apply(trainX,2,var)!=0) <= 1){
                    next
            }
            trainY <- trainY[idx.ea]
            fit <- tryCatch(
                    elastic.net(trainX,trainY),
                    error = function(e) {return ("err")})
            if(!is.data.frame(fit)){
                if(fit == "err"){
                    next
                }
            }
            if(nrow(fit) == 0) next
            fit$cg <- cg[i]
            models.ea <- rbind(models.ea,fit)
    }
}

models.ea <- models.ea[models.ea[,1] != "(Intercept)",]
models.all <- models.all[models.all[,1] != "(Intercept)",]

# mwas by models of all samples
cg2 <- unique(models.all$cg)
mwas.all <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.all[models.all$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.all[models.all$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.all[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.all) <- cg2
colnames(mwas.all) <- c("z","p")

# mwas by models of EA samples
cg2 <- unique(models.ea$cg)
mwas.ea <- matrix(0,nrow=length(cg2),ncol=2)
for(i in 1:length(cg2)){
        pos <- models.ea[models.ea$cg == cg2[i],1]
        gwas <- snp.gwas2$z[is.element(snp.gwas2$pos_hg38, pos)]
        weight <- models.ea[models.ea$cg == cg2[i],2]
        geno <- snp.1kg.eur2[match(pos,map.1kg.eur2$POS),]
        mwas.ea[i,] <- MWAS(gwas, weight, t(geno))
}
rownames(mwas.ea) <- cg2
colnames(mwas.ea) <- c("z","p")

# output models and mwas results
outf <- paste0(outd,"/models-old-cov1.all.wind.",wind[k])
write.csv(models.all,outf)
outf <- paste0(outd,"/models-old-cov1.ea.wind.",wind[k])
write.csv(models.ea,outf)
outf <- paste0(outd,"/mwas-old-cov1.all.wind.",wind[k])
write.csv(mwas.all,outf)
outf <- paste0(outd,"/mwas-old-cov1.ea.wind.",wind[k])
write.csv(mwas.ea,outf)
# Out:
# 1
# [1] "This cg is: 1987413"
# [1] "Dim of trainX: 297" "Dim of trainX: 31"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept)
-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -4.526254e-18
# 1979235      2.332323e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0007785337
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 0.0007785337
# 42
# [1] "This cg is: 1988141"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -2.100642e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.100642e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0007876715
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 0.0007876715
# 43
# [1] "This cg is: 1988201"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 1.473837e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.382318e-18
# 1979235      1.431582e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008327556
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 0.0008327556
# 44
# [1] "This cg is: 1988216"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.151965e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -2.602912e-18
# 1979235      1.407822e-18
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008378378
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 8.378378e-04
# 1979235     6.981176e-19
# 45
# [1] "This cg is: 1988292"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -3.032378e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -3.032378e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008302045
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 0.0008302045
# 46
# [1] "This cg is: 1988321"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -7.792703e-20
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -7.792703e-20
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000812691
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 8.126910e-04
# 1994714     8.542319e-19
# 47
# [1] "This cg is: 1988325"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -1.067262e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.823967e-18
# 1979235      9.718027e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                       s1
# (Intercept) 0.0008096687
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 8.096687e-04
# 1994714     2.125566e-19
# 48
# [1] "This cg is: 1988332"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 2.55804e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.457545e-18
# 1979235      9.696004e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000804038
# [1] "Coefficients when optimal: "
#                       s0
# (Intercept) 8.040380e-04
# 1994714     8.435592e-19
# 49
# [1] "This cg is: 1988401"
# [1] "Dim of trainX: 297" "Dim of trainX: 32"
# [1] "Len of trainY: 297"
# [1] "Coefficients when fitting: "
#                        s1
# (Intercept) -6.030875e-19
# [1] "Coefficients when optimal: "
#                        s0
# (Intercept) -1.744981e-18
# 1979235      6.462082e-19
# [1] "Dim of trainX: 133" "Dim of trainX: 32"
# [1] "Len of trainY: 133"
# [1] "Coefficients when fitting: "
#                      s1
# (Intercept) 0.000728097
# [1] "Coefficients when optimal: "
#                      s0
# (Intercept) 0.000728097

# %% [markdown]
# ## Make merged tables

# %% [markdown]
# ### For models

# %%
models.all$cg_features <- paste0(models.all$cg, "_", models.all$features)

# %%
head(models.all)
# Out:
#    features coefs         cg      cg_features
# 2  1979188  -1.509185e-18 1987413 1987413_1979188
# 4  1979188  -1.501484e-18 1987418 1987418_1979188
# 7  1977810  -3.862732e-19 1987449 1987449_1977810
# 11 1977810  -7.351572e-19 1987492 1987492_1977810
# 13 1977810  -1.441288e-18 1987511 1987511_1977810
# 17 1987813  -1.317435e-18 1987604 1987604_1987813

# %%
models.all.mine$cg_features <- paste0(models.all.mine$cg, "_", models.all.mine$features)

# %%
head(models.all.mine)
# Out:
#   features coefs         cg      cg_features
# 1 1977810   0.0007759077 1987413 1987413_1977810
# 2 1981360  -0.0010706745 1987413 1987413_1981360
# 3 1987719  -0.0012241509 1987413 1987413_1987719
# 4 1987813   0.0001768736 1987413 1987413_1987813
# 5 1990232  -0.0012980759 1987413 1987413_1990232
# 6 1994382   0.0011054336 1987413 1987413_1994382

# %%
colnames(models.all.mine)[2] <- "coefs_new"

# %%
colnames(models.all)[2] <- "coefs_old"

# %%
merged <- merge(models.all.mine, models.all)

# %%
head(merged)
# Out:
#   features cg      cg_features     coefs_new     coefs_old
# 1 1977810  1987449 1987449_1977810  0.0009566741 -3.862732e-19
# 2 1977810  1987492 1987492_1977810  0.0006559560 -7.351572e-19
# 3 1977810  1987511 1987511_1977810  0.0014771475 -1.441288e-18
# 4 1985405  1987808 1987808_1985405 -0.0020381756  5.949856e-19
# 5 1985405  1987853 1987853_1985405 -0.0026263623  8.824337e-19
# 6 1985405  1987858 1987858_1985405 -0.0022877707  1.469118e-18

# %% [markdown]
# ### for MWAS results

# %%
mwas.all.mine <- mwas.all.mine[which(rownames(mwas.all.mine) %in% rownames(mwas.all)), ]

# %%
mwas.all <- data.frame(mwas.all)

# %%
mwas.all.mine <- data.frame(mwas.all.mine)

# %%
mwas.all$pos <- rownames(mwas.all)
mwas.all.mine$pos <- rownames(mwas.all.mine)
rownames(mwas.all) <- rownames(mwas.all.mine) <- NULL

# %%
colnames(mwas.all)[1:2] <- c("old_Z", "old_p")
colnames(mwas.all.mine)[1:2] <- c("new_Z", "new_p")

# %%
head(mwas.all)
# Out:
#   old_Z     old_p        pos
# 1 -5.483111 4.179106e-08 1987413
# 2 -5.483111 4.179106e-08 1987418
# 3  9.681645 3.608623e-22 1987449
# 4  9.681645 3.608623e-22 1987492
# 5  9.681645 3.608623e-22 1987511
# 6 10.125509 4.257597e-24 1987604

# %%
head(mwas.all.mine)
# Out:
#   new_Z      new_p        pos
# 1  -9.927849 3.149753e-23 1987413
# 2  -9.989794 1.689325e-23 1987418
# 3 -10.027473 1.154330e-23 1987449
# 4 -10.046140 9.553671e-24 1987492
# 5 -10.023970 1.196000e-23 1987511
# 6 -10.018373 1.265698e-23 1987604

# %%
merged2 <- merge(mwas.all, mwas.all.mine, by = "pos")

# %%
head(merged2)
# Out:
#   pos     old_Z     old_p        new_Z      new_p
# 1 1987413 -5.483111 4.179106e-08  -9.927849 3.149753e-23
# 2 1987418 -5.483111 4.179106e-08  -9.989794 1.689325e-23
# 3 1987449  9.681645 3.608623e-22 -10.027473 1.154330e-23
# 4 1987492  9.681645 3.608623e-22 -10.046140 9.553671e-24
# 5 1987511  9.681645 3.608623e-22 -10.023970 1.196000e-23
# 6 1987604 10.125509 4.257597e-24 -10.018373 1.265698e-23

# %%
min(models.all$cg)
max(models.all$cg)
# Out:
# [1] 1987413
# [1] 1988401

# %%
head(snp.gwas2)
# Out:
#         snp        chr  pos_hg38 pos_hg19 info  A1 A2 z         p
# 1580243 rs11773627 chr7 1963098  2002733  0.987 T  C  -5.211806 1.955e-07
# 1581305 rs6972374  chr7 1963408  2003043  0.982 C  T  -5.288320 1.220e-07
# 1585924 rs12666575 chr7 1964786  2004421  0.993 C  T   8.855337 6.441e-19
# 1608594 rs11766575 chr7 1966112  2005747  0.990 T  C   8.833789 6.381e-19
# 1605654 rs4721264  chr7 1973362  2012997  0.985 G  A   9.455969 3.503e-21
# 1592364 rs62442944 chr7 1975412  2015047  0.991 T  G  -5.266792 1.591e-07

# %%
library(ggplot2)

# Common title parts
title_part2 <- "Chr7 :: 1,987,413 - 1,988,401"
title_part3 <- "Combined population (EA, AA) caudate"

# Plot A: merged
plot_a <- ggplot(merged, aes(x = coefs_old, y = coefs_new)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  labs(
    title = paste("Comparison of Coefficients", title_part2, title_part3, sep = "\n"),
    x = "Old Coefficients",
    y = "New Coefficients"
  ) +
  theme(plot.title = element_text(hjust = 0.5, size = 15)) +
  geom_text(aes(label = sprintf("R² = %.2f", summary(lm(coefs_new ~ coefs_old, data = merged))$r.squared)), 
            x = Inf, y = Inf, hjust = 1.1, vjust = 2, size = 5, color = "red")

# Plot B: merged2 log(p-values)
plot_b <- ggplot(merged2, aes(x = log10(old_p), y = log10(new_p))) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  labs(
    title = paste("Comparison of p-values", title_part2, title_part3, sep = "\n"),
    x = "Log10(Old p-values)",
    y = "Log10(New p-values)"
  ) +
  theme(plot.title = element_text(hjust = 0.5, size = 15)) +
  geom_text(aes(label = sprintf("R² = %.2f", summary(lm(log10(new_p) ~ log10(old_p), data = merged2))$r.squared)), 
            x = Inf, y = Inf, hjust = 1.1, vjust = 2, size = 5, color = "red")

# Plot C: merged2 Z-scores
plot_c <- ggplot(merged2, aes(x = old_Z, y = new_Z)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  labs(
    title = paste("Comparison of Z-scores", title_part2, title_part3, sep = "\n"),
    x = "Old Z-scores",
    y = "New Z-scores"
  ) +
  theme(plot.title = element_text(hjust = 0.5, size = 15)) +
  geom_text(aes(label = sprintf("R² = %.2f", summary(lm(new_Z ~ old_Z, data = merged2))$r.squared)), 
            x = Inf, y = Inf, hjust = 1.1, vjust = 2, size = 5, color = "red")

# Print the plots
print(plot_a)
print(plot_b)
print(plot_c)
# Out:
# Warning message in geom_text(aes(label = sprintf("R² = %.2f", summary(lm(coefs_new ~ :
# “All aesthetics have length 1, but the data has 25 rows.
# ℹ Did you mean to use `annotate()`?”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message in geom_text(aes(label = sprintf("R² = %.2f", summary(lm(log10(new_p) ~ :
# “All aesthetics have length 1, but the data has 33 rows.
# ℹ Did you mean to use `annotate()`?”
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# Warning message in geom_text(aes(label = sprintf("R² = %.2f", summary(lm(new_Z ~ :
# “All aesthetics have length 1, but the data has 33 rows.
# ℹ Did you mean to use `annotate()`?”
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %%
files <- list.files("/expanse/lustre/projects/jhu152/naglemi/mwas/gwas", pattern = "scz",
                    full.names = TRUE)

# %%
file_in <- fread(files[1])
# Out:
# Warning message in fread(files[1]):
# “Detected 1 column names but the data has 19 columns (i.e. invalid file). Added 18 extra default column names at the end.”

# %%
real_colnames <- stringr::str_split(colnames(file_in)[1], "\t")[[1]]
colnames(file_in) <- real_colnames

# %%
dim(file_in)
# Out:
# [1] 5879740      19

# %%
file_in[which(file_in$CHR == 7 & file_in$BP >= 1987413 & file_in$BP <= 1988401)][, -13]
# Out:
#   CHR SNP         BP      A1 A2 FRQ_A_53386 FRQ_U_77258 INFO  OR      SE
# 1 7   rs56362140  1988307 C  T  0.965       0.964       0.994 1.04603 0.0234
# 2 7   rs11765550  1987689 G  A  0.635       0.618       0.985 1.08611 0.0090
# 3 7   rs11765549  1987676 G  T  0.631       0.613       0.982 1.08676 0.0090
# 4 7   rs11773316  1987719 C  T  0.640       0.622       0.988 1.08883 0.0090
# 5 7   rs146040447 1987670 G  A  0.965       0.964       0.994 1.04540 0.0234
# 6 7   rs11763870  1987813 T  C  0.397       0.417       0.992 0.91475 0.0088
#   P         ngt HetISqt HetDf HetPVa Nca   Nco   Neff
# 1 5.450e-02 0    0.0    75    0.5784 53386 77258 58749.13
# 2 3.495e-20 0   10.6    75    0.2253 53386 77258 58749.13
# 3 1.744e-20 0   11.8    75    0.2006 53386 77258 58749.13
# 4 2.797e-21 6    9.6    75    0.2475 53386 77258 58749.13
# 5 5.829e-02 0    0.0    75    0.5635 53386 77258 58749.13
# 6 4.797e-24 0    5.5    75    0.3439 53386 77258 58749.13

# %%
max(file_in$OR)
# Out:
# [1] 1.23788

# %%
min(file_in$OR)
# Out:
# [1] 0.82259

# %%
max(log(file_in$OR, base = 10))
# Out:
# [1] 0.09267855

# %%
min(log(file_in$OR, base = 10))
# Out:
# [1] -0.08481657

# %%
head(gwas_stat_scz)
# Out:
#   CHR SNP        BP        A1 A2 FRQ_A_53386 FRQ_U_77258 INFO  OR      SE
# 1 8   rs62513865 100579985 C  T  0.930       0.927       0.963 1.01207 0.0171
# 2 8   rs79643588 105960820 G  A  0.907       0.906       0.997 0.99144 0.0148
# 3 8   rs17396518 107678601 T  G  0.565       0.566       0.985 0.99790 0.0087
# 4 8   rs983166   107669447 A  C  0.564       0.563       0.988 1.00491 0.0087
# 5 8   rs28842593 102032392 T  C  0.840       0.840       0.948 0.99611 0.0121
# 6 8   rs7014597  103140052 G  C  0.841       0.838       0.994 1.00793 0.0117
#   P      ngt
# 1 0.4847  0
# 2 0.5605  0
# 3 0.8145 13
# 4 0.5704  0
# 5 0.7488  1
# 6 0.5034  0
#   Direction
# 1 --+-++-+--+-+-++-++-++++-+--+-++-----++--------++++++-+-+-+-++---++--+--++++
# 2 +--+-+----+-+++++++++++-+-+-+++--+-----+----+++----++-+---+++++++++++---+--+
# 3 --+-+-++++-++-+-+++-+-+-++-++-+-+--+--+++++++--++++---++++++--+++-++-----+-+
# 4 --+-+---++-++-+-+---+-+-+--++-+-+-+---++--++++++-++----++++--+-++-++++---+++
# 5 ++++-------+++--++--+---+--+-++-+---+++--+---++-+++--++--++++--+-++++-+-+-++
# 6 +++------+--+-+--+--+++-+++--++---+++-+--+---+++-------++++---++--+-++++++++
#   HetISqt HetDf HetPVa  Nca   Nco   Neff
# 1  1.9    75    0.43130 53386 77258 58749.13
# 2 22.0    75    0.05057 53386 77258 58749.13
# 3  0.0    75    0.53120 53386 77258 58749.13
# 4  0.0    75    0.54830 53386 77258 58749.13
# 5  8.7    75    0.26680 53386 77258 58749.13
# 6  0.0    75    0.88930 53386 77258 58749.13
